# %% [markdown]
# ## **Catégorisez automatiquement des questions**
#
# ### partie 2/8 : requête API
#
# #### Un notebook de requête API, qui récupère 50 questions par requête via le wrapper StackAPI ou bien via Stack Exchange API, et qui stocke les principales caractéristiques de ces questions dans un DataFrame.
#
# <br>

# %% [markdown]
# ## 1 Imports

# %%
import requests
import datetime
import pandas as pd

# %% [markdown]
# ## 2 Requete API, via Stack Exchange API : objectif

# %%
# "réaliser une requête de 50 questions sur une période définie, contenant le tag “python”
# et qui ont un score > 50 (votes), récupérer les données principales de la question
# (date, titre, tags, score) dans un DataFrame et les afficher"

# %% [markdown]
# ## 3 Authentification, RGPD (filtre)

# %%
# Authentification
# Pas nécessaire ici, nous avons droit à 10 000 requêtes(lecture)/j sans OAuth 2.0
# L'OAuth 2.0 est indispensable seulement pour les requetes en écriture


# RGPD
# Nous n'avons aucune raison d'extraire des données personnelles ici, donc nous éviterons non seulement
# certaines colonnes évidentes, par exemple :
# OwnerUserId, OwnerDisplayName, LastEditorUserId, LastEditorDisplayName, etc...
# mais aussi la clé primaire (l'id), qui permettrait de les retrouver
# (notre cle primaire, si nous en avons besoin, sera simplement l'index de notre dataframe)

# Remarque /RGPD :
# github offre une sécurité supplémentaire avec github secrets,
# qui nous informe si des failles de sécurité sont détectées
# (même si le fichier est compressé !)

# Nous allons donc commencer par créer un filtre.
# On peut le faire depuis https://api.stackexchange.com/docs/create-filter,
# Ou directement depuis ce notebook, en utilisant par exemple le module requests.

api_filter_url = 'https://api.stackexchange.com/2.3/filters/create'
filter_params = {
    'include': 'creation_date,title,tags,score',
    'unsafe': 'false',
}

response = requests.get(api_filter_url, params=filter_params)
data = response.json()
print(data)
# Out:
# {'items': [{'included_fields': ['.backoff', '.error_id', '.error_message', '.error_name', '.has_more', '.items', '.quota_max', '.quota_remaining', 'access_token.access_token', 'access_token.account_id', 'access_token.expires_on_date', 'access_token.scope', 'account_merge.merge_date', 'account_merge.new_account_id', 'account_merge.old_account_id', 'achievement.account_id', 'achievement.achievement_type', 'achievement.badge_rank', 'achievement.creation_date', 'achievement.is_unread', 'achievement.link', 'achievement.on_site', 'achievement.reputation_change', 'achievement.title', 'answer.answer_id', 'answer.collectives', 'answer.community_owned_date', 'answer.content_license', 'answer.creation_date', 'answer.is_accepted', 'answer.last_activity_date', 'answer.last_edit_date', 'answer.locked_date', 'answer.owner', 'answer.posted_by_collectives', 'answer.question_id', 'answer.recommendations', 'answer.score', 'article.article_id', 'article.article_type', 'article.creation_date', 'article.last_activity_date', 'article.last_edit_date', 'article.link', 'article.owner', 'article.score', 'article.tags', 'article.title', 'article.view_count', 'badge.award_count', 'badge.badge_id', 'badge.badge_type', 'badge.link', 'badge.name', 'badge.rank', 'badge.user', 'badge_count.bronze', 'badge_count.gold', 'badge_count.silver', 'closed_details.by_users', 'closed_details.description', 'closed_details.on_hold', 'closed_details.original_questions', 'closed_details.reason', 'collective.description', 'collective.external_links', 'collective.link', 'collective.name', 'collective.slug', 'collective.tags', 'collective_external_link.link', 'collective_external_link.type', 'collective_membership.collective', 'collective_membership.role', 'collective_recommendation.collective', 'collective_recommendation.creation_date', 'collective_report.collective', 'collective_report.creation_date', 'collective_report.dimensions', 'collective_report.download_link', 'collective_report.end_date', 'collective_report.included_tags', 'collective_report.metrics', 'collective_report.name', 'collective_report.report_id', 'collective_report.report_type', 'collective_report.start_date', 'collective_report.state', 'comment.comment_id', 'comment.content_license', 'comment.creation_date', 'comment.edited', 'comment.owner', 'comment.parent_comment_id', 'comment.post_id', 'comment.post_state', 'comment.reply_to_user', 'comment.score', 'error.description', 'error.error_id', 'error.error_name', 'event.creation_date', 'event.event_id', 'event.event_type', 'exchanged_access_token.access_token', 'exchanged_access_token.account_id', 'exchanged_access_token.exchange_type', 'exchanged_access_token.expires_on_date', 'exchanged_access_token.original_access_token', 'exchanged_access_token.scope', 'filter.filter', 'filter.filter_type', 'filter.included_fields', 'flag_option.count', 'flag_option.description', 'flag_option.dialog_title', 'flag_option.has_flagged', 'flag_option.is_retraction', 'flag_option.option_id', 'flag_option.requires_comment', 'flag_option.requires_question_id', 'flag_option.requires_site', 'flag_option.sub_options', 'flag_option.title', 'inbox_item.answer_id', 'inbox_item.comment_id', 'inbox_item.creation_date', 'inbox_item.is_unread', 'inbox_item.item_type', 'inbox_item.link', 'inbox_item.question_id', 'inbox_item.site', 'inbox_item.title', 'info.answers_per_minute', 'info.api_revision', 'info.badges_per_minute', 'info.new_active_users', 'info.questions_per_minute', 'info.total_accepted', 'info.total_answers', 'info.total_badges', 'info.total_comments', 'info.total_questions', 'info.total_unanswered', 'info.total_users', 'info.total_votes', 'migration_info.on_date', 'migration_info.other_site', 'migration_info.question_id', 'network_activity.account_id', 'network_activity.activity_type', 'network_activity.api_site_parameter', 'network_activity.badge_id', 'network_activity.creation_date', 'network_activity.description', 'network_activity.link', 'network_activity.post_id', 'netwo ...

# %%
# ??

api_filter_url = 'https://api.stackexchange.com/2.3/filters/create'
filter_params = {
    'include': 'creation_date,title,tags,score',
    'unsafe': 'false',
}

response = requests.post(api_filter_url, data=filter_params)
data = response.json()
print(data)
# Out:
# {'items': [{'included_fields': ['.backoff', '.error_id', '.error_message', '.error_name', '.has_more', '.items', '.quota_max', '.quota_remaining', 'access_token.access_token', 'access_token.account_id', 'access_token.expires_on_date', 'access_token.scope', 'account_merge.merge_date', 'account_merge.new_account_id', 'account_merge.old_account_id', 'achievement.account_id', 'achievement.achievement_type', 'achievement.badge_rank', 'achievement.creation_date', 'achievement.is_unread', 'achievement.link', 'achievement.on_site', 'achievement.reputation_change', 'achievement.title', 'answer.answer_id', 'answer.collectives', 'answer.community_owned_date', 'answer.content_license', 'answer.creation_date', 'answer.is_accepted', 'answer.last_activity_date', 'answer.last_edit_date', 'answer.locked_date', 'answer.owner', 'answer.posted_by_collectives', 'answer.question_id', 'answer.recommendations', 'answer.score', 'article.article_id', 'article.article_type', 'article.creation_date', 'article.last_activity_date', 'article.last_edit_date', 'article.link', 'article.owner', 'article.score', 'article.tags', 'article.title', 'article.view_count', 'badge.award_count', 'badge.badge_id', 'badge.badge_type', 'badge.link', 'badge.name', 'badge.rank', 'badge.user', 'badge_count.bronze', 'badge_count.gold', 'badge_count.silver', 'closed_details.by_users', 'closed_details.description', 'closed_details.on_hold', 'closed_details.original_questions', 'closed_details.reason', 'collective.description', 'collective.external_links', 'collective.link', 'collective.name', 'collective.slug', 'collective.tags', 'collective_external_link.link', 'collective_external_link.type', 'collective_membership.collective', 'collective_membership.role', 'collective_recommendation.collective', 'collective_recommendation.creation_date', 'collective_report.collective', 'collective_report.creation_date', 'collective_report.dimensions', 'collective_report.download_link', 'collective_report.end_date', 'collective_report.included_tags', 'collective_report.metrics', 'collective_report.name', 'collective_report.report_id', 'collective_report.report_type', 'collective_report.start_date', 'collective_report.state', 'comment.comment_id', 'comment.content_license', 'comment.creation_date', 'comment.edited', 'comment.owner', 'comment.parent_comment_id', 'comment.post_id', 'comment.post_state', 'comment.reply_to_user', 'comment.score', 'error.description', 'error.error_id', 'error.error_name', 'event.creation_date', 'event.event_id', 'event.event_type', 'exchanged_access_token.access_token', 'exchanged_access_token.account_id', 'exchanged_access_token.exchange_type', 'exchanged_access_token.expires_on_date', 'exchanged_access_token.original_access_token', 'exchanged_access_token.scope', 'filter.filter', 'filter.filter_type', 'filter.included_fields', 'flag_option.count', 'flag_option.description', 'flag_option.dialog_title', 'flag_option.has_flagged', 'flag_option.is_retraction', 'flag_option.option_id', 'flag_option.requires_comment', 'flag_option.requires_question_id', 'flag_option.requires_site', 'flag_option.sub_options', 'flag_option.title', 'inbox_item.answer_id', 'inbox_item.comment_id', 'inbox_item.creation_date', 'inbox_item.is_unread', 'inbox_item.item_type', 'inbox_item.link', 'inbox_item.question_id', 'inbox_item.site', 'inbox_item.title', 'info.answers_per_minute', 'info.api_revision', 'info.badges_per_minute', 'info.new_active_users', 'info.questions_per_minute', 'info.total_accepted', 'info.total_answers', 'info.total_badges', 'info.total_comments', 'info.total_questions', 'info.total_unanswered', 'info.total_users', 'info.total_votes', 'migration_info.on_date', 'migration_info.other_site', 'migration_info.question_id', 'network_activity.account_id', 'network_activity.activity_type', 'network_activity.api_site_parameter', 'network_activity.badge_id', 'network_activity.creation_date', 'network_activity.description', 'network_activity.link', 'network_activity.post_id', 'netwo ...

# %%
# La stack exchange API inclue des champs par defaut, la doc conseille de filtrer
# manuellement la réponse.

# %% [markdown]
# ## 4 Stratégies possibles

# %%
# On peut utiliser directement l'outil en ligne, qui fournit une reponse de 100 questions max,
# format JSON compressé.
# exemple de la doc :
# /2.3/questions?fromdate=1320969600&todate=1321660800&order=desc&min=10&sort=votes&tagged=skyrim&site=gaming

# Avant de récupérer nos questions, nous pouvons d'abord nous faire une idée du nombre de questions
# qui satisfont nos critères sur une période donnée.

# Pour cela il y a plusieurs stratégies possibles,
# on peut par exemple utiliser le filtre "total" (built-in)
# Ou la méthode/endpoint "search" (plus flexible)
# Comme nous allons au final récupérer des questions, utilisons directement la méthode questions

# %% [markdown]
# ## 5 Test : nb de questions valides cette année

# %%
# All dates in the API are in unix epoch time

def get_number_of_questions(tag, start_date, end_date, min_score=50, pagesize=50):
    """
    Get the number of questions from Stack Exchange API based on specified criteria.

    Parameters:
    - tag (str): The tag to filter questions.
    - start_date (datetime): The start date for the query.
    - end_date (datetime): The end date for the query.
    - min_score (int): Minimum score for the questions (default: 50).
    - page_size (int): Number of questions per page (default API: 30, max: 100).

    Returns:
    - int: Number of questions matching the criteria.
    """
    api_url = 'https://api.stackexchange.com/2.3/questions'

    params = {
        'order': 'desc',
        'sort': 'votes',
        'tagged': tag,
        'site': 'stackoverflow',
        'fromdate': int(start_date.timestamp()),
        'todate': int(end_date.timestamp()),
        'min': min_score,
        'pagesize': pagesize
    }

    try:
        response = requests.get(api_url, params=params)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        data = response.json()

        if 'items' in data:
            return len(data['items'])
        else:
            return 0

    except requests.RequestException as e:
        print(f"Error during API request: {e}")
        return 0

# Observons l'activité cette année
tag='python'
start_date = datetime.datetime(2023, 1, 1)
end_date = datetime.datetime(2023, 11, 27)

result = get_number_of_questions(tag, start_date, end_date, pagesize=100)

print(f'Number of questions with the tag "{tag}" between {start_date} and {end_date}, votes > 50: \n{result}')
# Out:
# Number of questions with the tag "python" between 2023-01-01 00:00:00 and 2023-11-27 00:00:00, votes > 50:
# 13

# %% [markdown]
# ## 6 nb de questions valides l'année derniere

# %%
# Seulement 10 questions crées avec le tag python et un score > 50 (en presque un an)

# Observons l'activité l'année dernière
start_date = datetime.datetime(2022, 1, 1)
end_date = datetime.datetime(2022, 12, 31)

result = get_number_of_questions(tag, start_date, end_date)
print(f'Number of questions with the tag "{tag}" between {start_date} and {end_date}, votes > 50: \n{result}')

# Il faut du temps pour que le score atteigne 50, mais le traffic sur stack exchange a
# peut-être aussi diminué depuis l'année dernière (arrivée de chatGPT, etc...) ?
# Out:
# Number of questions with the tag "python" between 2022-01-01 00:00:00 and 2022-12-31 00:00:00, votes > 50:
# 37

# %%
# Juste pour savoir

# Observons l'activité cette année, sur 1 semaine
start_date = datetime.datetime(2023, 1, 1)
end_date = datetime.datetime(2023, 1, 8)

result = get_number_of_questions(tag, start_date, end_date, min_score=5)
print(f'Number of questions 2023: \n{result}')

# Puis l'année dernière
start_date_2022 = datetime.datetime(2022, 1, 1)
end_date_2022 = datetime.datetime(2022, 1, 8)

result2 = get_number_of_questions(tag, start_date_2022, end_date_2022, min_score=5)
print(f'Number of questions 2022: \n{result2}')

# Il semble que c'est bien le score qui limite le nombre de réponses.
# Out:
# Number of questions 2023:
# 15
# Number of questions 2022:
# 50

# %% [markdown]
# ## 7 Notre requete

# %%
def get_questions(tag, start_date, end_date, min_score=50, pagesize=50,
                  api_url='https://api.stackexchange.com/2.3/questions',
                  site = 'stackoverflow'):
    """
    Get questions from Stack Exchange API based on specified criteria.

    Parameters:
    - tag (str): The tag to filter questions.
    - start_date (datetime): The start date for the query.
    - end_date (datetime): The end date for the query.
    - min_score (int): Minimum score for the questions (default: 50).
    - page_size (int): Number of questions per page (default API: 30, max: 100. We want 50).

    Returns:
    - questions formatted as JSON object
    """
    api_url = api_url

    params = {
        'order': 'desc',
        'sort': 'votes',
        'tagged': tag,
        'site': site,
        'fromdate': int(start_date.timestamp()),
        'todate': int(end_date.timestamp()),
        'min': min_score,
        'pagesize': pagesize  # 30 par défaut, 100 max, 50 ici
    }

    try:
        response = requests.get(api_url, params=params)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        data = response.json()
        return data

    except requests.RequestException as e:
        print(f"Error during API request: {e}")
        return 0


# Prenons une période récente, et suffisante
start_date = datetime.datetime(2020, 1, 1)
end_date = datetime.datetime(2023, 11, 27)

result = get_questions(tag, start_date, end_date)
display(result)
# Out:
# {'items': [{'tags': ['python', 'pip', 'packaging', 'pyproject.toml'],
#    'owner': {'account_id': 3400218,
#     'reputation': 29683,
#     'user_id': 3015186,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.stack.imgur.com/KagUg.jpg?s=256&g=1',
#     'display_name': 'Niko Fohr',
#     'link': 'https://stackoverflow.com/users/3015186/niko-fohr'},
#    'is_answered': True,
#    'view_count': 284062,
#    'accepted_answer_id': 66472800,
#    'answer_count': 5,
#    'score': 351,
#    'last_activity_date': 1677001110,
#    'creation_date': 1595181079,
#    'last_edit_date': 1614931841,
#    'question_id': 62983756,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62983756/what-is-pyproject-toml-file-for',
#    'title': 'What is pyproject.toml file for?'},
#   {'tags': ['python', 'pandas', 'xlrd', 'pcf'],
#    'owner': {'account_id': 20190357,
#     'reputation': 2909,
#     'user_id': 14808721,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-M5mYg2mtURw/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuck8OiIkLBi6IBucITy4XIy72uK80A/s96-c/photo.jpg?sz=256',
#     'display_name': 'Vignesh K',
#     'link': 'https://stackoverflow.com/users/14808721/vignesh-k'},
#    'is_answered': True,
#    'view_count': 586368,
#    'closed_date': 1608122436,
#    'answer_count': 2,
#    'score': 289,
#    'last_activity_date': 1612795847,
#    'creation_date': 1607702016,
#    'last_edit_date': 1612795847,
#    'question_id': 65254535,
#    'link': 'https://stackoverflow.com/questions/65254535/xlrd-biffh-xlrderror-excel-xlsx-file-not-supported',
#    'closed_reason': 'Duplicate',
#    'title': 'xlrd.biffh.XLRDError: Excel xlsx file; not supported'},
#   {'tags': ['python', 'machine-learning', 'deep-learning', 'pytorch'],
#    'owner': {'account_id': 543843,
#     'reputation': 24956,
#     'user_id': 913098,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/e3e07b09128f889209b738276d42d7ef?s=256&d=identicon&r=PG',
#     'display_name': 'Gulzar',
#     'link': 'https://stackoverflow.com/users/913098/gulzar'},
#    'is_answered': True,
#    'view_count': 273209,
#    'accepted_answer_id': 60018731,
#    'answer_count': 4,
#    'score': 264,
#    'last_activity_date': 1674767993,
#    'creation_date': 1580572695,
#    'last_edit_date': 1648471214,
#    'question_id': 60018578,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60018578/what-does-model-eval-do-in-pytorch',
#    'title': 'What does model.eval() do in pytorch?'},
#   {'tags': ['python', 'linux', 'docker', 'docker-compose'],
#    'owner': {'account_id': 20032870,
#     'reputation': 2271,
#     'user_id': 14685247,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0a20904979404a4f79e1d4f8bb405aab?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'ming',
#     'link': 'https://stackoverflow.com/users/14685247/ming'},
#    'is_answered': True,
#    'view_count': 346451,
#    'answer_count': 22,
#    'score': 227,
#    'last_activity_date': 1699410067,
#    'creation_date': 1606035195,
#    'last_edit_date': 1675820908,
#    'question_id': 64952238,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64952238/docker-errors-dockerexception-error-while-fetching-server-api-version',
#    'title': 'docker.errors.DockerException: Error while fetching server API version'},
#   {'tags': ['python', 'pandas', 'numpy', 'scikit-learn', 'python-3.7'],
#    'owner': {'account_id': 6886384,
#     'reputation': 2371,
#     'user_id': 15150567,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-OWGodLwptYQ/AAAAAAAAAAI/AAAAAAAAA1o/AMZuucmZZ7jUgnhUF3BKhul3RbeBZAF1Bw/s96-c/photo.jpg?sz=256',
#     'display_name': 'Sachit Jani',
#     'link': 'https://stackoverflow.com/users/15150567/sachit-jani'},
#    'is_answered': True,
#    'view_count': 335022,
#    'protected_date': 1673901248,
#    'answer_count': 19,
#    'score': 227,
#    'last_activity_date': 1680884751,
#    'creation_date': 1612516308,
#    'last_edit_date': 1673850793,
#    'question_id': 66060487,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66060487/valueerror-numpy-ndarray-size-changed-may-indicate-binary-incompatibility-exp',
#    'title': 'ValueError: numpy.ndarray size changed, may indicate binary incompatibility. Expected 88 from C header, got 80 from PyObject'},
#   {'tags': ['python',
#     'postgresql',
#     'sqlalchemy',
#     'flask-sqlalchemy',
#     'psycopg2'],
#    'owner': {'account_id': 8971560,
#     'reputation': 2261,
#     'user_id': 6689838,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1072816459461942/picture?type=large',
#     'display_name': 'Maharsh Gheewala',
#     'link': 'https://stackoverflow.com/users/6689838/maharsh-gheewala'},
#    'is_answered': True,
#    'view_count': 168221,
#    'protected_date': 1675825029,
#    'answer_count': 8,
#    'score': 226,
#    'last_activity_date': 1680670127,
#    'creation_date': 1593658606,
#    'last_edit_date': 1616648738,
#    'question_id': 62688256,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62688256/sqlalchemy-exc-nosuchmoduleerror-cant-load-plugin-sqlalchemy-dialectspostgre',
#    'title': 'sqlalchemy.exc.NoSuchModuleError: Can&#39;t load plugin: sqlalchemy.dialects:postgres'},
#   {'tags': ['python', 'python-3.x', 'windows-10'],
#    'owner': {'account_id': 20238494,
#     'reputation': 2083,
#     'user_id': 14842976,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-tPgUuYJN48Q/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckXs8Wy0ReqrKZ98hL19LxSjnU7mw/s96-c/photo.jpg?sz=256',
#     'display_name': 'Joseph Haywood',
#     'link': 'https://stackoverflow.com/users/14842976/joseph-haywood'},
#    'is_answered': True,
#    'view_count': 1306770,
#    'protected_date': 1615207834,
#    'closed_date': 1691903466,
#    'accepted_answer_id': 65349178,
#    'answer_count': 25,
#    'score': 208,
#    'last_activity_date': 1695144539,
#    'creation_date': 1608242137,
#    'last_edit_date': 1661715212,
#    'question_id': 65348890,
#    'link': 'https://stackoverflow.com/questions/65348890/python-was-not-found-run-without-arguments-to-install-from-the-microsoft-store',
#    'closed_reason': 'Duplicate',
#    'title': 'Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings'},
#   {'tags': ['python', 'error-handling', 'pip'],
#    'owner': {'account_id': 23480036,
#     'reputation': 2188,
#     'user_id': 17532318,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d37672946ecec10b2814be93daa910ef?s=256&d=identicon&r=PG',
#     'display_name': 'Apoliticalboy',
#     'link': 'https://stackoverflow.com/users/17532318/apoliticalboy'},
#    'is_answered': True,
#    'view_count': 323180,
#    'answer_count': 18,
#    'score': 206,
#    'last_activity_date': 1704293535,
#    'creation_date': 1677700339,
#    'last_edit_date': 1694084649,
#    'question_id': 75608323,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75608323/how-do-i-solve-error-externally-managed-environment-every-time-i-use-pip-3',
#    'title': 'How do I solve &quot;error: externally-managed-environment&quot; every time I use pip 3?'},
#   {'tags': ['python', 'macos', 'terminal', 'atom-editor', 'macos-monterey'],
#    'owner': {'account_id': 24663681,
#     'reputation': 3396,
#     'user_id': 18559642,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/13cdab4eb9d9fb5b1c7dece549f96046?s=256&d=identicon&r=PG',
#     'display_name': 'Kirill Ignatyev',
#     'link': 'https://stackoverflow.com/users/18559642/kirill-ignatyev'},
#    'is_answered': True,
#    'view_count': 401498,
#    'protected_date': 1673118234,
#    'accepted_answer_id': 71621142,
#    'answer_count': 18,
#    'score': 205,
#    'last_activity_date': 1675219189,
#    'creation_date': 1648058522,
#    'last_edit_date': 1656277606,
#    'question_id': 71591971,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71591971/how-can-i-fix-the-zsh-command-not-found-python-error-macos-monterey-12-3',
#    'title': 'How can I fix the &quot;zsh: command not found: python&quot; error? (macOS Monterey 12.3, Python&amp;nbsp;3.10, Atom IDE, and atom-python-run 0.9.7)'},
#   {'tags': ['python', 'selenium'],
#    'owner': {'account_id': 10383148,
#     'reputation': 9300,
#     'user_id': 7657180,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6c0ee64d62bb9980080e6881a20a15fc?s=256&d=identicon&r=PG',
#     'display_name': 'YasserKhalil',
#     'link': 'https://stackoverflow.com/users/7657180/yasserkhalil'},
#    'is_answered': True,
#    'view_count': 446974,
#    'protected_date': 1657217293,
#    'accepted_answer_id': 70099102,
#    'answer_count': 11,
#    'score': 201,
#    'last_activity_date': 1699941869,
#    'creation_date': 1604676159,
#    'question_id': 64717302,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64717302/deprecationwarning-executable-path-has-been-deprecated-selenium-python',
#    'title': 'DeprecationWarning: executable_path has been deprecated selenium python'},
#   {'tags': ['python', 'scipy', 'pip', 'embedded-linux', 'python-wheel'],
#    'owner': {'account_id': 18141135,
#     'reputation': 2236,
#     'user_id': 13194982,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-VAtJtMr3kYU/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJMjwnVVurgGF-5_cRAsdHZDLzCo4Q/photo.jpg?sz=256',
#     'display_name': 'Sourabrt',
#     'link': 'https://stackoverflow.com/users/13194982/sourabrt'},
#    'is_answered': True,
#    'view_count': 457488,
#    'answer_count': 30,
#    'score': 201,
#    'last_activity_date': 1658308129,
#    'creation_date': 1587560390,
#    'question_id': 61365790,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61365790/error-could-not-build-wheels-for-scipy-which-use-pep-517-and-cannot-be-installe',
#    'title': 'ERROR: Could not build wheels for scipy which use PEP 517 and cannot be installed directly'},
#   {'tags': ['python', 'tensorflow', 'ray'],
#    'owner': {'account_id': 22989345,
#     'reputation': 2031,
#     'user_id': 17115086,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/16c137f7793988efb97ab410f7aec4f6?s=256&d=identicon&r=PG',
#     'display_name': 'hasu33',
#     'link': 'https://stackoverflow.com/users/17115086/hasu33'},
#    'is_answered': True,
#    'view_count': 291422,
#    'protected_date': 1689017298,
#    'answer_count': 17,
#    'score': 198,
#    'last_activity_date': 1704509020,
#    'creation_date': 1653965255,
#    'last_edit_date': 1656248470,
#    'question_id': 72441758,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72441758/typeerror-descriptors-cannot-not-be-created-directly',
#    'title': 'TypeError: Descriptors cannot not be created directly'},
#   {'tags': ['python', 'macos', 'homebrew', 'python-2.x'],
#    'owner': {'account_id': 3023753,
#     'reputation': 3686,
#     'user_id': 2564199,
#     'user_type': 'registered',
#     'accept_rate': 74,
#     'profile_image': 'https://www.gravatar.com/avatar/e7de6198991a53a6c0da7ef3f5011725?s=256&d=identicon&r=PG',
#     'display_name': 'Pauline',
#     'link': 'https://stackoverflow.com/users/2564199/pauline'},
#    'is_answered': True,
#    'view_count': 219883,
#    'accepted_answer_id': 60345962,
#    'answer_count': 13,
#    'score': 195,
#    'last_activity_date': 1675891874,
#    'creation_date': 1582109114,
#    'last_edit_date': 1602553702,
#    'question_id': 60298514,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60298514/how-to-reinstall-python2-from-homebrew',
#    'title': 'How to reinstall python@2 from Homebrew?'},
#   {'tags': ['python', 'pandas', 'dataframe', 'attributeerror'],
#    'owner': {'account_id': 18651684,
#     'reputation': 2031,
#     'user_id': 13595011,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gja1Bf3zfNP7LY4HSFgp6beG2pul2AVcXIsoLC52g=k-s256',
#     'display_name': 'Maksimjeet Chowdhary',
#     'link': 'https://stackoverflow.com/users/13595011/maksimjeet-chowdhary'},
#    'is_answered': True,
#    'view_count': 332632,
#    'protected_date': 1695993982,
#    'answer_count': 3,
#    'score': 184,
#    'last_activity_date': 1702932713,
#    'creation_date': 1680851159,
#    'last_edit_date': 1691967377,
#    'question_id': 75956209,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75956209/error-dataframe-object-has-no-attribute-append',
#    'title': 'Error &quot;&#39;DataFrame&#39; object has no attribute &#39;append&#39;&quot;'},
#   {'tags': ['python', 'python-black'],
#    'owner': {'account_id': 13900281,
#     'reputation': 12022,
#     'user_id': 10036039,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8790cbc891c02fffb597317b43a063fa?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'zerocewl',
#     'link': 'https://stackoverflow.com/users/10036039/zerocewl'},
#    'is_answered': True,
#    'view_count': 81951,
#    'accepted_answer_id': 71674345,
#    'answer_count': 6,
#    'score': 178,
#    'last_activity_date': 1701665110,
#    'creation_date': 1648626375,
#    'last_edit_date': 1651785651,
#    'question_id': 71673404,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71673404/importerror-cannot-import-name-unicodefun-from-click',
#    'title': 'ImportError: cannot import name &#39;_unicodefun&#39; from &#39;click&#39;'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 4071073,
#     'reputation': 4587,
#     'user_id': 3344139,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.stack.imgur.com/ytB7I.jpg?s=256&g=1',
#     'display_name': 'RunOrVeith',
#     'link': 'https://stackoverflow.com/users/3344139/runorveith'},
#    'is_answered': True,
#    'view_count': 106346,
#    'accepted_answer_id': 65793484,
#    'answer_count': 9,
#    'score': 177,
#    'last_activity_date': 1670330583,
#    'creation_date': 1606986952,
#    'last_edit_date': 1619177945,
#    'question_id': 65122957,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65122957/resolving-new-pip-backtracking-runtime-issue',
#    'title': 'Resolving new pip backtracking runtime issue'},
#   {'tags': ['python', 'django', 'django-urls', 'django-4.0'],
#    'owner': {'account_id': 39506,
#     'reputation': 301968,
#     'user_id': 113962,
#     'user_type': 'registered',
#     'accept_rate': 87,
#     'profile_image': 'https://www.gravatar.com/avatar/b80ae1d65878cf68a4b1a00848467527?s=256&d=identicon&r=PG',
#     'display_name': 'Alasdair',
#     'link': 'https://stackoverflow.com/users/113962/alasdair'},
#    'is_answered': True,
#    'view_count': 198444,
#    'protected_date': 1688169134,
#    'accepted_answer_id': 70319607,
#    'answer_count': 5,
#    'score': 174,
#    'last_activity_date': 1690610954,
#    'creation_date': 1639262655,
#    'question_id': 70319606,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70319606/importerror-cannot-import-name-url-from-django-conf-urls-after-upgrading-to',
#    'title': 'ImportError: cannot import name &#39;url&#39; from &#39;django.conf.urls&#39; after upgrading to Django 4.0'},
#   {'tags': ['python', 'python-3.x', 'django'],
#    'owner': {'account_id': 20471934,
#     'reputation': 1877,
#     'user_id': 15022111,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GglbOwwii7QET_t9MBkZTDpGTbdvrOVCOV40SkWew=k-s256',
#     'display_name': 'Hi There',
#     'link': 'https://stackoverflow.com/users/15022111/hi-there'},
#    'is_answered': True,
#    'view_count': 85182,
#    'accepted_answer_id': 66971803,
#    'answer_count': 5,
#    'score': 172,
#    'last_activity_date': 1659887345,
#    'creation_date': 1617722621,
#    'last_edit_date': 1659887345,
#    'question_id': 66971594,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66971594/auto-create-primary-key-used-when-not-defining-a-primary-key-type-warning-in-dja',
#    'title': 'Auto-create primary key used when not defining a primary key type warning in Django'},
#   {'tags': ['python', 'list', 'indexing', 'swap'],
#    'owner': {'account_id': 16490432,
#     'reputation': 2740,
#     'user_id': 13860719,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/9aXXj.jpg?s=256&g=1',
#     'display_name': 'Shaun Han',
#     'link': 'https://stackoverflow.com/users/13860719/shaun-han'},
#    'is_answered': True,
#    'view_count': 22847,
#    'accepted_answer_id': 68152940,
#    'answer_count': 8,
#    'score': 172,
#    'last_activity_date': 1698106750,
#    'creation_date': 1624808189,
#    'last_edit_date': 1698106750,
#    'question_id': 68152730,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/68152730/understand-python-swapping-why-is-a-b-b-a-not-always-equivalent-to-b-a-a',
#    'title': 'Understand Python swapping: why is a, b = b, a not always equivalent to b, a = a, b?'},
#   {'tags': ['python', 'excel', 'pandas'],
#    'owner': {'account_id': 20188429,
#     'reputation': 2607,
#     'user_id': 14807216,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b31b40bb7f63928b9dc755251aa27fc1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'LNQ',
#     'link': 'https://stackoverflow.com/users/14807216/lnq'},
#    'is_answered': True,
#    'view_count': 189071,
#    'protected_date': 1608777720,
#    'answer_count': 5,
#    'score': 171,
#    'last_activity_date': 1667945202,
#    'creation_date': 1607684916,
#    'last_edit_date': 1607938283,
#    'question_id': 65250207,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65250207/pandas-cannot-open-an-excel-xlsx-file',
#    'title': 'Pandas cannot open an Excel (.xlsx) file'},
#   {'tags': ['python', 'visual-c++', 'pip'],
#    'owner': {'account_id': 19662853,
#     'reputation': 1590,
#     'user_id': 14393948,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gg43aRRTvCexfkiavPSoo5UpYnVZY_0K6AcxdI6bg=k-s256',
#     'display_name': 'wloleo',
#     'link': 'https://stackoverflow.com/users/14393948/wloleo'},
#    'is_answered': True,
#    'view_count': 400579,
#    'protected_date': 1668477194,
#    'accepted_answer_id': 64262038,
#    'answer_count': 9,
#    'score': 164,
#    'last_activity_date': 1704444219,
#    'creation_date': 1602156410,
#    'last_edit_date': 1703275879,
#    'question_id': 64261546,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64261546/how-to-solve-error-microsoft-visual-c-14-0-or-greater-is-required-when-inst',
#    'title': 'How to solve &quot;error: Microsoft Visual C++ 14.0 or greater is required&quot; when installing Python packages?'},
#   {'tags': ['python', 'python-3.x', 'tensorflow', 'keras', 'tensorflow2.0'],
#    'owner': {'account_id': 3882738,
#     'reputation': 18754,
#     'user_id': 3214872,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://i.stack.imgur.com/NJBvG.jpg?s=256&g=1',
#     'display_name': 'GPhilo',
#     'link': 'https://stackoverflow.com/users/3214872/gphilo'},
#    'is_answered': True,
#    'view_count': 468840,
#    'protected_date': 1596965559,
#    'accepted_answer_id': 59823284,
#    'answer_count': 19,
#    'score': 160,
#    'last_activity_date': 1667973558,
#    'creation_date': 1579523213,
#    'last_edit_date': 1590593147,
#    'question_id': 59823283,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59823283/could-not-load-dynamic-library-cudart64-101-dll-on-tensorflow-cpu-only-install',
#    'title': 'Could not load dynamic library &#39;cudart64_101.dll&#39; on tensorflow CPU-only installation'},
#   {'tags': ['python', 'linux', 'alpine-linux'],
#    'owner': {'account_id': 6547232,
#     'reputation': 2169,
#     'user_id': 5062828,
#     'user_type': 'registered',
#     'accept_rate': 22,
#     'profile_image': 'https://lh5.googleusercontent.com/-76-PjkdknXw/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQPo1bNLcNrv-ki3G8Lnlad_JmAClQ/mo/photo.jpg?sz=256',
#     'display_name': 'Cutaraca',
#     'link': 'https://stackoverflow.com/users/5062828/cutaraca'},
#    'is_answered': True,
#    'view_count': 288260,
#    'accepted_answer_id': 62555259,
#    'answer_count': 9,
#    'score': 158,
#    'last_activity_date': 1701362798,
#    'creation_date': 1593001526,
#    'question_id': 62554991,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62554991/how-do-i-install-python-on-alpine-linux',
#    'title': 'How do I install python on alpine linux?'},
#   {'tags': ['python', 'pip', 'python-poetry'],
#    'owner': {'account_id': 446266,
#     'reputation': 6672,
#     'user_id': 839211,
#     'user_type': 'registered',
#     'accept_rate': 90,
#     'profile_image': 'https://i.stack.imgur.com/THWvr.jpg?s=256&g=1',
#     'display_name': 'Felipe',
#     'link': 'https://stackoverflow.com/users/839211/felipe'},
#    'is_answered': True,
#    'view_count': 113349,
#    'accepted_answer_id': 62787881,
#    'answer_count': 17,
#    'score': 154,
#    'last_activity_date': 1705932759,
#    'creation_date': 1594067909,
#    'last_edit_date': 1662582741,
#    'question_id': 62764148,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62764148/how-to-import-requirements-txt-from-an-existing-project-using-poetry',
#    'title': 'How to import requirements.txt from an existing project using Poetry'},
#   {'tags': ['python', 'path', 'pip', 'requirements.txt'],
#    'owner': {'account_id': 8311384,
#     'reputation': 2171,
#     'user_id': 6246352,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/ws9ud.jpg?s=256&g=1',
#     'display_name': 'Naeem Khoshnevis',
#     'link': 'https://stackoverflow.com/users/6246352/naeem-khoshnevis'},
#    'is_answered': True,
#    'view_count': 55580,
#    'protected_date': 1662599526,
#    'accepted_answer_id': 62886215,
#    'answer_count': 1,
#    'score': 154,
#    'last_activity_date': 1652418020,
#    'creation_date': 1594683418,
#    'question_id': 62885911,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62885911/pip-freeze-creates-some-weird-path-instead-of-the-package-version',
#    'title': 'pip freeze creates some weird path instead of the package version'},
#   {'tags': ['python', 'visual-studio-code', 'python-poetry'],
#    'owner': {'account_id': 10908059,
#     'reputation': 3204,
#     'user_id': 8491363,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6efa1647cc8d6adae97bcab9fd30d9ef?s=256&d=identicon&r=PG',
#     'display_name': 'user8491363',
#     'link': 'https://stackoverflow.com/users/8491363/user8491363'},
#    'is_answered': True,
#    'view_count': 93829,
#    'accepted_answer_id': 64434542,
#    'answer_count': 4,
#    'score': 153,
#    'last_activity_date': 1695631489,
#    'creation_date': 1579796188,
#    'question_id': 59882884,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59882884/vscode-doesnt-show-poetry-virtualenvs-in-select-interpreter-option',
#    'title': 'VSCode doesn&#39;t show poetry virtualenvs in select interpreter option'},
#   {'tags': ['python', 'machine-learning', 'package', 'conda', 'python-poetry'],
#    'owner': {'account_id': 1449869,
#     'reputation': 2671,
#     'user_id': 1367124,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://i.stack.imgur.com/azGrD.jpg?s=256&g=1',
#     'display_name': 'Seub',
#     'link': 'https://stackoverflow.com/users/1367124/seub'},
#    'is_answered': True,
#    'view_count': 67113,
#    'accepted_answer_id': 71110028,
#    'answer_count': 3,
#    'score': 153,
#    'last_activity_date': 1699380700,
#    'creation_date': 1643123383,
#    'last_edit_date': 1643126235,
#    'question_id': 70851048,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70851048/does-it-make-sense-to-use-conda-poetry',
#    'title': 'Does it make sense to use Conda + Poetry?'},
#   {'tags': ['python', 'pandas', 'dataframe', 'data-wrangling', 'data-munging'],
#    'owner': {'account_id': 29727,
#     'reputation': 4573,
#     'user_id': 80544,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.stack.imgur.com/HtN07.jpg?s=256&g=1',
#     'display_name': 'Glenn',
#     'link': 'https://stackoverflow.com/users/80544/glenn'},
#    'is_answered': True,
#    'view_count': 184768,
#    'accepted_answer_id': 70837545,
#    'answer_count': 8,
#    'score': 152,
#    'last_activity_date': 1690552412,
#    'creation_date': 1643042804,
#    'last_edit_date': 1645482240,
#    'question_id': 70837397,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70837397/good-alternative-to-pandas-append-method-now-that-it-is-being-deprecated',
#    'title': 'Good alternative to Pandas .append() method, now that it is being deprecated?'},
#   {'tags': ['python', 'python-3.x', 'list', 'cpython', 'python-internals'],
#    'owner': {'account_id': 1843521,
#     'reputation': 27823,
#     'user_id': 1672429,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0815eb7d4e9dd58022d51ba2011b9c0a?s=256&d=identicon&r=PG',
#     'display_name': 'Stefan Pochmann',
#     'link': 'https://stackoverflow.com/users/1672429/stefan-pochmann'},
#    'is_answered': True,
#    'view_count': 6142,
#    'accepted_answer_id': 60551320,
#    'answer_count': 3,
#    'score': 149,
#    'last_activity_date': 1583600431,
#    'creation_date': 1583425357,
#    'last_edit_date': 1583429583,
#    'question_id': 60549865,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60549865/what-causes-a-to-overallocate',
#    'title': 'What causes [*a] to overallocate?'},
#   {'tags': ['python', 'fastapi', 'uvicorn'],
#    'owner': {'account_id': 18038692,
#     'reputation': 1441,
#     'user_id': 13111448,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b0668a7d54439dc6d0e453488bf53827?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Pokisutra',
#     'link': 'https://stackoverflow.com/users/13111448/pokisutra'},
#    'is_answered': True,
#    'view_count': 217945,
#    'protected_date': 1668645866,
#    'accepted_answer_id': 62934660,
#    'answer_count': 14,
#    'score': 142,
#    'last_activity_date': 1693004003,
#    'creation_date': 1584987372,
#    'last_edit_date': 1648939338,
#    'question_id': 60819376,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60819376/fastapi-throws-an-error-error-loading-asgi-app-could-not-import-module-api',
#    'title': 'FastAPI throws an error (Error loading ASGI app. Could not import module &quot;api&quot;)'},
#   {'tags': ['python', 'google-analytics-api'],
#    'owner': {'account_id': 6468208,
#     'reputation': 6575,
#     'user_id': 5009293,
#     'user_type': 'registered',
#     'accept_rate': 76,
#     'profile_image': 'https://graph.facebook.com/995762863775266/picture?type=large',
#     'display_name': 'Doug Coats',
#     'link': 'https://stackoverflow.com/users/5009293/doug-coats'},
#    'is_answered': True,
#    'view_count': 224615,
#    'accepted_answer_id': 73932621,
#    'answer_count': 19,
#    'score': 140,
#    'last_activity_date': 1704967138,
#    'creation_date': 1663949925,
#    'last_edit_date': 1704753149,
#    'question_id': 73830524,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73830524/attributeerror-module-lib-has-no-attribute-x509-v-flag-cb-issuer-check',
#    'title': 'AttributeError: module &#39;lib&#39; has no attribute &#39;X509_V_FLAG_CB_ISSUER_CHECK&#39;'},
#   {'tags': ['python', 'python-3.x', 'windows', 'numpy'],
#    'owner': {'account_id': 19883764,
#     'reputation': 1403,
#     'user_id': 14567162,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-8ED7m_am4Uo/AAAAAAAAAAI/AAAAAAAAAbU/AMZuuclxX7dkrrBdmjNHqH7VsijjuTKGIg/s96-c/photo.jpg?sz=256',
#     'display_name': 'Reed Collins',
#     'link': 'https://stackoverflow.com/users/14567162/reed-collins'},
#    'is_answered': True,
#    'view_count': 85541,
#    'protected_date': 1605219106,
#    'accepted_answer_id': 64658254,
#    'answer_count': 9,
#    'score': 140,
#    'last_activity_date': 1610096233,
#    'creation_date': 1604360224,
#    'last_edit_date': 1605519690,
#    'question_id': 64654805,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64654805/how-do-you-fix-runtimeerror-package-fails-to-pass-a-sanity-check-for-numpy-an',
#    'title': 'How do you fix &quot;runtimeError: package fails to pass a sanity check&quot; for numpy and pandas?'},
#   {'tags': ['python', 'tensorflow', 'anaconda'],
#    'owner': {'account_id': 10181486,
#     'reputation': 3349,
#     'user_id': 7518091,
#     'user_type': 'registered',
#     'accept_rate': 91,
#     'profile_image': 'https://www.gravatar.com/avatar/f8af9d177a327eaf22be1651863a103a?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'user1315789',
#     'link': 'https://stackoverflow.com/users/7518091/user1315789'},
#    'is_answered': True,
#    'view_count': 240225,
#    'accepted_answer_id': 65333085,
#    'answer_count': 8,
#    'score': 138,
#    'last_activity_date': 1700233427,
#    'creation_date': 1607990716,
#    'last_edit_date': 1700233279,
#    'question_id': 65298241,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65298241/what-does-this-tensorflow-message-mean-any-side-effect-was-the-installation-su',
#    'title': 'What does this tensorflow message mean? Any side effect? Was the installation successful?'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 12235881,
#     'reputation': 2106,
#     'user_id': 8930321,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/0bc45c7114227787d7f27ce17f523a36?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'lowercase00',
#     'link': 'https://stackoverflow.com/users/8930321/lowercase00'},
#    'is_answered': True,
#    'view_count': 524239,
#    'protected_date': 1587068882,
#    'answer_count': 18,
#    'score': 137,
#    'last_activity_date': 1677439515,
#    'creation_date': 1580436978,
#    'last_edit_date': 1614469552,
#    'question_id': 59997065,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59997065/pip-python-normal-site-packages-is-not-writeable',
#    'title': 'pip/python: normal site-packages is not writeable'},
#   {'tags': ['python', 'python-3.x', 'download', 'youtube', 'youtube-dl'],
#    'owner': {'account_id': 18939012,
#     'reputation': 1457,
#     'user_id': 13819476,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8bbd0a28d4d0e1ce6ba2a58b63aae260?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Bastien',
#     'link': 'https://stackoverflow.com/users/13819476/bastien'},
#    'is_answered': True,
#    'view_count': 177400,
#    'protected_date': 1609065407,
#    'accepted_answer_id': 65230976,
#    'answer_count': 10,
#    'score': 131,
#    'last_activity_date': 1682517250,
#    'creation_date': 1599673099,
#    'last_edit_date': 1619130962,
#    'question_id': 63816790,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/63816790/youtube-dl-error-youtube-said-unable-to-extract-video-data',
#    'title': 'Youtube_dl : ERROR : YouTube said: Unable to extract video data'},
#   {'tags': ['python', 'flask', 'pytest', 'werkzeug'],
#    'owner': {'account_id': 20745029,
#     'reputation': 1841,
#     'user_id': 15233792,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/2ol6b.jpg?s=256&g=1',
#     'display_name': 'stevezkw',
#     'link': 'https://stackoverflow.com/users/15233792/stevezkw'},
#    'is_answered': True,
#    'view_count': 89286,
#    'protected_date': 1698079880,
#    'accepted_answer_id': 77214086,
#    'answer_count': 6,
#    'score': 131,
#    'last_activity_date': 1702711441,
#    'creation_date': 1696215720,
#    'last_edit_date': 1700174126,
#    'question_id': 77213053,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/77213053/why-did-flask-start-failing-with-importerror-cannot-import-name-url-quote-fr',
#    'title': 'Why did Flask start failing with &quot;ImportError: cannot import name &#39;url_quote&#39; from &#39;werkzeug.urls&#39;&quot;?'},
#   {'tags': ['python',
#     'django',
#     'importerror',
#     'python-module',
#     'circular-dependency'],
#    'owner': {'account_id': 9473820,
#     'reputation': 1265,
#     'user_id': 7043835,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4203ed009a7d8e7636fcfe3c0e03ae22?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': '3WZ',
#     'link': 'https://stackoverflow.com/users/7043835/3wz'},
#    'is_answered': True,
#    'view_count': 404944,
#    'protected_date': 1623706069,
#    'accepted_answer_id': 64809784,
#    'answer_count': 17,
#    'score': 126,
#    'last_activity_date': 1705676873,
#    'creation_date': 1605196086,
#    'last_edit_date': 1705676873,
#    'question_id': 64807163,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64807163/importerror-cannot-import-name-from-partially-initialized-module-m',
#    'title': 'ImportError: cannot import name &#39;...&#39; from partially initialized module &#39;...&#39; (most likely due to a circular import)'},
#   {'tags': ['python', 'python-3.x', 'pathlib'],
#    'owner': {'account_id': 16410122,
#     'reputation': 1963,
#     'user_id': 11853632,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/12a934b35c313adcbf98aaf10aed69f1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'reinhardt',
#     'link': 'https://stackoverflow.com/users/11853632/reinhardt'},
#    'is_answered': True,
#    'view_count': 99456,
#    'accepted_answer_id': 61321618,
#    'answer_count': 6,
#    'score': 126,
#    'last_activity_date': 1703241024,
#    'creation_date': 1587382490,
#    'question_id': 61321503,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61321503/is-there-a-pathlib-alternate-for-os-path-join',
#    'title': 'Is there a Pathlib alternate for os.path.join?'},
#   {'tags': ['python', 'pylint'],
#    'owner': {'account_id': 15406446,
#     'reputation': 1459,
#     'user_id': 12160503,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2048851171863469/picture?type=large',
#     'display_name': 'Isaac Anatolio',
#     'link': 'https://stackoverflow.com/users/12160503/isaac-anatolio'},
#    'is_answered': True,
#    'view_count': 203785,
#    'closed_date': 1665543271,
#    'answer_count': 8,
#    'score': 125,
#    'last_activity_date': 1628071953,
#    'creation_date': 1583716399,
#    'last_edit_date': 1616202315,
#    'question_id': 60593604,
#    'link': 'https://stackoverflow.com/questions/60593604/importerror-attempted-relative-import-with-no-known-parent-package',
#    'closed_reason': 'Duplicate',
#    'title': 'ImportError : Attempted relative import with no known parent package'},
#   {'tags': ['python',
#     'machine-learning',
#     'scikit-learn',
#     'logistic-regression'],
#    'owner': {'account_id': 1130688,
#     'reputation': 1873,
#     'user_id': 7373787,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/6df86729130c9a20a2df0e2aeefd7443?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'sums22',
#     'link': 'https://stackoverflow.com/users/7373787/sums22'},
#    'is_answered': True,
#    'view_count': 246748,
#    'protected_date': 1618936399,
#    'accepted_answer_id': 62659927,
#    'answer_count': 4,
#    'score': 120,
#    'last_activity_date': 1673518122,
#    'creation_date': 1593522500,
#    'last_edit_date': 1618913680,
#    'question_id': 62658215,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62658215/convergencewarning-lbfgs-failed-to-converge-status-1-stop-total-no-of-iter',
#    'title': 'ConvergenceWarning: lbfgs failed to converge (status=1): STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'},
#   {'tags': ['python', 'python-3.x', 'linux', 'pip'],
#    'owner': {'account_id': 22984508,
#     'reputation': 1201,
#     'user_id': 17110906,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4d835ba2d974f7b6e2c5844a29641106?s=256&d=identicon&r=PG',
#     'display_name': 'Christopher Coco',
#     'link': 'https://stackoverflow.com/users/17110906/christopher-coco'},
#    'is_answered': True,
#    'view_count': 150266,
#    'answer_count': 12,
#    'score': 119,
#    'last_activity_date': 1704987252,
#    'creation_date': 1633747154,
#    'last_edit_date': 1633747387,
#    'question_id': 69503329,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69503329/pip-is-not-working-for-python-3-10-on-ubuntu',
#    'title': 'Pip is not working for Python 3.10 on Ubuntu'},
#   {'tags': ['python',
#     'docker',
#     'docker-compose',
#     'dependencies',
#     'importerror'],
#    'owner': {'account_id': 3369545,
#     'reputation': 3213,
#     'user_id': 2829150,
#     'user_type': 'registered',
#     'accept_rate': 51,
#     'profile_image': 'https://www.gravatar.com/avatar/1e9c788890b3d2a8e468ed2773864b2c?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Arie',
#     'link': 'https://stackoverflow.com/users/2829150/arie'},
#    'is_answered': True,
#    'view_count': 161202,
#    'protected_date': 1691442712,
#    'answer_count': 15,
#    'score': 119,
#    'last_activity_date': 1699634829,
#    'creation_date': 1652208276,
#    'last_edit_date': 1667754370,
#    'question_id': 72191560,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72191560/importerror-cannot-import-name-soft-unicode-from-markupsafe',
#    'title': 'ImportError: cannot import name &#39;soft_unicode&#39; from &#39;markupsafe&#39;'},
#   {'tags': ['python', 'pandas', 'dataframe'],
#    'owner': {'account_id': 15702272,
#     'reputation': 1281,
#     'user_id': 11330069,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-V1jQ5QLfKI8/AAAAAAAAAAI/AAAAAAAAABY/j4kK5yAK4Ak/photo.jpg?sz=256',
#     'display_name': 'Diarmid Roberts',
#     'link': 'https://stackoverflow.com/users/11330069/diarmid-roberts'},
#    'is_answered': True,
#    'view_count': 163357,
#    'answer_count': 16,
#    'score': 118,
#    'last_activity_date': 1685493073,
#    'creation_date': 1580405248,
#    'last_edit_date': 1614713321,
#    'question_id': 59991397,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59991397/attributeerror-dataframe-object-has-no-attribute-ix',
#    'title': 'AttributeError: &#39;DataFrame&#39; object has no attribute &#39;ix&#39;'},
#   {'tags': ['python',
#     'selenium',
#     'google-chrome',
#     'selenium-webdriver',
#     'selenium-chromedriver'],
#    'owner': {'account_id': 19488994,
#     'reputation': 1173,
#     'user_id': 14257612,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c49440f3d6f3831211bcb56d9614a61e?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Alesss',
#     'link': 'https://stackoverflow.com/users/14257612/alesss'},
#    'is_answered': True,
#    'view_count': 263850,
#    'accepted_answer_id': 72773269,
#    'answer_count': 4,
#    'score': 117,
#    'last_activity_date': 1700498304,
#    'creation_date': 1656337711,
#    'last_edit_date': 1661689426,
#    'question_id': 72773206,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72773206/selenium-python-attributeerror-webdriver-object-has-no-attribute-find-el',
#    'title': 'Selenium - Python - AttributeError: &#39;WebDriver&#39; object has no attribute &#39;find_element_by_name&#39;'},
#   {'tags': ['python', 'numpy'],
#    'owner': {'account_id': 8369136,
#     'reputation': 3552,
#     'user_id': 6284785,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/9d2ef82797b12ebbeebbf008f9524f50?s=256&d=identicon&r=PG',
#     'display_name': 'Anatoly',
#     'link': 'https://stackoverflow.com/users/6284785/anatoly'},
#    'is_answered': True,
#    'view_count': 234686,
#    'answer_count': 22,
#    'score': 116,
#    'last_activity_date': 1695172833,
#    'creation_date': 1614021415,
#    'last_edit_date': 1614030641,
#    'question_id': 66322049,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66322049/could-not-install-packages-due-to-an-oserror-winerror-2-no-such-file-or-direc',
#    'title': 'Could not install packages due to an OSError: [WinError 2] No such file or directory'},
#   {'tags': ['python', 'prompt', 'openai-api', 'completion', 'chatgpt-api'],
#    'owner': {'account_id': 3235065,
#     'reputation': 1960,
#     'user_id': 3018860,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/edec84abcde58e8f5d45a7e5522ff1e1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Unix',
#     'link': 'https://stackoverflow.com/users/3018860/unix'},
#    'is_answered': True,
#    'view_count': 243334,
#    'closed_date': 1685124780,
#    'accepted_answer_id': 75898717,
#    'answer_count': 5,
#    'score': 115,
#    'last_activity_date': 1704422130,
#    'creation_date': 1680263884,
#    'last_edit_date': 1704294387,
#    'question_id': 75898276,
#    'link': 'https://stackoverflow.com/questions/75898276/openai-api-error-429-you-exceeded-your-current-quota-please-check-your-plan-a',
#    'closed_reason': 'Not suitable for this site',
#    'title': 'OpenAI API error 429: &quot;You exceeded your current quota, please check your plan and billing details&quot;'},
#   {'tags': ['python', 'openai-api', 'urllib3'],
#    'owner': {'account_id': 11229285,
#     'reputation': 1243,
#     'user_id': 8237910,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-OajeBMxDGMo/AAAAAAAAAAI/AAAAAAAAAmQ/8vm8L0FQK1c/photo.jpg?sz=256',
#     'display_name': 'prismwatermelon',
#     'link': 'https://stackoverflow.com/users/8237910/prismwatermelon'},
#    'is_answered': True,
#    'view_count': 230450,
#    'accepted_answer_id': 76187415,
#    'answer_count': 15,
#    'score': 114,
#    'last_activity_date': 1704842074,
#    'creation_date': 1683349902,
#    'last_edit_date': 1691972425,
#    'question_id': 76187256,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76187256/importerror-urllib3-v2-0-only-supports-openssl-1-1-1-currently-the-ssl-modu',
#    'title': 'ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the &#39;ssl&#39; module is compiled with LibreSSL 2.8.3'},
#   {'tags': ['python', 'python-3.9'],
#    'owner': {'account_id': 4650123,
#     'reputation': 34807,
#     'user_id': 3767239,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://www.gravatar.com/avatar/4d6c9d978220f4ac99f6a1237288a99c?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'a_guest',
#     'link': 'https://stackoverflow.com/users/3767239/a-guest'},
#    'is_answered': True,
#    'view_count': 11334,
#    'answer_count': 3,
#    'score': 114,
#    'last_activity_date': 1612271090,
#    'creation_date': 1611094722,
#    'last_edit_date': 1611234002,
#    'question_id': 65800344,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65800344/what-are-soft-keywords',
#    'title': 'What are &quot;soft keywords&quot;?'},
#   {'tags': ['python', 'virtualenv'],
#    'owner': {'account_id': 15854936,
#     'reputation': 1271,
#     'user_id': 11439612,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/bBSil.jpg?s=256&g=1',
#     'display_name': 'Tung Ng.',
#     'link': 'https://stackoverflow.com/users/11439612/tung-ng'},
#    'is_answered': True,
#    'view_count': 99641,
#    'accepted_answer_id': 63491349,
#    'answer_count': 15,
#    'score': 113,
#    'last_activity_date': 1694164402,
#    'creation_date': 1597854368,
#    'last_edit_date': 1676018186,
#    'question_id': 63491221,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/63491221/modulenotfounderror-no-module-named-virtualenv-seed-embed-via-app-data-when-i',
#    'title': 'ModuleNotFoundError: No module named &#39;virtualenv.seed.embed.via_app_data&#39; when I created new env by virtualenv'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 69666,
#     'reputation': 6305,
#     'user_id': 202576,
#     'user_type': 'registered',
#     'accept_rate': 47,
#     'profile_image': 'https://www.gravatar.com/avatar/bdf45a8317ff3471cdcc7ba2f18c79a1?s=256&d=identicon&r=PG',
#     'display_name': 'onknows',
#     'link': 'https://stackoverflow.com/users/202576/onknows'},
#    'is_answered': True,
#    'view_count': 152553,
#    'protected_date': 1618889077,
#    'answer_count': 12,
#    'score': 113,
#    'last_activity_date': 1674357448,
#    'creation_date': 1611639213,
#    'last_edit_date': 1674357448,
#    'question_id': 65896334,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65896334/upgrading-pip-fails-with-syntax-error-caused-by-sys-stderr-writeferror-exc',
#    'title': 'Upgrading pip fails with syntax error caused by sys.stderr.write(f&quot;ERROR: {exc}&quot;)'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 278}

# %% [markdown]
# ## 8 Filtrage et affichage : le dataframe obtenu

# %%
# Plus qu'à filtrer / créer le dataframe

def extract_fields_and_create_dataframe(data):
    questions = data.get('items', [])

    # Extracting desired fields
    extracted_data = [
        {
            'creation_date': question.get('creation_date', None),
            'title': question.get('title', None),
            'tags': question.get('tags', None),
            'score': question.get('score', None),
        }
        for question in questions
    ]

    # Creating DataFrame
    df = pd.DataFrame(extracted_data)

    return df


df = extract_fields_and_create_dataframe(result)

print(df.shape)
display(df)
# Out:
# (50, 4)
#     creation_date                                              title  \
# 0      1595181079                   What is pyproject.toml file for?
# 1      1607702016  xlrd.biffh.XLRDError: Excel xlsx file; not sup...
# 2      1580572695              What does model.eval() do in pytorch?
# 3      1606035195  docker.errors.DockerException: Error while fet...
# 4      1612516308  ValueError: numpy.ndarray size changed, may in...
# 5      1593658606  sqlalchemy.exc.NoSuchModuleError: Can&#39;t lo...
# 6      1608242137  Python was not found; run without arguments to...
# 7      1677700339  How do I solve &quot;error: externally-managed...
# 8      1648058522  How can I fix the &quot;zsh: command not found...
# 9      1604676159  DeprecationWarning: executable_path has been d...
# 10     1587560390  ERROR: Could not build wheels for scipy which ...
# 11     1653965255  TypeError: Descriptors cannot not be created d...
# 12     1582109114           How to reinstall python@2 from Homebrew?
# 13     1680851159  Error &quot;&#39;DataFrame&#39; object has no ...
# 14     1648626375  ImportError: cannot import name &#39;_unicodef...
# 15     1606986952       Resolving new pip backtracking runtime issue
# 16     1639262655  ImportError: cannot import name &#39;url&#39; ...
# 17     1617722621  Auto-create primary key used when not defining...
# 18     1624808189  Understand Python swapping: why is a, b = b, a...
# 19     1607684916           Pandas cannot open an Excel (.xlsx) file
# 20     1602156410  How to solve &quot;error: Microsoft Visual C++...
# 21     1579523213  Could not load dynamic library &#39;cudart64_1...
# 22     1593001526           How do I install python on alpine linux?
# 23     1594067909  How to import requirements.txt from an existin...
# 24     1594683418  pip freeze creates some weird path instead of ...
# 25     1579796188  VSCode doesn&#39;t show poetry virtualenvs in ...
# 26     1643123383          Does it make sense to use Conda + Poetry?
# 27     1643042804  Good alternative to Pandas .append() method, n...
# 28     1583425357                  What causes [*a] to overallocate?
# 29     1584987372  FastAPI throws an error (Error loading ASGI ap...
# 30     1663949925  AttributeError: module &#39;lib&#39; has no at...
# 31     1604360224  How do you fix &quot;runtimeError: package fai...
# 32     1607990716  What does this tensorflow message mean? Any si...
# 33     1580436978  pip/python: normal site-packages is not writeable
# 34     1599673099  Youtube_dl : ERROR : YouTube said: Unable to e...
# 35     1696215720  Why did Flask start failing with &quot;ImportE...
# 36     1605196086  ImportError: cannot import name &#39;...&#39; ...
# 37     1587382490     Is there a Pathlib alternate for os.path.join?
# 38     1583716399  ImportError : Attempted relative import with n...
# 39     1593522500  ConvergenceWarning: lbfgs failed to converge (...
# 40     1633747154       Pip is not working for Python 3.10 on Ubuntu
# 41     1652208276  ImportError: cannot import name &#39;soft_unic...
# 42     1580405248  AttributeError: &#39;DataFrame&#39; object has...
# 43     1656337711  Selenium - Python - AttributeError: &#39;WebDr...
# 44     1614021415  Could not install packages due to an OSError: ...
# 45     1680263884  OpenAI API error 429: &quot;You exceeded your ...
# 46     1683349902  ImportError: urllib3 v2.0 only supports OpenSS...
# 47     1611094722                What are &quot;soft keywords&quot;?
# 48     1597854368  ModuleNotFoundError: No module named &#39;virt...
# 49     1611639213  Upgrading pip fails with syntax error caused b...
#
#                                                  tags  score
# 0            [python, pip, packaging, pyproject.toml]    351
# 1                         [python, pandas, xlrd, pcf]    289
# 2   [python, machine-learning, deep-learning, pyto...    264
# 3             [python, linux, docker, docker-compose]    227
# 4   [python, pandas, numpy, scikit-learn, python-3.7]    227
# 5   [python, postgresql, sqlalchemy, flask-sqlalch...    226
# 6                    [python, python-3.x, windows-10]    208
# 7                       [python, error-handling, pip]    206
# 8   [python, macos, terminal, atom-editor, macos-m...    205
# 9                                  [python, selenium]    201
# 10  [python, scipy, pip, embedded-linux, python-wh...    201
# 11                          [python, tensorflow, ray]    198
# 12              [python, macos, homebrew, python-2.x]    195
# 13        [python, pandas, dataframe, attributeerror]    184
# 14                             [python, python-black]    178
# 15                                      [python, pip]    177
# 16          [python, django, django-urls, django-4.0]    174
# 17                       [python, python-3.x, django]    172
# 18                     [python, list, indexing, swap]    172
# 19                            [python, excel, pandas]    171
# 20                          [python, visual-c++, pip]    164
# 21  [python, python-3.x, tensorflow, keras, tensor...    160
# 22                      [python, linux, alpine-linux]    158
# 23                       [python, pip, python-poetry]    154
# 24              [python, path, pip, requirements.txt]    154
# 25        [python, visual-studio-code, python-poetry]    153
# 26  [python, machine-learning, package, conda, pyt...    153
# 27  [python, pandas, dataframe, data-wrangling, da...    152
# 28  [python, python-3.x, list, cpython, python-int...    149
# 29                         [python, fastapi, uvicorn]    142
# 30                     [python, google-analytics-api]    140
# 31               [python, python-3.x, windows, numpy]    140
# 32                     [python, tensorflow, anaconda]    138
# 33                                      [python, pip]    137
# 34  [python, python-3.x, download, youtube, youtub...    131
# 35                  [python, flask, pytest, werkzeug]    131
# 36  [python, django, importerror, python-module, c...    126
# 37                      [python, python-3.x, pathlib]    126
# 38                                   [python, pylint]    125
# 39  [python, machine-learning, scikit-learn, logis...    120
# 40                   [python, python-3.x, linux, pip]    119
# 41  [python, docker, docker-compose, dependencies,...    119
# 42                        [python, pandas, dataframe]    118
# 43  [python, selenium, google-chrome, selenium-web...    117
# 44                                    [python, numpy]    116
# 45  [python, prompt, openai-api, completion, chatg...    115
# 46                      [python, openai-api, urllib3]    114
# 47                               [python, python-3.9]    114
# 48                               [python, virtualenv]    113
# 49                                      [python, pip]    113

# %% [markdown]
# ## 9 Requete sur le site fr

# %%
# test fr, sans tag

def get_questions_fr(start_date, end_date, min_score=50, pagesize=50,
                  api_url='https://api.stackexchange.com/2.3/questions',
                  site = 'french'):
    """
    Get questions from Stack Exchange API based on specified criteria.

    Parameters:
    - start_date (datetime): The start date for the query.
    - end_date (datetime): The end date for the query.
    - min_score (int): Minimum score for the questions (default: 50).
    - page_size (int): Number of questions per page (default API: 30, max: 100. We want 50).

    Returns:
    - questions formatted as JSON object
    """
    api_url = api_url

    params = {
        'order': 'desc',
        'sort': 'votes',
        'site': site,
        'fromdate': int(start_date.timestamp()),
        'todate': int(end_date.timestamp()),
        'min': min_score,
        'pagesize': pagesize  # 30 par défaut, 100 max, 50 ici
    }

    try:
        response = requests.get(api_url, params=params)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        data = response.json()
        return data

    except requests.RequestException as e:
        print(f"Error during API request: {e}")
        return 0


#
start_date = datetime.datetime(2010, 1, 1)
end_date = datetime.datetime(2023, 12, 31)

result_fr = get_questions_fr(start_date=start_date, end_date=end_date,
                       min_score=0, pagesize=50, site='french')

df_fr = extract_fields_and_create_dataframe(result_fr)

print(df_fr.shape)
display(df_fr)

# interesting :)
# par contre le Stack Exchange Data Explorer (SEDE) ne permet pas de filtrer par site,
# donc impossible de recuperer 50 000 questions d'un coup.

# autres strats possibles si on veut entrainer un modele fr :
# - apres authentification, on pourrait le faire par requetes automatiques avec l'api, en 2 jours environ
# (nb requetes limite 300 par j + limite / minute. il faut y aller doucement)
# - trouver une autre sources de questions + tags en fr
# Out:
# (50, 4)
#     creation_date                                              title  \
# 0      1313616378  Pourquoi place-t-on une espace avant les ponct...
# 1      1313611862  If &quot;Je t&#39;aime&quot; means &quot;I lov...
# 2      1313665489                         Pourquoi trente-six&#160;?
# 3      1313618007  Accentuation des majuscules — Accents on upper...
# 4      1313740740   When does one pronounce the &#39;s&#39; in plus?
# 5      1314356872  How to translate “By the way”? — Comment tradu...
# 6      1487234147  What languages are perceived as classy or fanc...
# 7      1531154732  Where did French&#39;s silent ending consonant...
# 8      1313819407  Quand peut-on mettre un adjectif avant ou apr&...
# 9      1358529089  Why are O and E sometimes attached together, a...
# 10     1314882414  Differences between “Oui” and “Si” in the affi...
# 11     1342204738      Ways of saying “you&#39;re welcome” in French
# 12     1314977178  Why does French use a &quot;split negative&quot;?
# 13     1343093685     Comment traduire &#171; what the fuck &#187; ?
# 14     1313658782  J&#39;ai bien peur que tu n&#39;aies raison&#1...
# 15     1313667434  What movies or TV series can I use to improve ...
# 16     1315323198  D&#39;o&#249; viennent soixante-dix et quatre-...
# 17     1316623414  Comment traduire &#171;&#160;upload&#160;&#187...
# 18     1340144019      Hibou vs chouette? What&#39;s the difference?
# 19     1512034375  Do native speakers of French generally use &qu...
# 20     1313680264  Quelles parties du monde francophone continuen...
# 21     1313670126  Quand faut-il mettre un pluriel apr&#232;s un ...
# 22     1342780163                  “Bonsoir” or “Bonne soir&#233;e”?
# 23     1313612484  Diff&#233;rence entre le pass&#233; simple et ...
# 24     1314132966  How to know when to use &quot;bon&quot; or &qu...
# 25     1314280078  How did &quot;coucou&quot; (with its original ...
# 26     1315448141             “L’on y danse”: why the article “l’ ”?
# 27     1437585177  The difference between &quot;num&#233;ro&quot;...
# 28     1661355781  Why does everyone in The Lord of the Rings use...
# 29     1313618809  &#171;&#160;On&#160;&#187; remplace &#171;&#16...
# 30     1531653285  What does &quot;j&#39;ai tennis&quot; idiom mean?
# 31     1313613810  &#171; Autant pour moi &#187; ou &#171; Au tem...
# 32     1313688940  How do you decide whether to use &quot;vous&qu...
# 33     1326285505  Quelle est la diff&#233;rence entre &#171;car&...
# 34     1338490062  &quot;Pas encore&quot; — is it correct to have...
# 35     1313613373  &#171;&#160;Avant que&#160;&#187; et &#171;&#1...
# 36     1313618303  Quelle est la diff&#233;rence entre les pronom...
# 37     1320265469             Usage of “d&#39;eau” vs “de l&#39;eau”
# 38     1340033628  Pourquoi huit ou quinze jours pour une ou deux...
# 39     1363856847  Que r&#233;pondre &#224; un merci m&#233;rit&#...
# 40     1334792882       Comment traduire &#171; boilerplate &#187; ?
# 41     1368606495  Quand dire &#171; Bonjour &#187; et quand dire...
# 42     1387360132  Pourquoi certains &#171; e &#187; se prononcen...
# 43     1517244957  Should I use Bonjour or Salut to a clerk in Fr...
# 44     1313616206  When to use &quot;conna&#238;tre&quot; and whe...
# 45     1313828503  Comment d&#233;cide-t-on du genre des n&#233;o...
# 46     1314223221  Are there good tools for learning to speak Fre...
# 47     1314608874  Comment traduire l&#39;expression anglaise &#1...
# 48     1314703301  Quelle formule de politesse doit-on utiliser &...
# 49     1314763303  How would you translate &#39;placeholder&#39; ...
#
#                                                  tags  score
# 0                [histoire, typographie, ponctuation]    105
# 1                                             [usage]     87
# 2           [expressions, nombres, origine-ou-raison]     83
# 3   [orthographe, typographie, diacritiques, majus...     73
# 4         [prononciation, n&#233;gation, comparatifs]     73
# 5            [traduction, anglais, expressions, oral]     59
# 6   [histoire, comparaison-de-langues, emprunts, r...     59
# 7   [prononciation, &#233;tymologie, histoire, ori...     51
# 8              [grammaire, adjectifs, ordre-des-mots]     49
# 9                  [orthographe, alphabet, ligatures]     47
# 10           [choix-de-mot, n&#233;gation, questions]     46
# 11                                        [politesse]     46
# 12               [grammaire, histoire, n&#233;gation]     45
# 13  [traduction, anglais, expressions, registre-fa...     45
# 14  [grammaire, n&#233;gation, adverbes, ne-expl&#...     44
# 15  [ressources, apprentissage, t&#233;l&#233;visi...     44
# 16                                [histoire, nombres]     44
# 17        [traduction, anglais, informatique, jargon]     43
# 18                            [vocabulaire, zoologie]     43
# 19                              [grammaire, partitif]     43
# 20               [usage, nombres, r&#233;gionalismes]     42
# 21                  [expressions, grammaire, pluriel]     40
# 22           [sens, usage, choix-de-mot, salutations]     40
# 23  [grammaire, temps-grammatical, pass&#233;-comp...     39
# 24                [choix-de-mot, adjectifs, adverbes]     35
# 25       [usage, &#233;tymologie, argot, salutations]     35
# 26                      [pronoms, articles, euphonie]     35
# 27               [vocabulaire, anglais, choix-de-mot]     34
# 28  [traduction, pronoms, litt&#233;rature, regist...     34
# 29      [pronoms, linguistique, &#233;volution, oral]     33
# 30                 [expressions-idiomatiques, humour]     33
# 31  [expressions, sens, choix-de-mot, expressions-...     32
# 32      [usage, choix-de-mot, politesse, vouvoiement]     32
# 33                    [grammaire, sens, conjonctions]     32
# 34                          [prononciation, liaisons]     32
# 35  [grammaire, conjonctions, subjonctif, mode-gra...     31
# 36                        [grammaire, pronoms, en, y]     31
# 37  [grammaire, pr&#233;positions, articles, parti...     31
# 38  [expressions, &#233;tymologie, indications-de-...     31
# 39                    [usage, vocabulaire, politesse]     31
# 40   [traduction, vocabulaire, anglais, informatique]     30
# 41                 [usage, choix-de-mot, salutations]     30
# 42  [prononciation, histoire, voyelles, nasalisation]     30
# 43                           [politesse, salutations]     30
# 44                      [choix-de-mot, rule-of-thumb]     29
# 45                    [genre, n&#233;ologismes, noms]     29
# 46                        [ressources, apprentissage]     29
# 47                 [traduction, anglais, expressions]     29
# 48           [politesse, salutations, correspondance]     29
# 49                              [traduction, anglais]     29

# %% [markdown]
# ## Conclusion

# %%
# Mon retour sur l'utilisation de l'API :

# La doc est très claire, elle va à l'essentiel dès le début et elle est courte et très bien structurée :
# Il y a très vite la liste des méthodes/endpoints, et des exemples de requetes un peu complexes
# pour comprendre et tester la syntaxe.

# Je ne l'ai pas assez manipulée pour pouvoir vraiment proposer des améliorations.
# Peut-être créer un filtre spécifique aux RGPD, et simplifier l'accès aux filtres publics ?

# %% [markdown]
# ## Annexes : StackExchange Data Explorer

# %%
# La page d'accueil du "StackExchange Data Explorer" (l'outil d’export de données)
# présente la structure de la table, avec le type de chaque colonne, et un lien vers la doc :
# https://meta.stackexchange.com/questions/2677/database-schema-documentation-for-the-public-data-dump-and-sede

# Table : posts
# "You find in Posts all non-deleted posts."

# La requete donnee en exemple est un tres bon pt de depart.
# Tags1 - question tags (PostTypeId = 1)
# AnswerCount - the number of undeleted answers (only present if PostTypeId = 1)
# FavoriteCount (nullable)

# On peut aussi y ajouter :

# extraire des questions relativement recentes : par exemple, parce que de nouveaux tags on pu apparaitre,
# qui seraient sous-estimes autrement.
# CreationDate > ...


# autres pistes possibles, mais pas tres utiles je pense :

# CommentCount (nullable) : semble redondant puisqu'on a deja AnswerCount et FavoriteCount
# de + sur stack il y a generalemt bcp - de commentaires que de reponses
# ClosedDate1 (present only if the post is closed) :  pas sur que cela nous importe directement
# CommunityOwnedDate (present only if post is community wiki'd) donc pas pour les questions
# ContentLicense1 pas pertinent pour nous.

# %% [markdown]
# ## Requete SQL

# %%
# la requete proposee en exemple

# SELECT TOP 50000 Title, Body, Tags, Id, Score, ViewCount, FavoriteCount, AnswerCount
# FROM Posts
# WHERE PostTypeId = 1 AND ViewCount > 10 AND FavoriteCount > 10
# AND Score > 5 AND AnswerCount > 0 AND LEN(Tags) - LEN(REPLACE(Tags, '<','')) >= 5

# donne 1 seule reponse ! Baissons le favoriteCount

# SELECT TOP 50000 Title, Body, Tags, Id, Score, ViewCount, FavoriteCount, AnswerCount
# FROM Posts
# WHERE PostTypeId = 1 AND ViewCount > 10 AND FavoriteCount > 5
# AND Score > 5 AND AnswerCount > 0 AND LEN(Tags) - LEN(REPLACE(Tags, '<','')) >= 5

# Ok, seules 6 lignes ont un FavoriteCount > 1
# (136 lignes > 0)

# SELECT TOP 50000 Title, Body, Tags, Score, ViewCount, FavoriteCount, AnswerCount
# FROM Posts
# WHERE PostTypeId = 1 AND ViewCount > 10
# AND Score > 5 AND AnswerCount > 0 AND LEN(Tags) - LEN(REPLACE(Tags, '<','')) >= 5

# fournit bien 50 000 lignes en reponse.

# est-ce qu on a vraimt besoin d'extraire les counts ?
# pourquoi pas juste Title, Body, Tags ?
# Pas besoin de GROUP BY ou d'ORDER BY ici.

# On peut choisir d'extraire, parmi nos questions qui remplissent nos criteres,
# les plus recentes. Notre requete devient :

# SELECT TOP 50000 Title, Body, Tags, Id, Score, ViewCount, FavoriteCount, AnswerCount, CreationDate
# FROM Posts
# WHERE PostTypeId = 1 AND ViewCount > 10000 AND Score > 10 AND AnswerCount > 1
# AND LEN(Tags) - LEN(REPLACE(Tags, '<','')) >= 5
# ORDER BY CreationDate DESC;
