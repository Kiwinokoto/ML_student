# %% [markdown]
# ## **Catégorisez automatiquement des questions**
#
# ### partie 4/8 : Prédiction de tags, approche supervisée + tracking mlflow
#
# #### <br> Notebook d’exploration et de pré-traitement des questions, comprenant une analyse univariée et multivariée, un nettoyage des questions, un feature engineering de type bag of words avec réduction de dimension (du vocabulaire et des tags)
#
# <br>

# %% [markdown]
# ## 1 Import

# %% [markdown]
# ### 1.1 Librairies

# %%
# finir d'organiser, check inutiles ?

#
import os, sys, random
import ast
import numpy as np
import pandas as pd
from typing import Tuple
from pandarallel import pandarallel
from pprint import pprint
from collections import Counter

# Visualisation
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image

# NLP
from bs4 import BeautifulSoup
import re, string
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# gensim
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.matutils import corpus2dense
from gensim.matutils import Sparse2Corpus
from gensim.models import LdaModel, CoherenceModel
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from gensim import similarities
from gensim.models.ldamulticore import LdaMulticore

# sklearn
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.metrics import make_scorer, PredictionErrorDisplay, r2_score
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier


print('\nPython version ' + sys.version)
print('pyLDAvis version ' + pyLDAvis.__version__)

# Modify if necessary
num_cores = os.cpu_count()
print(f"\nNumber of CPU cores: {num_cores}")
pandarallel.initialize(progress_bar=False, nb_workers=6)

#
import mlflow
from mlflow import MlflowClient
from mlflow.models.signature import infer_signature, ModelSignature #, Schema, ParamSchema
from mlflow.types import Schema, ParamSchema, ParamSpec, ColSpec

# os.environ['MLFLOW_TRACKING_URI'] = './'

# ! REQUIRES CONSOLE COMMAND : mlflow ui
# depuis dossier notebooks

# Utilisable seulement en local...
mlflow.set_tracking_uri("http://localhost:5000")
client = MlflowClient(tracking_uri="http://127.0.0.1:5000")
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/ubuntu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ubuntu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ubuntu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Python version 3.11.5 (main, Sep 11 2023, 13:23:44) [GCC 11.2.0]
# pyLDAvis version 3.4.0
#
# Number of CPU cores: 8
# INFO: Pandarallel will run on 6 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# ### 1.2 Functions

# %%
def get_missing_values(df):
    """Generates a DataFrame containing the count and proportion of missing values for each feature.

    Args:
        df (pandas.DataFrame): The input DataFrame to analyze.

    Returns:
        pandas.DataFrame: A DataFrame with columns for the feature name, count of missing values,
        count of non-missing values, proportion of missing values, and data type for each feature.
    """
    # Count the missing values for each column
    missing = df.isna().sum()

    # Calculate the percentage of missing values
    percent_missing = df.isna().mean() * 100

    # Create a DataFrame to store the results
    missings_df = pd.DataFrame({
        'column_name': df.columns,
        'missing': missing,
        'present': df.shape[0] - missing,  # Count of non-missing values
        'percent_missing': percent_missing.round(2),  # Rounded to 2 decimal places
        'type': df.dtypes
    })

    # Sort the DataFrame by the count of missing values
    missings_df.sort_values('missing', inplace=True)

    return missings_df

# with pd.option_context('display.max_rows', 1000):
#   display(get_missing_values(df))


def quick_look(df, miss=True):
    """
    Display a quick overview of a DataFrame, including shape, head, tail, unique values, and duplicates.

    Args:
        df (pandas.DataFrame): The input DataFrame to inspect.
        check_missing (bool, optional): Whether to check and display missing values (default is True).

    The function provides a summary of the DataFrame, including its shape, the first and last rows, the count of unique values per column, and the number of duplicates.
    If `check_missing` is set to True, it also displays missing value information.
    """
    print(f'shape : {df.shape}')

    display(df.head())
    display(df.tail())

    print('uniques :')
    display(df.nunique())

    print('Doublons ? ', df.duplicated(keep='first').sum(), '\n')

    if miss:
        display(get_missing_values(df))


def preprocess_text(text):
    #Cleaning
    text = BeautifulSoup(text, 'html.parser').get_text()
    text = text.lower().strip()

    # Tokenization
    try:
        tokens = nltk.word_tokenize(text)
        tokenizer = nltk.RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(" ".join(tokens))  # Apply RegexpTokenizer to the entire list

        # Remove punctuation (make sure, RegexpTokenizer should have done it already)
        tokens = [token for token in tokens if token not in string.punctuation]

    except Exception as e:
        print(f"Error in tokenization: {e}")
        return []

    # Lemmatization
    lemmatizer = WordNetLemmatizer()

    # Get part of speech for each token
    pos_tags = nltk.pos_tag(tokens)
    lemmatized_tokens = []

    for token, pos_tag in pos_tags:
        # ! Uncommenting next line may crash the cell
        # print(f"Token: {token}, POS Tag: {pos_tag}")
        if pos_tag.startswith('V'):
            # On garde
            lemmatized_tokens.append(lemmatizer.lemmatize(token, pos='v'))
            # Returns the input word unchanged if it cannot be found in WordNet.
        elif pos_tag.startswith('N'):
            # On garde
            try:
                lemmatized_tokens.append(lemmatizer.lemmatize(token, pos='n'))
            except Exception as e:
                print(f"Error lemmatizing verb {token}: {e}")
        # Sinon on supprime

    # Read forbidden words (stopwords, too frequent, too rare) from the file
    with open('./forbidden_words.txt', 'r') as file:
        forbidden = [line.strip() for line in file]

    filtered_list = [token for token in lemmatized_tokens if token not in forbidden]

    # keep uniques
    seen_tokens = set()
    unique_tokens = []

    for token in filtered_list:
        if token not in seen_tokens:
            seen_tokens.add(token)
            if len(token) > 2:
                unique_tokens.append(token)

    return unique_tokens

# %%
def create_mlflow_experiment(
    experiment_name: str, artifact_location: str, tags: dict[str, str]
) -> str:
    """
    Create a new mlflow experiment with the given name and artifact location.

    Parameters:
    ----------
    experiment_name: str
        The name of the experiment to create.
    artifact_location: str
        The artifact location of the experiment to create.
    tags: dict[str,Any]
        The tags of the experiment to create.

    Returns:
    -------
    experiment_id: str
        The id of the created experiment.
    """
    try:
        experiment_id = mlflow.create_experiment(
            name=experiment_name, artifact_location=artifact_location, tags=tags
        )
    except:
        print(f"Experiment {experiment_name} already exists.")
        experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id

    mlflow.set_experiment(experiment_name=experiment_name)

    return experiment_id


def get_mlflow_experiment(
    experiment_id: str = None, experiment_name: str = None
) -> mlflow.entities.Experiment:
    """
    Retrieve the mlflow experiment with the given id or name.

    Parameters:
    ----------
    experiment_id: str
        The id of the experiment to retrieve.
    experiment_name: str
        The name of the experiment to retrieve.

    Returns:
    -------
    experiment: mlflow.entities.Experiment
        The mlflow experiment with the given id or name.
    """
    if experiment_id is not None:
        experiment = mlflow.get_experiment(experiment_id)
    elif experiment_name is not None:
        experiment = mlflow.get_experiment_by_name(experiment_name)
    else:
        raise ValueError("Either experiment_id or experiment_name must be provided.")

    return experiment


def turn_str_back_into_list(df):
    """Correct the type change due to .csv export"""

    df['title_nltk'] = df['title_nltk'].apply(ast.literal_eval)
    df['body_nltk'] = df['body_nltk'].apply(ast.literal_eval)
    df['title_spacy'] = df['title_spacy'].apply(ast.literal_eval)
    df['body_spacy'] = df['body_spacy'].apply(ast.literal_eval)
    df['all_tags'] = df['all_tags'].apply(ast.literal_eval)

# %%
# Again, this needs mlfow ui console command first -> unusable on remote server
# all_experiments = client.search_experiments()
# pprint(all_experiments)

# %% [markdown]
# ### 1.3 Data

# %%
raw_data = pd.read_csv('./../0_data/cleaned_data/bow_classic.csv', sep=',')

turn_str_back_into_list(raw_data)

display(raw_data.tail())

print(raw_data.shape)
# Out:
#               CreationDate                                              title  \
# 47660  2011-05-23 22:22:56  How can I send a file document to the printer ...
# 47661  2011-05-23 21:15:51  CA1014 Mark 'some.dll' with CLSCompliant(true)...
# 47662  2011-05-23 21:05:59           How to change a text file's name in C++?
# 47663  2011-05-23 20:06:35                      php implode (101) with quotes
# 47664  2011-05-23 20:00:57    What characters are allowed in a iOS file name?
#
#                                                     body  \
# 47660  Here's the basic premise:\nMy user clicks some...
# 47661  When I run StyleCop, I got this error message ...
# 47662  I would like to change a txt file's name, but ...
# 47663  Imploding  a simple array \nwould look like th...
# 47664  I'm looking for a way to make sure a string ca...
#
#                                                 all_tags  \
# 47660            [c#, winforms, pdf, .net-4.0, printing]
# 47661  [visual-studio, visual-studio-2010, dll, style...
# 47662     [c++, algorithm, file, directory, file-rename]
# 47663                [php, arrays, string, csv, implode]
# 47664  [ios, file, filenames, character-encoding, nsf...
#
#                                    title_nltk  \
# 47660  [send, file, document, printer, print]
# 47661     [mark, dll, error, message, vs2010]
# 47662           [change, text, file, name, c]
# 47663                            [php, quote]
# 47664          [character, allow, file, name]
#
#                                                body_nltk  \
# 47660  [send, file, document, printer, print, premise...
# 47661  [mark, dll, error, message, vs2010, run, get, ...
# 47662  [change, text, file, name, c, like, change, tx...
# 47663  [php, quote, array, look, array, array, lastna...
# 47664  [character, allow, file, name, look, way, make...
#
#                                   title_spacy  \
# 47660  [send, file, document, printer, print]
# 47661                        [error, message]
# 47662                    [change, text, file]
# 47663                                 [quote]
# 47664                [character, allow, file]
#
#                                               body_spacy
# 47660  [premise, user, click, file, spit, desktop, wa...
# 47661  [run, error, message, need, mark, dll, set, dl...
# 47662  [like, change, txt, file, find, example, want,...
# 47663  [implode, array, look, array, email, phone, ar...
# 47664  [look, way, string, file, section, code, delet...
# (47665, 8)

# %%
# pour parcourir rapidement la premiere partie du ntbk
quick_df = raw_data[::10]

train_df, test_df = train_test_split(quick_df, test_size=0.1, random_state=42)

train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

print(train_df.shape)
print(test_df.shape)
# Out:
# (4290, 8)
# (477, 8)

# %% [markdown]
# ## 2 KNN

# %%
# Often gives good results if enough data
# fast
# Accepts basically any input, as long as it is numerical

# => Perfect for testing different embeddings !

# %% [markdown]
# ### 2.1 Dummy knn : il copie sur le + proche voisin

# %%
# Notre baseline

def predict_tags_using_dummy_knn(df, feature, target, k=1, exemple=None):
    documents = df[feature].tolist()
    gensim_dictionary = Dictionary(documents)
    corpus = [gensim_dictionary.doc2bow(doc) for doc in documents]

    # Convert Gensim corpus to dense matrix
    dense_matrix = corpus2dense(corpus, num_terms=len(gensim_dictionary)).T

    # Ici on ne va pas demander au knn de faire de prediction,
    # On veut juste qu'il trouve les voisins.
    # Mais la fonction fit a besoin de targets en param
    target_values = df[target].values

    # Initialize kNN model
    knn_model = KNeighborsRegressor(n_neighbors=k, metric='cosine', algorithm='brute')
    # print(knn_model.n_neighbors)

    knn_model.fit(dense_matrix, target_values)

    # Example query
    query_document = exemple
    query_bow = gensim_dictionary.doc2bow(query_document)
    query_vector = corpus2dense([query_bow], num_terms=len(gensim_dictionary)).T

    # Find nearest neighbors
    _, indices = knn_model.kneighbors(query_vector)

    # Aggregate tags from neighbors
    neighbor_tags = [tag for i in indices.flatten() for tag in df.iloc[i][target]]

    print(neighbor_tags)

    # Predict tags based on most common tags among neighbors
    predicted_tags = [tag for tag, _ in Counter(neighbor_tags).most_common(n=10)]
    # 5 tags/question en moyenne mais on peut suggérer +
    # ici a ameliorer

    return predicted_tags, knn_model


exemple = ["your", 'text', 'document', 'javascript']
# Call the function with your DataFrame and the desired text feature and target tags
predicted_tags, knn_test = predict_tags_using_dummy_knn(train_df, 'title_nltk', 'all_tags', exemple=exemple)
print(predicted_tags, '\n')

# javascript ok
# Out:
# ['c#', 'wpf', 'winforms', 'textbox', 'textchanged']
# ['c#', 'wpf', 'winforms', 'textbox', 'textchanged']

# %% [markdown]
# ### 2.2 knn basic

# %%
# add grid search cv
# add score

def predict_tags_using_knn(df, feature, target, k=50, exemple=None):
    documents = df[feature].tolist()
    gensim_dictionary = Dictionary(documents)
    corpus = [gensim_dictionary.doc2bow(doc) for doc in documents]

    # Convert Gensim corpus to dense matrix
    dense_matrix = corpus2dense(corpus, num_terms=len(gensim_dictionary)).T

    # Ici on ne va pas demander au knn de faire de prediction,
    # On veut juste qu'il trouve les voisins.
    # Mais la fonction fit a besoin de targets en param
    target_values = df[target].values

    # Initialize kNN model
    knn_model = KNeighborsRegressor(n_neighbors=k, metric='cosine', algorithm='brute')
    knn_model.fit(dense_matrix, target_values)

    # Example query
    query_document = exemple
    query_bow = gensim_dictionary.doc2bow(query_document)
    query_vector = corpus2dense([query_bow], num_terms=len(gensim_dictionary)).T

    # Find nearest neighbors
    _, indices = knn_model.kneighbors(query_vector)

    # Aggregate tags from neighbors
    neighbor_tags = [tag for i in indices.flatten() for tag in df.iloc[i][target]]

    print(neighbor_tags)

    # Predict tags based on most common tags among neighbors
    predicted_tags = [tag for tag, _ in Counter(neighbor_tags).most_common(n=10)]
    # 5 tags/question en moyenne mais on peut suggérer +
    # ici a ameliorer

    return query_vector, predicted_tags

# %% [markdown]
# ### 2.3 predictions (input = list)

# %%
exemple1 = ["your", 'text', 'document', 'javascript']
_, predicted_tags1 = predict_tags_using_knn(train_df, 'title_nltk', 'all_tags', exemple=exemple1)
print(predicted_tags1, '\n')

# javascript ok
# Out:
# ['c#', 'wpf', 'winforms', 'textbox', 'textchanged', 'javascript', 'reactjs', 'functional-programming', 'immutability', 'immutable.js', 'javascript', 'jquery', 'ajax', 'asp.net-mvc-3', 'url', 'ios', 'objective-c', 'uilabel', 'autolayout', 'uistoryboard', 'javascript', 'arrays', 'object', 'arguments', 'slice', 'user-interface', 'text', 'dart', 'flutter', 'marquee', 'python', 'machine-learning', 'neural-network', 'nlp', 'keras', 'ios', 'objective-c', 'swift', 'event-handling', 'uitextfielddelegate', 'javascript', 'reactjs', 'sublimetext3', 'babeljs', 'jsx', 'android', 'user-interface', 'text', 'imageview', 'tablelayout', 'javascript', 'text', 'svg', 'd3.js', 'geometry', 'javascript', 'html', 'google-chrome', 'error-handling', 'http-status-code-404', 'javascript', 'object', 'callback', 'this', 'scope', 'sql', 'oracle', 'view', 'oracle9i', 'ora-00932', 'javascript', 'parsing', 'datetime', 'format', 'datetime-format', 'android', 'android-alertdialog', 'android-dialogfragment', 'android-dialog', 'android-6.0-marshmallow', 'ios', 'objective-c', 'iphone', 'uibutton', 'textcolor', 'excel', 'api', 'translation', 'google-translate', 'deepl', 'javascript', 'html', 'canvas', 'svg', 'html2canvas', 'javascript', 'unit-testing', 'constructor', 'mocking', 'sinon', 'javascript', 'html', 'dynamic', 'drop-down-menu', 'checkbox', 'android', 'iphone', 'css', 'mobile-safari', 'css-transforms', 'javascript', 'node.js', 'closures', 'scope', 'serverside-javascript', 'javascript', 'c#', 'asp.net', 'asp.net-mvc', 'asp.net-core', 'java', 'spring', 'hibernate', 'spring-boot', 'jpa', 'python', 'selenium', 'webdriver', 'web-scraping', 'alert', 'javascript', 'node.js', 'ms-word', 'converters', 'jspdf', 'javascript', 'floating-point', 'double', 'floating-accuracy', 'numerical-methods', 'python', 'html', 'web-scraping', 'text', 'beautifulsoup', 'html', 'css', 'image', 'multiline', 'vertical-alignment', 'javascript', 'jquery', 'ajax', 'csv', 'filereader', 'javascript', 'string', 'algorithm', 'recursion', 'permutation', 'javascript', 'html', 'canvas', 'text', 'rendering', 'html', 'css', 'mobile', 'twitter-bootstrap', 'tablet', 'c#', '.net', 'asp.net', 'winforms', 'label', 'jquery', 'html', 'jquery-ui', 'datepicker', 'jquery-ui-datepicker', 'javascript', 'jquery', 'json', 'checkbox', 'hashtable', 'javascript', 'jquery', 'html', 'regex', 'replace', 'javascript', 'html', 'css', 'overflow', 'ellipsis', 'javascript', 'promise', 'async-await', 'reduce', 'ecmascript-next', 'javascript', 'node.js', 'asynchronous', 'foreach', 'synchronous', 'c#', 'xaml', 'dialog', 'windows-10', 'win-universal-app', 'javascript', 'jquery', 'ajax', 'api', 'ecmascript-6', 'javascript', 'html', 'json', 'replace', 'userscripts', 'javascript', 'api', 'oauth-2.0', 'angularjs', 'consumer', 'objective-c', 'ios', 'xcode', 'interface-builder', 'uitextfield', 'javascript', 'jquery', 'math', 'modulo', 'negative-number', 'python', 'unit-testing', 'testing', 'logging', 'pytest', 'visual-studio', 'file', 'tabs', 'document', 'show-hide', 'javascript', 'html', 'css', 'jquery-mobile', 'cordova']
# ['javascript', 'html', 'jquery', 'text', 'css', 'c#', 'ios', 'objective-c', 'python', 'ajax']

# %%
exemple2 = ["your", 'text', 'document', 'python']
# Call the function with your DataFrame and the desired text feature and target tags
_, predicted_tags2 = predict_tags_using_knn(train_df, 'title_nltk', 'all_tags', exemple=exemple2)
print(predicted_tags2, '\n')

# python
# Out:
# ['python', 'parsing', 'text', 'file-io', 'python-2.7', 'python', 'html', 'web-scraping', 'text', 'beautifulsoup', 'amazon-web-services', 'opencv', 'amazon-s3', 'aws-lambda', 'python-3.8', 'c#', 'wpf', 'winforms', 'textbox', 'textchanged', 'python', 'python-3.x', 'operators', 'matrix-multiplication', 'python-3.5', 'python', 'packaging', 'remote-access', 'download', 'software-update', 'ios', 'objective-c', 'uilabel', 'autolayout', 'uistoryboard', 'python', 'matplotlib', 'plot', 'visualization', 'histogram', 'user-interface', 'text', 'dart', 'flutter', 'marquee', 'ios', 'objective-c', 'swift', 'event-handling', 'uitextfielddelegate', 'python', 'python-3.x', 'linux', 'ubuntu', 'unicode', 'python', 'selenium', 'asynchronous', 'webdriver', 'python-asyncio', 'python', 'comments', 'terminology', 'code-analysis', 'pep8', 'python', 'json', 'compare', 'diff', 'unordered', 'python', 'matplotlib', 'seaborn', 'bokeh', 'waffle-chart', 'python', 'permutation', 'combinations', 'puzzle', 'python-itertools', 'python', 'python-3.x', 'pip', 'python-requests', 'pipenv', 'python', 'opencv', 'image-processing', 'computer-vision', 'ocr', 'python', 'math', 'coordinates', 'interpolation', 'geo', 'python', 'macos', 'serial-port', 'usb', 'pyserial', 'python', 'multithreading', 'exception', 'python-3.x', 'catch-all', 'ios', 'objective-c', 'iphone', 'uibutton', 'textcolor', 'python', 'ssl', 'openssl', 'dropbox-api', 'nas', 'python', 'python-3.x', 'inheritance', 'python-2.x', 'setattr', 'android', 'android-alertdialog', 'android-dialogfragment', 'android-dialog', 'android-6.0-marshmallow', 'python', 'functional-programming', 'iterator', 'method-chaining', 'fluent-interface', 'python', 'python-2.7', 'opencv', 'lambda', 'opencv3.0', 'python', 'caching', 'singleton', 'unique', 'memoization', 'python', 'machine-learning', 'neural-network', 'nlp', 'keras', 'android', 'user-interface', 'text', 'imageview', 'tablelayout', 'python', 'numpy', 'matplotlib', 'scipy', 'curve-fitting', 'python', 'class', 'operators', 'tuples', 'divide', 'python', 'machine-learning', 'scikit-learn', 'prediction', 'one-hot-encoding', 'python', 'multithreading', 'concurrency', 'locking', 'python-import', 'sql', 'oracle', 'view', 'oracle9i', 'ora-00932', 'python', 'windows', 'python-2.7', 'powershell', 'pip', 'python', 'debugging', 'asynchronous', 'python-asyncio', 'ipdb', 'python', 'python-3.x', 'while-loop', 'iterator', 'generator', 'python', 'arrays', 'vector', 'matrix', 'initialization', 'python', 'pandas', 'dataframe', 'conditional-formatting', 'pandas-styles', 'python', 'signal-processing', 'speech-recognition', 'speech-to-text', 'speech', 'excel', 'api', 'translation', 'google-translate', 'deepl', 'python', 'asynchronous', 'async-await', 'generator', 'python-asyncio', 'python', 'file', 'copy', 'python-2.x', 'pathlib', 'python', 'pandas', 'dataframe', 'ipython', 'selection', 'python', 'x86', 'interpreter', 'cpython', 'strncmp', 'javascript', 'text', 'svg', 'd3.js', 'geometry', 'c++', 'python', 'ctypes', 'cython', 'boost-python', 'python', 'post', 'request', 'urllib2', 'urllib', 'javascript', 'reactjs', 'sublimetext3', 'babeljs', 'jsx']
# ['python', 'python-3.x', 'text', 'python-2.7', 'opencv', 'ios', 'objective-c', 'matplotlib', 'asynchronous', 'python-asyncio']

# %%
exemple = test_df['title_nltk'][0]
print(exemple)

# Call the function with your DataFrame and the desired text feature and target tags
_, predicted_tags = predict_tags_using_knn(train_df, 'title_nltk', 'all_tags', exemple=exemple)
print(predicted_tags, '\n')

# firebase peut etre predit
# grand succes !
# Out:
# ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# ['node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query', 'java', 'sql', 'hibernate', 'spring-mvc', 'hql', 'linux', 'docker', 'windows-subsystem-for-linux', 'pgadmin', 'laradock', 'python', 'python-3.x', 'django', 'foreign-keys', 'django-users', 'android', 'unit-testing', 'integration-testing', 'android-testing', 'android-espresso', 'php', 'mysql', 'laravel', 'laravel-5', 'eloquent', 'ios', 'xcode', 'swift', 'app-store-connect', 'xcode6', 'php', 'encryption', 'openssl', 'warnings', 'rsa', 'opengl', 'ssh', 'x11', 'nvidia', 'tegra', 'c++', 'c', 'int', 'short', 'integer-promotion', 'visual-studio', 'visual-studio-2010', 'projects-and-solutions', 'visual-studio-project', 'find-all-references', 'python', 'python-2.7', 'dictionary', 'floating-point', 'int', 'git', 'github', 'bitbucket', 'ssh-keys', 'public-key', 'php', 'mysql', 'laravel', 'laravel-5', 'pessimistic-locking', 'jquery', 'ajax', 'search', 'laravel', 'pagination', 'javascript', 'ajax', 'iframe', 'https', 'internet-explorer-11', 'google-cloud-platform', 'storage', 'gcloud', 'bucket', 'google-cloud-billing', 'android', 'return', 'android-edittext', 'android-softkeyboard', 'enter', 'sql', 'cassandra', 'foreign-keys', 'foreign-key-relationship', 'cql', 'c#', 'entity-framework-4.3', 'seed', 'linq-expressions', 'entity-framework-migrations', 'php', 'jquery', 'forms', 'laravel', 'eloquent', 'laravel', 'laravel-5', 'routes', 'laravel-routing', 'laravel-middleware', 'android', 'sqlite', 'orm', 'android-room', 'android-orm', 'python', 'variables', 'dictionary', 'jinja2', 'substitution', 'php', 'laravel', 'file-upload', 'laravel-5.4', 'php-7', 'php', 'arrays', 'collections', 'eloquent', 'laravel-5', 'ssh', 'ssh-keys', 'openssh', 'tortoisegit', 'ssh-agent', 'php', 'laravel', 'laravel-5', 'timezone', 'laravel-5.3', 'php', 'sql-server', 'laravel', 'stored-procedures', 'laravel-5', 'php', 'laravel', 'eloquent', 'greatest-n-per-group', 'eager-loading', 'c#', '.net', 'c#-4.0', '.net-4.0', 'petapoco', 'laravel', 'ssl', 'laravel-5', 'https', 'homestead', 'php', 'mysql', 'laravel', 'amazon-s3', 'amazon-cloudfront', 'laravel', '.htaccess', 'mod-rewrite', 'https', 'laravel-5.4', 'tomcat', 'ssl', 'centos', 'certificate', 'diffie-hellman', 'ios', 'objective-c', 'ios7', 'nsdictionary', 'uipickerview', 'php', 'apache', 'laravel', 'subdomain', 'hosts', 'android', 'android-emulator', 'emulation', 'android-virtual-device', 'internal-storage', 'php', 'laravel', 'laravel-4', 'composer-php', 'autoload', 'javascript', 'image', 'canvas', 'firebase', 'firebase-storage', 'android', 'performance', 'sqlite', 'primary-key', 'uuid', 'java', 'android', 'firebase', 'android-glide', 'firebaseui', 'ios', 'xcode', 'react-native', 'apple-m1', 'apple-silicon', 'php', 'laravel', 'try-catch', 'laravel-5.4', 'php-7.1', 'php', 'laravel', 'laravel-5.6', 'laravel-5.7', 'laravel-5.8', 'java', 'angularjs', 'spring', 'maven', 'gradle', 'java', 'dictionary', 'null', 'hashmap', 'java-9', 'database', 'windows-runtime', 'windows-store-apps', 'microsoft-metro', 'local-storage', 'laravel', 'laravel-5', 'homestead', 'ngrok', 'vagrant-share', 'php', 'laravel', 'localization', 'laravel-blade', 'pluralize']
# ['laravel', 'php', 'laravel-5', 'android', 'java', 'eloquent', 'python', 'mysql', 'ios', 'dictionary']

# %% [markdown]
# ### 2.4 Predictions (input = text)

# %%
exemple = test_df['title'][0]
print(exemple)

exemple_text = preprocess_text(exemple)

_, predicted_tags = predict_tags_using_knn(train_df, 'title_nltk', 'all_tags', exemple=exemple_text)
print(predicted_tags, '\n')

# ok
# Out:
# Laravel chmod(/var/dev/project/storage/oauth-public.key): Operation failed: Operation not permitted
# /tmp/ipykernel_111882/2421486217.py:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()
# ['python', 'python-3.x', 'django', 'foreign-keys', 'django-users', 'ios', 'xcode', 'swift', 'app-store-connect', 'xcode6', 'php', 'mysql', 'laravel', 'laravel-5', 'eloquent', 'node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query', 'php', 'encryption', 'openssl', 'warnings', 'rsa', 'visual-studio', 'visual-studio-2010', 'projects-and-solutions', 'visual-studio-project', 'find-all-references', 'git', 'github', 'bitbucket', 'ssh-keys', 'public-key', 'jquery', 'ajax', 'search', 'laravel', 'pagination', 'linux', 'docker', 'windows-subsystem-for-linux', 'pgadmin', 'laradock', 'python', 'python-2.7', 'dictionary', 'floating-point', 'int', 'php', 'mysql', 'laravel', 'laravel-5', 'pessimistic-locking', 'google-cloud-platform', 'storage', 'gcloud', 'bucket', 'google-cloud-billing', 'php', 'sql-server', 'laravel', 'stored-procedures', 'laravel-5', 'php', 'arrays', 'collections', 'eloquent', 'laravel-5', 'python', 'variables', 'dictionary', 'jinja2', 'substitution', 'php', 'laravel', 'file-upload', 'laravel-5.4', 'php-7', 'laravel', 'laravel-5', 'routes', 'laravel-routing', 'laravel-middleware', 'ssh', 'ssh-keys', 'openssh', 'tortoisegit', 'ssh-agent', 'c#', 'entity-framework-4.3', 'seed', 'linq-expressions', 'entity-framework-migrations', 'php', 'jquery', 'forms', 'laravel', 'eloquent', 'php', 'laravel', 'laravel-5', 'timezone', 'laravel-5.3', 'php', 'laravel', 'eloquent', 'greatest-n-per-group', 'eager-loading', 'sql', 'cassandra', 'foreign-keys', 'foreign-key-relationship', 'cql', 'c#', '.net', 'c#-4.0', '.net-4.0', 'petapoco', 'android', 'sqlite', 'orm', 'android-room', 'android-orm', 'android', 'return', 'android-edittext', 'android-softkeyboard', 'enter', 'php', 'mysql', 'laravel', 'amazon-s3', 'amazon-cloudfront', 'java', 'android', 'firebase', 'android-glide', 'firebaseui', 'php', 'laravel', 'laravel-4', 'composer-php', 'autoload', 'php', 'apache', 'laravel', 'subdomain', 'hosts', 'laravel', '.htaccess', 'mod-rewrite', 'https', 'laravel-5.4', 'android', 'performance', 'sqlite', 'primary-key', 'uuid', 'tomcat', 'ssl', 'centos', 'certificate', 'diffie-hellman', 'java', 'sql', 'hibernate', 'spring-mvc', 'hql', 'laravel', 'ssl', 'laravel-5', 'https', 'homestead', 'android', 'android-emulator', 'emulation', 'android-virtual-device', 'internal-storage', 'ios', 'objective-c', 'ios7', 'nsdictionary', 'uipickerview', 'javascript', 'image', 'canvas', 'firebase', 'firebase-storage', 'ios', 'xcode', 'react-native', 'apple-m1', 'apple-silicon', 'database', 'windows-runtime', 'windows-store-apps', 'microsoft-metro', 'local-storage', 'laravel', 'laravel-5', 'homestead', 'ngrok', 'vagrant-share', 'java', 'dictionary', 'null', 'hashmap', 'java-9', 'java', 'angularjs', 'spring', 'maven', 'gradle', 'shell', 'openssl', 'rsa', 'public-key', 'pem', 'ios', 'objective-c', 'reactjs', 'xcode', 'react-native', 'java', 'javafx', 'javafx-2', 'javafx-8', 'fxml', 'android', 'unit-testing', 'integration-testing', 'android-testing', 'android-espresso', 'python', 'python-3.x', 'google-cloud-platform', 'google-cloud-storage', 'google-cloud-functions', 'android', 'css', 'google-chrome-devtools', 'emulation', 'read-eval-print-loop', 'javascript', 'reactjs', 'typescript', 'eslint', 'typescript-eslint']
# ['laravel', 'php', 'laravel-5', 'android', 'java', 'python', 'ios', 'eloquent', 'xcode', 'mysql']

# %%
exemple = test_df['title'][1]
print(exemple)

exemple_text = preprocess_text(exemple)

_, predicted_tags = predict_tags_using_knn(train_df, 'title_nltk', 'all_tags', exemple=exemple_text)
print(predicted_tags, '\n')

# scala ok
# Out:
# Python/Selenium incognito/private mode
# /tmp/ipykernel_111882/2421486217.py:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()
# ['python', 'python-3.x', 'selenium-webdriver', 'selenium-firefoxdriver', 'firefox-headless', 'python', 'selenium', 'selenium-webdriver', 'iframe', 'webdriver', 'python', 'google-chrome', 'selenium', 'google-chrome-extension', 'selenium-webdriver', 'python', 'google-chrome', 'selenium-webdriver', 'selenium-chromedriver', 'window-size', 'python', 'linux', 'google-chrome', 'selenium-webdriver', 'automated-tests', 'python', 'matplotlib', 'plot', 'visualization', 'histogram', 'amazon-web-services', 'opencv', 'amazon-s3', 'aws-lambda', 'python-3.8', 'python', 'packaging', 'remote-access', 'download', 'software-update', 'python', 'python-3.x', 'operators', 'matrix-multiplication', 'python-3.5', 'python', 'arrays', 'vector', 'matrix', 'initialization', 'python', 'signal-processing', 'speech-recognition', 'speech-to-text', 'speech', 'python', 'python-2.7', 'opencv', 'lambda', 'opencv3.0', 'node.js', 'selenium', 'heroku', 'webdriver', 'scraper', 'python', 'python-3.x', 'linux', 'ubuntu', 'unicode', 'node.js', 'google-chrome', 'selenium', 'selenium-webdriver', 'selenium-chromedriver', 'python', 'functional-programming', 'iterator', 'method-chaining', 'fluent-interface', 'python', 'windows', 'python-2.7', 'powershell', 'pip', 'python-3.x', 'selenium', 'google-chrome', 'proxy', 'tor', 'python', 'macos', 'serial-port', 'usb', 'pyserial', 'objective-c', 'ios', 'datetime', 'nsdate', 'nsdateformatter', 'python', 'ssl', 'openssl', 'dropbox-api', 'nas', 'python', 'numpy', 'matplotlib', 'scipy', 'curve-fitting', 'python', 'opencv', 'image-processing', 'computer-vision', 'ocr', 'python', 'file', 'copy', 'glob', 'shutil', 'python', 'python-3.x', 'pip', 'python-requests', 'pipenv', 'python', 'python-3.x', 'inheritance', 'python-2.x', 'setattr', 'python', 'comments', 'terminology', 'code-analysis', 'pep8', 'python', 'pandas', 'dataframe', 'conditional-formatting', 'pandas-styles', 'python', 'debugging', 'asynchronous', 'python-asyncio', 'ipdb', 'python', 'google-chrome', 'python-3.x', 'selenium', 'python-3.3', 'python', 'file', 'copy', 'python-2.x', 'pathlib', 'python', 'machine-learning', 'scikit-learn', 'prediction', 'one-hot-encoding', 'python', 'multithreading', 'concurrency', 'locking', 'python-import', 'python', 'python-3.x', 'while-loop', 'iterator', 'generator', 'c++', 'python', 'ctypes', 'cython', 'boost-python', 'python', 'class', 'operators', 'tuples', 'divide', 'python', 'post', 'request', 'urllib2', 'urllib', 'python', 'pandas', 'dataframe', 'ipython', 'selection', 'python', 'matplotlib', 'seaborn', 'bokeh', 'waffle-chart', 'python', 'x86', 'interpreter', 'cpython', 'strncmp', 'python', 'permutation', 'combinations', 'puzzle', 'python-itertools', 'python', 'caching', 'singleton', 'unique', 'memoization', 'python', 'math', 'coordinates', 'interpolation', 'geo', 'python', 'unit-testing', 'mocking', 'python-module', 'python-mock', 'python', 'asynchronous', 'async-await', 'generator', 'python-asyncio', 'python', 'scipy', 'interpolation', 'spline', 'cubic-spline', 'mysql', 'ruby-on-rails', 'ruby-on-rails-4', 'database-connection', 'strict', 'python', 'json', 'compare', 'diff', 'unordered', 'python', 'selenium', 'asynchronous', 'webdriver', 'python-asyncio', 'python', 'multithreading', 'exception', 'python-3.x', 'catch-all']
# ['python', 'python-3.x', 'selenium', 'selenium-webdriver', 'google-chrome', 'webdriver', 'matplotlib', 'opencv', 'asynchronous', 'python-asyncio']

# %% [markdown]
# ### 2.5 scores

# %%
# Notre objectif de prédiction de tags ressemble a un pb de classification multi-label,
# où la matrice de confusion est extrêmement déséquilibrée :
# 5 tags sont prédits positifs, contre environ 250 000 tags (si on travaille sur all_tags)
# predits negatifs. Autrement dit :

# On peut utiliser la precision pour évaluer notre modèle. C'est même exactement l'outil qu'il nous faut :
# "précision = la proportion de prédictions correctes parmi les points que l’on a prédits positifs."
# En + c de loin le plus léger en ressources, puisqu'il ne s'occupe que des 5 tags prédits.

# En revanche je pense que le recall n'a pas vraiment de sens ici, il sera "écrasé" par
# le nombre de tags predits negatifs, sa valeur sera tjs très proche de zero.
# (même remarque pour la spécificité et l'accuracy)
# Et sans recall, pas de f1 score.
# à vérifier

# %% [markdown]
# #### Precision

# %%
# pourquoi on ne peut pas utiliser le score precision sckikit ici :
from sklearn.metrics import precision_score as p_score

# Assuming y_true is the ground truth (real tags) and y_pred is the predicted tags
precision = p_score(['ok', 'ko'], ['ko', 'ok'], average='micro')  # You can use 'micro', 'macro', or 'weighted' depending on your use case
print(f'Precision: {precision}')
# Out:
# Precision: 0.0

# %%
def precision_topics(real_tags:list, predicted_tags:list): # pour comparer 2 listes
    # precision = TP / (TP + FP)
    tp = 0
    for predicted_tag in predicted_tags:
        if predicted_tag in real_tags:
            tp += 1

    fp = len(predicted_tags) - tp
    precision = tp/(tp + fp)
    # <=> precision = tp/len(predicted_tags)

    return precision


print(precision_topics(exemple1, predicted_tags1))
precision_topics(exemple2, predicted_tags2)

# ok
# Out:
# 0.2
# 0.2

# %%
def precision_score(y_true, y_pred): # pour comparer 2 df ou 2 matrices de mm shape[0]
    precision = 0
    for i in range(0, len(y_pred)):
        precision += precision_topics(y_true[i], y_pred[i])
    precision_moyenne = precision / len(y_pred)

    return precision_moyenne


# pour la gridsearchcv
custom_precision_scorer = make_scorer(precision_score, greater_is_better=True)

# %% [markdown]
# #### Recall

# %%
# La precision nous interesse davantage ici, pour au moins 2 raisons :
# 1) On n'a aucune raison de "pénaliser" le modele pour les faux negatifs
# 2) Ici le recall va etre tres proche de zero, et sa variance sera tres faible
# => bcp - parlant

def recall_topics(all_tags: list, predicted_tags: list):
    # recall = TP / (TP + FN)
    tp = 0
    fn = 0
    for real_tag in all_tags:
        if real_tag in predicted_tags:
            tp += 1
        else:
            fn += 1
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0

    return recall


# insister ds la doctype : y_all = all tags ici, != y_true (5-6 tags max)
def recall_score(y_all, y_pred): # pour comparer 2 df ou 2 matrices de mm shape[0]
    recall = 0
    for i in range(0, len(y_pred)):
        recall += recall_topics(y_all, y_pred[i]) # ca risque d'etre long a calculer
    recall_moyen = recall / len(y_pred)

    return recall_moyen


custom_recall_scorer = make_scorer(recall_score, greater_is_better=True)

# %% [markdown]
# #### f1 score

# %%
# mm rearques que pour le recall

def f1_topics(real_tags: list, predicted_tags: list, all_tags:list):
    precision = precision_score(real_tags, predicted_tags)
    recall = recall_topics(all_tags, predicted_tags)

    # F1 score = 2 * (precision * recall) / (precision + recall)
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return f1


def f1_score(y_true, y_pred, y_all):
    f1_score = 0
    for i in range(0, len(y_pred)):
        score += f1_topics(y_true[i], y_pred[i], y_all)
    score_moyen = score / len(y_pred)

    return score_moyen


custom_f1_scorer = make_scorer(f1_score, greater_is_better=True)

# %% [markdown]
# #### Accuracy

# %%
# idem, ici la variance sera presque nulle (TP entre 0 et 5, TN = environ 250 000...)

def accuracy_topics(real_tags: list, predicted_tags: list, all_tags:list):
    # accuracy = (TP + TN) / (TP + TN + FP + FN)
    tp = sum(1 for tag in predicted_tags if tag in real_tags)
    tn = sum(1 for tag in all_tags if (tag not in predicted_tags) and (tag not in real_tags) )
    fp = sum(1 for tag in predicted_tags if tag not in real_tags)
    fn = sum(1 for tag in all_tags if (tag not in predicted_tags) and (tag in real_tags))

    accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0

    return accuracy


def accuracy_score(y_true, y_pred, y_all):
    score = 0
    for i in range(0, len(y_pred)):
        score += accuracy_topics(y_true[i], y_pred[i], y_all)
    score_moyen = score / len(y_pred)

    return score_moyen


custom_accuracy_scorer = make_scorer(accuracy_score, greater_is_better=True)

# %% [markdown]
# #### Jaccard similarity

# %%
# utilisé en partie 3 pour évaluer la similarité des topics obtenus / la lda
# ici pour comparer topics reels et topics predits.
# devrait etre correlé a la precision non ?
# st ts les 2 liés au nb de tp (true positifs)

def jaccard_similarity(topic1, topic2):
    set1 = set(topic1)
    set2 = set(topic2)
    return len(set1.intersection(set2)) / len(set1.union(set2))


def jaccard_score(y_true, y_pred): # pour comparer 2 df ou 2 matrices de mm shape[0]
    jacc = 0
    for i in range(0, len(y_pred)):
        jacc += jaccard_similarity(y_true[i], y_pred[i])
    jacc_moyen = jacc / len(y_pred)

    return jacc_moyen


# pour la gridsearchcv
custom_jacc_scorer = make_scorer(jaccard_score, greater_is_better=True)

# %% [markdown]
# ### 2.6 Evaluation

# %%
# add grid search cv
# add recall, f1 score ?

def predict_tags_using_knn(train_df=train_df, feature='title_nltk', target='all_tags', test_df=test_df, k=5,
                           n=5, scorer=precision_score):
    # 1 PREPROCESSING
    documents = train_df[feature].tolist()
    gensim_dictionary = Dictionary(documents)
    # print(len(gensim_dictionary))
    corpus = [gensim_dictionary.doc2bow(doc) for doc in documents]
    # print(len(corpus))
    # taille corpus ?

    # Convert Gensim corpus to dense matrix
    dense_matrix = corpus2dense(corpus, num_terms=len(gensim_dictionary)).T
    # taille matrice ? afficher
    # print(dense_matrix.shape, '\n')
    # pas tres dense ici, c notre bow donc tres sparse en fait
    # curieux d'appeler "corpus2dense()" une fonction qui retourne une matrice sparse
    # pprint(dense_matrix[:10]) # vraiment tres dense, quasiment que des 0 ! Bref
    # print('\n')

    # Ici on ne va pas demander au knn de faire de prediction,
    # On veut juste qu'il trouve les voisins.
    # Mais la fonction fit a besoin de targets en param
    target_values = train_df[target].values

    # 2 MODEL TRAINING
    knn_model = KNeighborsRegressor(n_neighbors=k)
    knn_model.fit(dense_matrix, target_values)

    # 3 PREDICTION
    # Predictions completes en 1h ou 2
    # optimiser avec pandarallel ?
    # use a sample en attendant
    predictions=[]
    min_range=0
    max_range=25 # test.shape[0]=4767
    for i in range(min_range, max_range):
        query_document = test_df[feature][i]
        print(f'doc {i} : {query_document}')
        print(f'real tags : {test_df[target][i]}')
        query_bow = gensim_dictionary.doc2bow(query_document)
        query_vector = corpus2dense([query_bow], num_terms=len(gensim_dictionary)).T

        # Find nearest neighbors
        _, indices = knn_model.kneighbors(query_vector)

        # Aggregate tags from neighbors
        neighbor_tags = [tag for i in indices.flatten() for tag in train_df.iloc[i][target]]

        # Predict tags based on most common tags among neighbors
        predicted_tags = [tag for tag, _ in Counter(neighbor_tags).most_common(n=n)]
        # 5 tags/question en moyenne mais on peut suggérer +
        predictions.append(predicted_tags)
        print(f'predicted : {predicted_tags}')
        print(precision_topics(test_df[target][i], predicted_tags), '\n')

    true_tags = [tags for tags in test_df[target][min_range:max_range]]

    # mean_precision = precision_score(true_tags, predictions)
    mean_precision = scorer(true_tags, predictions)

    return mean_precision


# Call the function with your DataFrame and the desired text feature and target tags
jaccard_moyen = predict_tags_using_knn(scorer=jaccard_score)

print(f'jaccard moyen = {jaccard_moyen}')
# 0.34 de precision pour 5 voisins ?? c enorme !
# <=> jaccard 0.15 (/body), 0.11(title)
# Out:
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'matplotlib', 'plot', 'visualization']
# 0.2
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'regex', 'mongodb-query', 'pymongo', 'sql-like']
# 0.2
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'javascript', 'typescript', 'object', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'memory-leaks', 'neural-network']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['angular', 'internationalization', 'ngx-translate', 'angular5', 'angular-i18n']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['bash', 'sublimetext', 'linux', 'pipe', 'stdin']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'java', 'sql-server', 'sql-server-2008', 't-sql']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'node.js', 'logfile', 'forever', 'logrotate']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['angular', 'ios', 'swift', 'xcode', 'swift3']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['ruby-on-rails', 'ruby', 'ruby-on-rails-3', 'rubymine', 'rubymine-7']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['html', 'pdf', 'css', 'printing', 'creation']
# 0.2
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'generics', 'c#-4.0']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['ios', 'machine-learning', 'ocr', 'nslinguistictagger', 'apple-vision']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'string', 'java', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'swift', 'optimization', 'compilation', 'type-inference']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'properties', 'python-3.x', 'amazon-web-services']
# 0.0
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['c#', '.net', 'visual-studio', 'command-line', 'mstest']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'object', 'java', 'typescript', 'properties']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['scala', 'c++', 'generics', 'types', 'higher-kinded-types']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'xamarin', 'mvvm', 'xamarin.forms', 'async-await']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['java', 'unit-testing', 'javascript', 'android', 'junit']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['python', 'class', 'count', 'decorator', 'exit']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'asynchronous', 'httpclient', '.net-4.5']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'foreign-keys', 'django-users']
# 0.0
#
# jaccard moyen = 0.0588888888888889

# %% [markdown]
# ### 2.7 logging mlfow

# %%
# Si erreur, commande console
# mlflow ui
# depuis dossier notebooks

experiment_id = create_mlflow_experiment(
    experiment_name="knn_optimisation",
    artifact_location="./artifacts",
    tags={"model": "knn", "preprocessing": 'bow', "feature": "title_nltk", 'target': 'all_tags'},
)
# Out:
# Experiment knn_optimisation already exists.

# %%
experiment = get_mlflow_experiment(experiment_id=experiment_id)
print("Name: {}".format(experiment.name))

with mlflow.start_run(run_name="testing", experiment_id=experiment_id) as run:
    parameters = {
        "preprocessing": 'bow',
        "feature": 'title_nltk',
        "k neighbors": 10,
        "target": 'all_tags'
    }
    mlflow.log_params(parameters)

    jaccard_moyen = predict_tags_using_knn(k=10, scorer=jaccard_score)

    metrics = {
            "jaccard": jaccard_moyen
        }

    # multiple metrics
    mlflow.log_metrics(metrics)

    # print info about the run
    print("run_id: {}".format(run.info.run_id))
    id_test_1 = run.info.run_id
    print("experiment_id: {}".format(run.info.experiment_id))
    print("status: {}".format(run.info.status))
    print("start_time: {}".format(run.info.start_time))
    print("end_time: {}".format(run.info.end_time))
    # print("lifecycle_stage: {}".format(run.info.lifecycle_stage)) # deprecated
# Out:
# Name: knn_optimisation
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'laravel', 'node.js', 'mongodb', 'express']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3']
# 0.4
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data', 'spring-data-mongodb']
# 0.8
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'object', 'java', 'properties', 'javascript']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'tensorflow', 'deep-learning', 'c#', 'c']
# 0.4
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['iphone', 'ios', 'python', 'javascript', 'android']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'command-line']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'python', 'types']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'c#', 'python', 'machine-learning', 'neural-network']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'xcode', 'javascript', 'angular', 'android']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['iphone', 'android', 'serial-port', 'sms', 'gsm']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['javascript', 'html', 'ios', 'reactjs', 'pdf']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c', 'pinvoke']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python', 'java', 'pandas']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'time', 'swift', 'optimization']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'properties', 'django', 'java']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'junit', '.net']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object', 'null', 'option-type']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['c++', 'scala', 'algorithm', 'c++11', 'data-structures']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'asp.net', 'xamarin', 'mvvm']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing', 'spring-boot']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'c#', 'python', 'class', 'count']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'nginx', 'location']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'angular', 'angular5', 'ssh-keys', 'python-3.x']
# 0.0
#
# run_id: f36a451b5dc44421ad99eaa440fe7004
# experiment_id: 627378971600475090
# status: RUNNING
# start_time: 1707332454215
# end_time: None

# %% [markdown]
# ### 2.8 Nested mlflow runs pour recherche manuelle du nb optimal de voisins

# %%
# tried different values here, see ui

with mlflow.start_run(run_name="k_opti_small_values", experiment_id=experiment_id) as parent:
    precision = []
    k_values = list(range(1, 25, 2))

    for k in k_values:
        with mlflow.start_run(run_name=f'child_{k}', nested=True) as child:
            print(f'RUN ID child_{k}:', child.info.run_id)

            parameters = {
                "preprocessing": 'bow',
                "feature": 'title_nltk',
                "k neighbors": k,
                "target": 'all_tags',
                "nb_tags_predicted": 5
            }
            mlflow.log_params(parameters)

            jaccard_moyen = predict_tags_using_knn(k=k, scorer=jaccard_score)

            metrics = {
                "jaccard": jaccard_moyen
            }
            # multiple metrics
            mlflow.log_metrics(metrics)

            precision.append((k, jaccard_moyen))

    jaccard_moyen = [item[1] for item in precision]

    # Plot precision scores against k values
    plt.plot(k_values, jaccard_moyen, marker='o')
    plt.xlabel('k')
    plt.ylabel('Precision')
    plt.title('Precision Score for Different k Values')
    plt.grid(True)

    # Save the plot
    plt.savefig("./artifacts/jaccard_plot_1_25.png")
    # Log the saved figure using MLflow
    mlflow.log_artifact("./artifacts/jaccard_plot_1_25.png")

    # Show the plot (optional)
    plt.show()


# k=13
# Out:
# RUN ID child_1: f4df00fa7b344d62929ca90fc1836c8a
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['amazon-web-services', 'opencv', 'amazon-s3', 'aws-lambda', 'python-3.8']
# 0.0
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['regex', 'mongodb', 'mongodb-query', 'pymongo', 'sql-like']
# 0.2
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['javascript', 'typescript', 'object', 'properties', 'conditional-statements']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['database', 'database-design', 'database-schema', 'olap', 'oltp']
# 0.0
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['c#', 'amazon-web-services', 'amazon-s3', 'aws-lambda', 'aws-sdk']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['linux', 'bash', 'pipe', 'stdin', 'sublimetext']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 'sql-server-2008', 't-sql', 'sql-server-2008-r2']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['powershell', 'encoding', 'utf-8', 'character-encoding', 'io-redirection']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'swift', 'xcode', 'swift3', 'xcode8']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['c#', 'asp.net-mvc', 'razor', 'asp.net-mvc-4', 'partial-views']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['html', 'pdf', 'css', 'printing', 'creation']
# 0.2
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', 'generics', 'c#-4.0', '.net-4.0']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['ios', 'machine-learning', 'ocr', 'nslinguistictagger', 'apple-vision']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['java', 'string', 'parsing', 'bigdecimal', 'decimalformat']
# 0.0
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['swift', 'optimization', 'compilation', 'type-inference', 'compilation-time']
# 0.0
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'python-3.x', 'amazon-web-services', 'apache-spark', 'amazon-s3']
# 0.0
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['c#', '.net', 'visual-studio', 'command-line', 'mstest']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['audio', 'bluetooth', 'communication', 'headset', 'a2dp']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['scala', 'monads', 'typeclass', 'for-comprehension', 'either']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['xamarin', 'mvvm', 'xamarin.forms', 'async-await', 'prism']
# 0.0
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['java', 'android', 'unit-testing', 'junit', 'junit5']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['python', 'class', 'count', 'decorator', 'exit']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'asynchronous', 'httpclient', '.net-4.5']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'foreign-keys', 'django-users']
# 0.0
#
# RUN ID child_3: dad52ee1920b42528215b6a1b30dd1d3
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'matplotlib', 'plot', 'visualization', 'histogram']
# 0.2
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'regex', 'mongodb-query', 'pymongo', 'sql-like']
# 0.2
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['javascript', 'typescript', 'object', 'properties', 'conditional-statements']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['c', 'linux', 'process', 'exec', 'execvp']
# 0.0
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['mysql', 'sql', 'postgresql', 'datetime', 'timestamp']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['bash', 'sublimetext', 'linux', 'pipe', 'stdin']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 'sql-server-2008', 't-sql', 'sql-server-2008-r2']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['apk', 'uri', 'securityexception', 'android-7.0-nougat', 'packageinstaller']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['android', 'android-studio', 'android-gradle-plugin', 'build.gradle', 'android-sdk-tools']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['ruby-on-rails', 'ruby', 'ruby-on-rails-3', 'rubymine', 'rubymine-7']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'objective-c', 'uilabel', 'autolayout', 'uistoryboard']
# 0.0
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'pinvoke', 'alternate-data-stream']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['python', 'pandas', 'random-forest', 'binning', 'discretization']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['string', 'json', 'java', 'parsing', 'bigdecimal']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['swift', 'optimization', 'compilation', 'type-inference', 'compilation-time']
# 0.0
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'python-3.x', 'amazon-web-services', 'apache-spark', 'amazon-s3']
# 0.0
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['c#', '.net', 'visual-studio', 'command-line', 'mstest']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['java', 'null', 'option-type', 'nullable', 'java-9']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['scala', 'c++', 'algorithm', 'c++11', 'data-structures']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'xamarin', 'mvvm', 'xamarin.forms', 'async-await']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['unit-testing', 'javascript', 'java', 'android', 'junit']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['c++', 'c++11', 'templates', 'template-meta-programming', 'template-specialization']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['nginx', 'location', 'http-status-code-404', 'nginx-location', 'nginx-config']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'foreign-keys', 'django-users']
# 0.0
#
# RUN ID child_5: 15463c149d504dfcb719ba56c17cf59a
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'matplotlib', 'plot', 'visualization']
# 0.2
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'regex', 'mongodb-query', 'pymongo', 'sql-like']
# 0.2
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'javascript', 'typescript', 'object', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'memory-leaks', 'neural-network']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['angular', 'internationalization', 'ngx-translate', 'angular5', 'angular-i18n']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['bash', 'sublimetext', 'linux', 'pipe', 'stdin']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'java', 'sql-server', 'sql-server-2008', 't-sql']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'node.js', 'logfile', 'forever', 'logrotate']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['angular', 'ios', 'swift', 'xcode', 'swift3']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['ruby-on-rails', 'ruby', 'ruby-on-rails-3', 'rubymine', 'rubymine-7']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['html', 'pdf', 'css', 'printing', 'creation']
# 0.2
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'generics', 'c#-4.0']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['ios', 'machine-learning', 'ocr', 'nslinguistictagger', 'apple-vision']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'string', 'java', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'swift', 'optimization', 'compilation', 'type-inference']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'properties', 'python-3.x', 'amazon-web-services']
# 0.0
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['c#', '.net', 'visual-studio', 'command-line', 'mstest']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'object', 'java', 'typescript', 'properties']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['scala', 'c++', 'generics', 'types', 'higher-kinded-types']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'xamarin', 'mvvm', 'xamarin.forms', 'async-await']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['java', 'unit-testing', 'javascript', 'android', 'junit']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['python', 'class', 'count', 'decorator', 'exit']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'asynchronous', 'httpclient', '.net-4.5']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'foreign-keys', 'django-users']
# 0.0
#
# RUN ID child_7: eba6ef15269a476d86e89762ab7d7bc6
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['laravel', 'node.js', 'mongodb', 'express', 'mongoose']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'selenium-webdriver', 'python-3.x', 'selenium', 'selenium-firefoxdriver']
# 0.6
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'regex', 'mongodb-query']
# 0.4
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'object', 'properties', 'javascript', 'typescript']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'memory-leaks', 'neural-network']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['angular', 'internationalization', 'ngx-translate', 'angular5', 'angular-i18n']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['linux', 'bash', 'sublimetext', 'command-line', 'terminal']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'types', 'sql-server-2008']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'c#', 'node.js', 'logfile', 'forever']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['javascript', 'angular', 'android', 'typescript', 'angular-cli']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'iphone', 'ipad', 'uiview', 'frame']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['html', 'javascript', 'ios', 'objective-c', 'uilabel']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'pinvoke', 'alternate-data-stream']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'java', 'python', 'pandas', 'random-forest']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'string', 'parsing', 'error-handling']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'optimization', 'compilation']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'django', 'object', 'properties', 'python-3.x']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['c#', 'unit-testing', 'java', '.net', 'visual-studio']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'object', 'java', 'typescript', 'properties']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['scala', 'c++', 'generics', 'types', 'higher-kinded-types']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'xamarin', 'mvvm', 'xamarin.forms']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['java', 'unit-testing', 'javascript', 'aws-sdk', 'android']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['c#', 'c++', 'c++11', 'templates', 'template-meta-programming']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', 'ios', 'objective-c', 'reactjs', 'xcode']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'foreign-keys', 'django-users']
# 0.0
#
# RUN ID child_9: 35c0081d52fa49edb0bf3938da295ec8
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['ssh-keys', 'laravel', 'node.js', 'mongodb', 'express']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'selenium-webdriver', 'python-3.x', 'amazon-web-services', 'amazon-s3']
# 0.4
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['java', 'spring', 'mongodb', 'spring-data', 'regex']
# 0.6
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'object', 'properties', 'java', 'javascript']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'tensorflow', 'deep-learning', 'database', 'database-design']
# 0.4
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'uibutton', 'rubymotion', 'rmq']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'command-line']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'java', 'python']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'c#', 'node.js', 'logfile', 'forever']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'angular', 'android', 'android-studio', 'android-gradle-plugin']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'c#', 'iphone', 'ipad', 'uiview']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['html', 'ios', 'javascript', 'pdf', 'css']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'pinvoke', 'alternate-data-stream']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'python', 'java', 'ios', 'machine-learning']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'time', 'java', 'swift', 'optimization']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'django', 'object', 'properties', 'python-3.x']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'junit', '.net']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['java', 'javascript', 'object', 'iphone', 'ios']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['scala', 'types', 'c++', 'generics', 'higher-kinded-types']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'xamarin', 'mvvm', 'xamarin.forms']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['java', 'unit-testing', 'spring', 'javascript', 'aws-sdk']
# 0.4
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['javascript', 'html', 'c#', 'assembly', 'cpu']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'reactjs', 'react-native']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'angular', 'angular5']
# 0.0
#
# RUN ID child_11: b54090ddaf754a2b81ab709932de9b50
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'laravel', 'node.js', 'mongodb', 'express']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'selenium', 'amazon-web-services']
# 0.6
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data', 'spring-data-mongodb']
# 0.8
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'java', 'javascript', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'tensorflow', 'c#', 'deep-learning', 'machine-learning']
# 0.4
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'c#', 'python', 'uibutton']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'macos']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'python', 'types']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'c#', 'node.js', 'logfile', 'forever']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android', 'python']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#', 'asp.net-mvc', 'razor']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['javascript', 'html', 'ios', 'reactjs', 'pdf']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', 'c', 'types', '.net-4.0']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'python', 'java', 'android', 'c#']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'optimization', 'compilation']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'django', 'properties', 'javascript']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'maven', 'junit']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'object', 'java', 'audio', 'bluetooth']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['c++', 'scala', 'algorithm', 'c++11', 'data-structures']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'python', 'xamarin', 'mvvm']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing', 'aws-sdk']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['python', 'java', 'c#', 'class', 'count']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['.net', 'testing', 'xpath', 'selenium', 'junit']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'angular', 'angular5']
# 0.0
#
# RUN ID child_13: fd9d75480d224934817d0beb41d6e999
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'sql', 'ssh-keys', 'laravel', 'android']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3']
# 0.4
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data', 'spring-data-mongodb']
# 0.8
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'javascript', 'java', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'java', 'c#']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'objective-c', 'c#', 'python']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'macos']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'python']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#', 'node.js', 'logfile']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android', 'swift']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#', 'asp.net-mvc', 'razor']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'objective-c', 'html', 'reactjs']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c', 'types']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python', 'java', 'datetime']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'compilation', 'performance']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'javascript', 'django', 'properties']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'maven', 'junit']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object', 'audio', 'bluetooth']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['ios', 'c++', 'scala', 'objective-c', 'iphone']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'python', 'asp.net-mvc', 'python-3.x', 'asp.net']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing', 'aws-sdk']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#', 'html', 'class']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'objective-c', 'xcode']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'ssh-keys', 'android']
# 0.0
#
# RUN ID child_15: bec14fd7ae8046e9b26e819d4d388f34
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['android', 'python', 'laravel', 'ssh-keys', 'php']
# 0.2
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3']
# 0.4
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['java', 'spring', 'mongodb', 'spring-data', 'spring-data-mongodb']
# 0.8
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'java', 'javascript', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'java', 'c#', 'machine-learning', 'tensorflow']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['c#', 'ios', 'c++', 'c', 'objective-c']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'command-line']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'python']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', '.net', 'c#', 'node.js']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android', 'swift']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['c#', 'android', 'java', 'iphone', 'javascript']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'objective-c', 'javascript', 'html', 'c#']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'ios', 'c']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['python', 'string', 'java', 'android', 'datetime']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'compilation', 'time']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'amazon-web-services', 'amazon-s3', 'properties']
# 0.0
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', '.net', 'junit']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'iphone', 'ios', 'object', 'java']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['c#', 'scala', 'c++', 'types', '.net']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'python', 'asp.net', 'javascript']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'iphone', 'ios', 'java', 'android']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['javascript', 'java', 'python', 'c#', 'html']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['ios', 'objective-c', 'c#', '.net', 'reactjs']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'angular', 'angular5']
# 0.0
#
# RUN ID child_17: e0be3a820dba449cb9b1dfdb31badd39
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'php', 'mysql', 'laravel', 'laravel-5']
# 0.4
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'selenium', 'amazon-web-services']
# 0.6
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['java', 'spring', 'mongodb', 'spring-data', 'hibernate']
# 0.6
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'object', 'ios', 'java', 'javascript']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'c#', 'java', 'spring-boot', 'machine-learning']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['c#', 'ios', 'c', '.net', 'python']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'macos']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'java']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#', 'iphone', 'ios']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'angular', 'c#', 'android', 'swift']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['javascript', 'android', 'iphone', 'ipad', 'c#']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'html', 'objective-c', 'c#']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', 'c', '.net-4.0', 'ios']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['python', 'java', 'string', 'ios', 'parsing']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'ios', 'java', 'string']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'time', 'datetime', 'date']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'django', 'object', 'iphone', 'ios']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'python', 'unit-testing', 'c#', '.net']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['objective-c', 'ios', 'javascript', 'object', 'java']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['c++', 'python', 'c#', 'multithreading', 'scala']
# 0.4
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'asp.net', 'python', 'async-await']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['ios', 'javascript', 'c#', 'iphone', 'objective-c']
# 0.0
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#', 'javascript', 'html']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'objective-c', 'reactjs']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'android', 'python-3.x', 'django', 'angular']
# 0.0
#
# RUN ID child_19: 4792db4046434fabaa9103a59c53de83
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'android', 'laravel', 'php', 'laravel-5']
# 0.4
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3']
# 0.4
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['java', 'spring', 'mongodb', 'spring-data', 'spring-data-mongodb']
# 0.8
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'object', 'javascript', 'java', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'c#', 'java', 'spring-boot', 'machine-learning']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'c#', 'python', 'objective-c', '.net']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'java']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'java']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['c#', 'logging', 'python', '.net', 'ios']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'swift', 'xcode']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'c#', 'iphone', 'java', 'javascript']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'html', 'objective-c', 'c#']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c', 'c++']
# 0.2
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['python', 'string', 'c#', 'java', 'parsing']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'string', 'javascript', 'ios', 'java']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'time', 'swift', 'compilation']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'django', 'object', 'javascript', 'c#']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'c#', 'python', 'unit-testing', 'ios']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'ios', 'object', 'iphone', 'objective-c']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['c++', 'ios', 'c++11', 'scala', 'types']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'python', 'asp.net', 'async-await']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'ios', 'java', 'android', 'unit-testing']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'javascript', 'python', 'android', 'c#']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['ios', 'objective-c', 'c#', '.net', 'reactjs']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'android', 'python-3.x', 'django', 'angular']
# 0.0
#
# RUN ID child_21: 2020810d10d24e109308a7d983df9eeb
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'php', 'mysql', 'laravel', 'laravel-5']
# 0.4
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'selenium', 'iphone']
# 0.6
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['java', 'spring', 'mongodb', 'spring-data', 'pymongo']
# 0.6
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'javascript', 'object', 'ios', 'java']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['c#', 'python', 'java', 'machine-learning', 'tensorflow']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['python', 'c#', 'javascript', 'ios', 'python-3.x']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'file', 'bash', 'sublimetext']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'c#', '.net']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'ios', '.net', 'angular']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'swift', 'xcode']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'iphone', 'javascript', 'ios', 'java']
# 0.2
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['javascript', 'html', 'ios', 'c#', 'objective-c']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c++', 'c']
# 0.2
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'ios', 'python', 'java']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'string', 'parsing', 'ios']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'time', 'swift', 'datetime']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'django', 'python-3.x', 'object', 'javascript']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'python', 'c#', 'ios', 'unit-testing']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['ios', 'javascript', 'iphone', 'objective-c', 'object']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['c++', 'multithreading', 'ios', 'c', 'c++11']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'javascript', 'python', 'asp.net']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['ios', 'javascript', 'iphone', 'objective-c', 'java']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'javascript', 'python', 'angular', 'android']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', 'ios', '.net', 'objective-c', 'reactjs']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'android', 'python-3.x', 'django', 'ssh-keys']
# 0.0
#
# RUN ID child_23: 5790adddc62e4104a314b0ff5e0b14a7
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'laravel', 'php', 'mysql', 'laravel-5']
# 0.4
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'ios', 'selenium']
# 0.6
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['java', 'spring', 'mongodb', 'spring-data', 'python']
# 0.6
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['python', 'javascript', 'object', 'properties', 'ios']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'c#', 'java', 'machine-learning', 'tensorflow']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['javascript', 'c#', 'c++', 'ios', 'python']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'c#', 'linux', 'bash', 'sublimetext']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 'ios', 't-sql', 'c#']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['c#', 'logging', '.net', 'ios', 'python']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'c#', 'python']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['c#', 'android', 'iphone', 'javascript', 'ios']
# 0.2
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['javascript', 'ios', 'html', 'objective-c', 'python']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', 'c++', 'c', '.net-4.0']
# 0.2
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['python', 'string', 'c#', 'java', 'ios']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'ios', 'javascript', 'java', 'string']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'time', 'java', 'swift', 'datetime']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'django', 'object', 'objective-c', 'ios']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['c#', 'python', 'java', '.net', 'ios']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['ios', 'javascript', 'iphone', 'objective-c', 'c#']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['python', 'c++', 'c#', 'multithreading', 'ios']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'asp.net-mvc', 'asp.net', 'javascript', 'python']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['ios', 'javascript', 'iphone', 'objective-c', 'java']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'javascript', 'python', 'android', 'php']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['ios', 'objective-c', 'c#', 'reactjs', 'xcode']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'android', 'ssh-keys', 'angular', 'angular5']
# 0.0

# %% [markdown]
# ### 2.9 Influence du nb de topics prédits sur la précision

# %%
with mlflow.start_run(run_name="tags_opti", experiment_id=experiment_id) as parent:
    precision = []
    nb_tags = [3, 4, 5, 10, 20]

    for n in nb_tags:
        with mlflow.start_run(run_name=f'child_{n}', nested=True) as child:
            print(f'RUN ID child_{n}:', child.info.run_id)

            parameters = {
                "preprocessing": 'bow',
                "feature": 'title_nltk',
                "k neighbors": 13,
                "target": 'all_tags',
                "nb_tags_predicted": n
            }
            mlflow.log_params(parameters)

            jaccard_moyen = predict_tags_using_knn(k=13, n=n, scorer=jaccard_score)

            metrics = {
                "jaccard": jaccard_moyen
            }

            # multiple metrics
            mlflow.log_metrics(metrics)

            precision.append((n, jaccard_moyen))

    jaccard_moyen = [item[1] for item in precision]

    # Plot precision scores against k values
    plt.plot(nb_tags, jaccard_moyen, marker='o')
    plt.xlabel('n')
    plt.ylabel('Precision')
    plt.title('Precision Score for Different n Values')
    plt.grid(True)

    # Save the plot
    plt.savefig("./artifacts/jaccard_plot_3_4_tags.png")
    # Log the saved figure using MLflow
    mlflow.log_artifact("./artifacts/jaccard_plot_3_4_tags.png")

    # Show the plot (optional)
    plt.show()
# Out:
# RUN ID child_3: ee7577e7cb594fa5bcfd7845d434a30c
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'sql', 'ssh-keys']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver']
# 0.6666666666666666
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring']
# 0.6666666666666666
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'javascript']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow']
# 0.3333333333333333
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'objective-c']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash']
# 0.3333333333333333
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql']
# 0.6666666666666666
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#']
# 0.0
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'objective-c']
# 0.3333333333333333
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java']
# 0.3333333333333333
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift']
# 0.3333333333333333
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'javascript']
# 0.0
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['ios', 'c++', 'scala']
# 0.3333333333333333
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'python', 'asp.net-mvc']
# 0.3333333333333333
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android']
# 0.3333333333333333
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django']
# 0.0
#
# RUN ID child_4: 7273a409cd9847988656538061758bf7
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'sql', 'ssh-keys', 'laravel']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services']
# 0.5
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data']
# 0.75
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'javascript', 'java']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'java']
# 0.25
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'objective-c', 'c#']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext']
# 0.25
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008']
# 0.5
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#', 'node.js']
# 0.25
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#', 'asp.net-mvc']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'objective-c', 'html']
# 0.5
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python', 'java']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string']
# 0.25
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'compilation']
# 0.25
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'javascript', 'django']
# 0.25
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'maven']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object', 'audio']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['ios', 'c++', 'scala', 'objective-c']
# 0.25
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'python', 'asp.net-mvc', 'python-3.x']
# 0.25
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing']
# 0.25
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#', 'html']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'objective-c']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'ssh-keys']
# 0.0
#
# RUN ID child_5: 04d38d157f3146178d73c18e2cd161b2
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'sql', 'ssh-keys', 'laravel', 'android']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3']
# 0.4
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data', 'spring-data-mongodb']
# 0.8
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'javascript', 'java', 'properties']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'java', 'c#']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'objective-c', 'c#', 'python']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'macos']
# 0.2
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'python']
# 0.4
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#', 'node.js', 'logfile']
# 0.2
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android', 'swift']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#', 'asp.net-mvc', 'razor']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'objective-c', 'html', 'reactjs']
# 0.4
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c', 'types']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python', 'java', 'datetime']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing']
# 0.2
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'compilation', 'performance']
# 0.2
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'javascript', 'django', 'properties']
# 0.2
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'maven', 'junit']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object', 'audio', 'bluetooth']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['ios', 'c++', 'scala', 'objective-c', 'iphone']
# 0.2
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'python', 'asp.net-mvc', 'python-3.x', 'asp.net']
# 0.2
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing', 'aws-sdk']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#', 'html', 'class']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'objective-c', 'xcode']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'ssh-keys', 'android']
# 0.0
#
# RUN ID child_10: c5576ee0a6154b52adb99e9623ec5c29
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'sql', 'ssh-keys', 'laravel', 'android', 'mysql', 'node.js', 'mongodb', 'express', 'mongoose']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3', 'aws-lambda', 'operators', 'matrix-multiplication', 'python-3.5', 'selenium-firefoxdriver']
# 0.2
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data', 'spring-data-mongodb', 'regex', 'mongodb-query', 'pymongo', 'sql-like', 'javascript']
# 0.4
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'javascript', 'java', 'properties', 'ios', 'objective-c', 'android', 'typescript', 'conditional-statements']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'java', 'c#', 'deep-learning', 'database', 'database-design', 'database-schema', 'olap']
# 0.2
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'objective-c', 'c#', 'python', 'c', 'mysql', 'sql', 'postgresql', 'datetime']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'macos', 'command-line', 'terminal', 'java', 'pipe', 'stdin']
# 0.1
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'python', 'types', 'java', 'database', 'sql-server-2008-r2', 'type-safety']
# 0.2
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#', 'node.js', 'logfile', 'forever', 'logrotate', 'powershell', 'encoding', 'utf-8']
# 0.1
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android', 'swift', 'python', 'typescript', 'angular-cli', 'angular-compiler-cli', 'android-studio']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#', 'asp.net-mvc', 'razor', 'asp.net-mvc-4', 'partial-views', 'serial-port', 'sms', 'gsm']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'objective-c', 'html', 'reactjs', 'iphone', 'python', 'uilabel', 'autolayout', 'uistoryboard']
# 0.2
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c', 'types', 'python', 'generics', 'c#-4.0', 'pinvoke', 'alternate-data-stream']
# 0.0
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python', 'java', 'datetime', 'ios', 'machine-learning', 'ocr', 'nslinguistictagger', 'apple-vision']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing', 'html', 'error-handling', 'bigdecimal', 'decimalformat', 'python']
# 0.1
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'compilation', 'performance', 'time', 'optimization', 'type-inference', 'compilation-time', 'import']
# 0.1
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'javascript', 'django', 'properties', 'java', 'python-3.x', 'amazon-web-services', 'apache-spark', 'amazon-s3']
# 0.1
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'maven', 'junit', '.net', 'visual-studio', 'command-line', 'mstest', 'mysql']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object', 'audio', 'bluetooth', 'communication', 'headset', 'a2dp', 'dependency-injection', 'jersey']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['ios', 'c++', 'scala', 'objective-c', 'iphone', 'algorithm', 'c++11', 'data-structures', 'time-complexity', 'generics']
# 0.1
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'python', 'asp.net-mvc', 'python-3.x', 'asp.net', 'xamarin', 'mvvm', 'xamarin.forms', 'async-await', 'prism']
# 0.1
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing', 'aws-sdk', 'spring', 'spring-boot', 'ios', 'iphone', 'junit']
# 0.2
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#', 'html', 'class', 'count', 'decorator', 'exit', 'c++', 'c++11']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'objective-c', 'xcode', 'python', 'asynchronous', 'httpclient', '.net-4.5', 'reactjs']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'ssh-keys', 'android', 'angular', 'angular5', 'foreign-keys', 'django-users', 'git']
# 0.0
#
# RUN ID child_20: d50e3584684e4e39b30abd3d691fa94b
# doc 0 : ['laravel', 'chmod', 'var', 'dev', 'project', 'storage', 'key', 'operation', 'fail', 'operation', 'permit']
# real tags : ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# predicted : ['python', 'sql', 'ssh-keys', 'laravel', 'android', 'mysql', 'node.js', 'mongodb', 'express', 'mongoose', 'mongodb-query', 'python-3.x', 'django', 'foreign-keys', 'django-users', 'java', 'hibernate', 'spring-mvc', 'hql', 'git']
# 0.0
#
# doc 1 : ['python', 'selenium', 'mode']
# real tags : ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# predicted : ['python', 'python-3.x', 'selenium-webdriver', 'amazon-web-services', 'amazon-s3', 'aws-lambda', 'operators', 'matrix-multiplication', 'python-3.5', 'selenium-firefoxdriver', 'firefox-headless', 'opencv', 'python-3.8', 'matplotlib', 'plot', 'visualization', 'histogram', 'packaging', 'remote-access', 'download']
# 0.1
#
# doc 2 : ['difference', 'spring', 'data', 'mongodb', 'hibernate', 'mongodb']
# real tags : ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# predicted : ['mongodb', 'java', 'spring', 'spring-data', 'spring-data-mongodb', 'regex', 'mongodb-query', 'pymongo', 'sql-like', 'javascript', 'node.js', 'mongoose', 'bulkinsert', 'hibernate', 'orm', 'hibernate-5.x', 'spring-boot', 'spring-annotations', 'spring-4', 'java-annotations']
# 0.2
#
# doc 3 : ['automapper', 'map', 'property', 'object', 'string']
# real tags : ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# predicted : ['object', 'python', 'javascript', 'java', 'properties', 'ios', 'objective-c', 'android', 'typescript', 'conditional-statements', 'matplotlib', 'runtime-error', 'data-visualization', 'attributeerror', 'swift', 'uiview', 'autoresizingmask', 'string', 'parsing', 'bigdecimal']
# 0.0
#
# doc 4 : ['difference', 'tensor', 'tensor', 'view', 'pytorch']
# real tags : ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# predicted : ['python', 'machine-learning', 'tensorflow', 'java', 'c#', 'deep-learning', 'database', 'database-design', 'database-schema', 'olap', 'oltp', 'memory-leaks', 'neural-network', 'spring-boot', 'spring-annotations', 'spring-4', 'java-annotations', 'c', 'linux', 'process']
# 0.1
#
# doc 5 : ['assume']
# real tags : ['php', 'apache', 'curl', 'wamp', 'kohana']
# predicted : ['ios', 'iphone', 'objective-c', 'c#', 'python', 'c', 'mysql', 'sql', 'postgresql', 'datetime', 'timestamp', 'xcode', 'ipad', 'multithreading', 'foreach', 'parallel.foreach', 'concurrent-collections', 'types', 'type-safety', 'dynamic-typing']
# 0.0
#
# doc 6 : ['linux', 'pipe', 'audio', 'file', 'input']
# real tags : ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# predicted : ['javascript', 'linux', 'bash', 'sublimetext', 'macos', 'command-line', 'terminal', 'java', 'pipe', 'stdin', 'file', 'xcode', 'cocoa', 'icons', 'iconutil', 'json', 'visual-studio-code', 'format', 'prettier', 'android']
# 0.05
#
# doc 7 : ['non', 'cluster', 'index', 'guid', 'type', 'column', 'sql', 'server']
# real tags : ['sql-server', 't-sql', 'optimization', 'indexing', 'foreign-keys']
# predicted : ['sql', 'sql-server', 't-sql', 'sql-server-2008', 'python', 'types', 'java', 'database', 'sql-server-2008-r2', 'type-safety', 'dynamic-typing', 'memory-safety', 'spring', 'http', 'spring-mvc', 'servlets', 'ios', 'swift', 'codable', 'decodable']
# 0.1
#
# doc 8 : ['silence', 'output', 'log', 'install', 'command']
# real tags : ['node.js', 'npm', 'command-line-arguments', 'npm-install', 'node-modules']
# predicted : ['logging', 'python', 'c#', 'node.js', 'logfile', 'forever', 'logrotate', 'powershell', 'encoding', 'utf-8', 'character-encoding', 'io-redirection', 'machine-learning', 'neural-network', 'keras', 'apk', 'uri', 'securityexception', 'android-7.0-nougat', 'packageinstaller']
# 0.05
#
# doc 9 : ['plugin', 'compile', 'project']
# real tags : ['java', 'maven', 'jakarta-ee', 'aspectj', 'aspectj-maven-plugin']
# predicted : ['ios', 'javascript', 'angular', 'android', 'swift', 'python', 'typescript', 'angular-cli', 'angular-compiler-cli', 'android-studio', 'android-gradle-plugin', 'build.gradle', 'android-sdk-tools', 'xcode', 'swift3', 'xcode8', 'internationalization', 'ngx-translate', 'angular5', 'angular-i18n']
# 0.0
#
# doc 10 : ['error', 'view', 'frame', 'label', 'runtime']
# real tags : ['ios', 'objective-c', 'xcode', 'layout', 'xcode5']
# predicted : ['android', 'javascript', 'c#', 'asp.net-mvc', 'razor', 'asp.net-mvc-4', 'partial-views', 'serial-port', 'sms', 'gsm', 'avr', 'at-command', 'php', 'mysqli', 'standards', 'strict', 'mysqli-multi-query', 'android-studio', 'android-gradle-plugin', 'build.gradle']
# 0.0
#
# doc 11 : ['html5', 'text', 'textarea']
# real tags : ['javascript', 'html', 'textarea', 'syntax-highlighting', 'rich-text-editor']
# predicted : ['ios', 'javascript', 'objective-c', 'html', 'reactjs', 'iphone', 'python', 'uilabel', 'autolayout', 'uistoryboard', 'pdf', 'css', 'printing', 'creation', 'mysql', 'sql', 'postgresql', 'datetime', 'timestamp', 'sublimetext3']
# 0.1
#
# doc 12 : ['c', 'enums']
# real tags : ['c++', 'enums', 'language-lawyer', 'enumeration', 'ordinal']
# predicted : ['c#', '.net', '.net-4.0', 'c', 'types', 'python', 'generics', 'c#-4.0', 'pinvoke', 'alternate-data-stream', 'silverlight', 'graphics', 'gdi+', 'c++', 'decimal', 'precision', 'python-3.x', 'django', 'foreign-keys', 'django-users']
# 0.05
#
# doc 13 : ['convert', 'arraybuffer', 'string', 'stack', 'size', 'exceed']
# real tags : ['javascript', 'jquery', 'encoding', 'data-conversion', 'arraybuffer']
# predicted : ['string', 'c#', 'python', 'java', 'datetime', 'ios', 'machine-learning', 'ocr', 'nslinguistictagger', 'apple-vision', 'pandas', 'random-forest', 'binning', 'discretization', 'parsing', 'bigdecimal', 'decimalformat', 'linq', 'collections', 'ienumerable']
# 0.0
#
# doc 14 : ['handle', 'mongodb', 'attempt', 'parse', 'json', 'string']
# real tags : ['c#', 'asp.net-mvc', 'json', 'mongodb', 'knockout.js']
# predicted : ['json', 'javascript', 'java', 'string', 'parsing', 'html', 'error-handling', 'bigdecimal', 'decimalformat', 'python', 'grep', 'pprint', 'jquery', 'url', 'escaping', 'regex', 'mongodb', 'mongodb-query', 'pymongo', 'sql-like']
# 0.1
#
# doc 15 : ['handle', 'time', 'time', 'zone', 'matplotlib']
# real tags : ['python', 'matplotlib', 'plot', 'timezone', 'python-datetime']
# predicted : ['python', 'java', 'swift', 'compilation', 'performance', 'time', 'optimization', 'type-inference', 'compilation-time', 'import', 'relative-path', 'python-packaging', 'relative-import', 'x86', 'intel', 'sse', 'avx', 'csv', 'pandas', 'python-datetime']
# 0.1
#
# doc 16 : ['django', 'attributeerror', 'tuple', 'object', 'attribute', 'regex']
# real tags : ['regex', 'django', 'python-2.7', 'django-urls', 'django-1.8']
# predicted : ['python', 'object', 'javascript', 'django', 'properties', 'java', 'python-3.x', 'amazon-web-services', 'apache-spark', 'amazon-s3', 'serialization', 'django-rest-framework', 'deserialization', 'class', 'exception', 'graph', 'cluster-computing', 'networkx', 'knn', 'iphone']
# 0.05
#
# doc 17 : ['test', 'pipe', 'dependency', 'service']
# real tags : ['angular', 'typescript', 'dependency-injection', 'angular2-testing', 'angular-test']
# predicted : ['java', 'unit-testing', 'c#', 'maven', 'junit', '.net', 'visual-studio', 'command-line', 'mstest', 'mysql', 'sql', 'postgresql', 'datetime', 'timestamp', 'dependencies', 'repository', 'dependency-management', 'json', 'rest', 'ios']
# 0.0
#
# doc 18 : ['trait', 'make', 'object']
# real tags : ['generics', 'rust', 'traits', 'dynamic-dispatch', 'trait-objects']
# predicted : ['javascript', 'java', 'object', 'audio', 'bluetooth', 'communication', 'headset', 'a2dp', 'dependency-injection', 'jersey', 'glassfish', 'hk2', 'typescript', 'properties', 'conditional-statements', 'arrays', 'arguments', 'slice', 'iphone', 'objective-c']
# 0.0
#
# doc 19 : ['thread', 'compare', 'scala', 'actor']
# real tags : ['java', 'multithreading', 'performance', 'scala', 'akka']
# predicted : ['ios', 'c++', 'scala', 'objective-c', 'iphone', 'algorithm', 'c++11', 'data-structures', 'time-complexity', 'generics', 'types', 'higher-kinded-types', 'type-constructor', 'monads', 'typeclass', 'for-comprehension', 'either', 'mysql', 'sql', 'postgresql']
# 0.05
#
# doc 20 : ['create', 'applicationuser', 'usermanager', 'seed', 'method', 'mvc', 'web', 'application']
# real tags : ['c#', '.net', 'asp.net-identity', 'seed', 'asp.net-mvc-5.1']
# predicted : ['c#', 'python', 'asp.net-mvc', 'python-3.x', 'asp.net', 'xamarin', 'mvvm', 'xamarin.forms', 'async-await', 'prism', 'scenekit', 'arkit', 'maya', 'realitykit', 'usdz', 'dictionary', 'matplotlib', 'boxplot', 'unit-testing', 'junit']
# 0.05
#
# doc 21 : ['spring', 'mockmvc', 'unit', 'testing', 'integration', 'testing']
# real tags : ['java', 'spring', 'spring-mvc', 'spring-test', 'spring-test-mvc']
# predicted : ['javascript', 'java', 'android', 'unit-testing', 'aws-sdk', 'spring', 'spring-boot', 'ios', 'iphone', 'junit', 'junit5', 'node.js', 'jestjs', 'exception', 'struts', 'dao', 'data-access', 'rest-assured', 'spring-boot-test', 'mockmvc']
# 0.1
#
# doc 22 : ['r', 'work', 'object', 'class']
# real tags : ['r', 'ggplot2', 'time-series', 'posixct', 'scales-xml']
# predicted : ['java', 'python', 'c#', 'html', 'class', 'count', 'decorator', 'exit', 'c++', 'c++11', 'templates', 'template-meta-programming', 'template-specialization', 'assembly', 'cpu', 'callstack', 'low-level', 'calling-convention', 'scala', 'apache-spark']
# 0.0
#
# doc 23 : ['cvc', 'find', 'declaration', 'element', 'project']
# real tags : ['java', 'xml', 'spring', 'maven', 'spring-mvc']
# predicted : ['c#', '.net', 'ios', 'objective-c', 'xcode', 'python', 'asynchronous', 'httpclient', '.net-4.5', 'reactjs', 'react-native', 'testing', 'xpath', 'selenium', 'junit', 'svg', 'nginx', 'location', 'http-status-code-404', 'nginx-location']
# 0.0
#
# doc 24 : ['set', 'key', 'google', 'compute', 'engine']
# real tags : ['ssh', 'google-cloud-platform', 'cloud', 'google-compute-engine', 'putty']
# predicted : ['python', 'python-3.x', 'django', 'ssh-keys', 'android', 'angular', 'angular5', 'foreign-keys', 'django-users', 'git', 'github', 'bitbucket', 'public-key', 'android-studio', 'gradle', 'android-gradle-plugin', 'build.gradle', 'angular2-forms', 'angular-material2', 'angular-reactive-forms']
# 0.0

# %% [markdown]
# ### 2.10 Preprocessing (feature et target)

# %%
# Nous avons besoin de transformer la target pdt le preprocessing (-> bow)
# mm si on ne s'sn sert pas vraiment, car grid_search.fit() n'accepte que des valeurs numériques.

# Avantage : on peut utiliser des metriques classiques pour le score (ici r2),
# mais ca n'a aucun sens metier interpretable.
# peut tjs etre utile si fortement correlé à notre precision score custom
# ou au score de similarité Jaccard

# Compliqué à faire dans le pipeline sckikit, qui transforme les features mais pas la target.
# TransformedTargetRegressor ne convient pas non plus ici : c'est un modele wrapper,
# utilisé apres le pipeline.
# trouvé qq "solutions" + ou - elegantes, mais rien de compatible à la fois avec sklearn et mlflow.

# Ici convertir les tags en bag of words ou les one hot encoder revient exactement au meme, donc
# autant utiliser le bow, on a deja le transformeur.
# En + avec la plupart des embedding on peut considerer que la prediction de topics devient
# un probleme de regression, les valeurs predites par les modeles sont des vecteurs
# dans un espace techniquement fini, mais immense.

# %%
def token_list_into_bow(X):
    documents = X.tolist()
    # print(documents)
    gensim_dictionary = Dictionary(documents)
    corpus = [gensim_dictionary.doc2bow(doc) for doc in documents]

    # Convert Gensim corpus to dense matrix
    bow_matrix = corpus2dense(corpus, num_terms=len(gensim_dictionary)).T

    return bow_matrix, gensim_dictionary

# %% [markdown]
# ### 2.11 (tentative de) gridsearch

# %%
# Prend trop de ressources !
# les runs mlflow sont + pratiques pour encapsuler le code

# En plus je me demande si la gridsearch est une bonne idée pour le knn.
# deja pour la lda et la nmf j'avais des doutes
# a verifier mais pour ces modeles je pense qu'un dataset d'entrainement plus petit peut
# serieusement impacter le nb optimal pour l'hyperparam
# (voisins pour le knn, topics pour lda et nmf)

def pipe_knn(train_df=train_df, feature='title_nltk', target='all_tags', test_df=test_df, metric='cosine'):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].values

    X_bow_matrix, _ = token_list_into_bow(X_train)
    y_bow_matrix, _ = token_list_into_bow(y_train)

    # Create a KNN Regressor
    knn_regressor = KNeighborsRegressor(metric=metric)

    # Create a pipeline with preprocessing and a knn regressor, to simplify gridsearch
    pipe = Pipeline(steps=[
        ("knn_regressor", knn_regressor)
    ])

    # Define hyperparameters and their possible values for grid search
    param_grid = {
        'knn_regressor__n_neighbors': [11, 13, 15],
        'knn_regressor__weights': ['uniform'] # , 'distance'
    }

    # Create the GridSearchCV object with multiple scoring metrics
    # scoring = {'neg_mean_squared_error': 'neg_mean_squared_error', 'r2': 'r2'}
    grid_search = GridSearchCV(pipe, param_grid=param_grid,
                            scoring='r2', cv=3, verbose=1) # add, refit='precision' for multiple scoring

    # Fit the GridSearchCV object to your training data to perform hyperparameter tuning
    grid_search.fit(X_bow_matrix, y_bow_matrix)

    # Access the best hyperparameters
    best_params = grid_search.best_params_
    print("Best Hyperparameters:", best_params)

    # Create the KNN regressor with the best hyperparameters
    best_knn_regressor = KNeighborsRegressor(# metric=metric,
                                             n_neighbors=best_params['knn_regressor__n_neighbors'],
                                             weights=best_params['knn_regressor__weights'])

    # Create a pipeline with the preprocessor and the tuned knn regressor
    pipeline_with_tuned_knn = Pipeline(steps=[
        ("knn_regressor", best_knn_regressor)  # Use the tuned neighbor and weight values here
    ])

    # Perform cross-validation (on training set) and display the scores for each split
    # scoring = ['r2', 'neg_mean_squared_error']
    cv_scores = cross_validate(pipeline_with_tuned_knn, X_bow_matrix, y_bow_matrix, cv=5, scoring='r2')
    # print("Cross-Validation Scores (training):", '\n', cv_scores)
    print("Cross-Validation Scores:")
    pprint(cv_scores)
    for i, score in enumerate(cv_scores['test_score']):
        print(f"Split {i+1} : precision = {score}")


# crash le kernel
# pipe_knn()

# %%
# On oublie la gridsearchcv, mais on garde le scorer
# pour evaluer notre modele sur tt le training / testing set
# (pas seulement les 25 premieres lignes du set)

def pipe_knn(train_df=train_df, feature='title_nltk', target='all_tags', test_df=test_df, metric='cosine'):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].values

    X_bow_matrix, _ = token_list_into_bow(X_train)
    y_bow_matrix, _ = token_list_into_bow(y_train)

    # Create a KNN Regressor
    knn_regressor = KNeighborsRegressor(metric=metric)

    # Define hyperparameters and their possible values for tuning
    params = {
        'n_neighbors': 13,
        'weights': 'uniform'
    }

    # Create the KNN regressor with the specified hyperparameters
    knn_regressor.set_params(**params)

    # Fit the KNN regressor to your training data
    knn_regressor.fit(X_bow_matrix, y_bow_matrix)

    # Evaluate the model using a scorer
    scorer = make_scorer(r2_score)
    score = scorer(knn_regressor, X_bow_matrix, y_bow_matrix)
    print("R2 Score:", score)

    return knn_regressor


# Demande bcp trop de ressources (31.5 GiB pour y_pred)
# pipe_knn()

# %% [markdown]
# ### 2.11 Utilisation d'un classifier multilabel

# %%
# Utiliser un regresseur permet de facilement travailler avec l'ensemble des tags, mais
# nécessite une méthode .predict() custom, et les prédictions sont très lentes :
# impossible d'évaluer notre moèle sur une partie importante du dataset,
# on doit se contenter d'un petit sample.

# Voyons si un regresseur multilabel peut résoudre ces 2 problèmes

# %%
#

all_tags = [tag for tags in raw_data['all_tags'] for tag in tags]
print(f'Il y a {len(all_tags)} tags au total. \n')
print(f'Il y a {len(set(all_tags))} tags différents. \n')

# display(questions_tags)

# Fréquence
tag_frequencies_dict = {}
for tag in all_tags:
    tag_frequencies_dict[tag] = tag_frequencies_dict.get(tag, 0) + 1

# Sort the dictionary items by values in descending order
sorted_tag_frequencies = dict(sorted(tag_frequencies_dict.items(), key=lambda item: item[1], reverse=True))

# Extract tags and frequencies
tags = list(sorted_tag_frequencies.keys())
frequencies = list(sorted_tag_frequencies.values())

df_freq = pd.DataFrame({'Tag': tags, 'Frequency': frequencies})
# Out:
# Il y a 238327 tags au total.
#
# Il y a 15817 tags différents.

# %%
def keep_most_frequent_tags(list_tags, df_freq=df_freq, lim=100):
    """
    Keep only the n most frequent tags (default 100).

    Parameters:
    - liste_tokens (list): The input list of tokens to be processed.
    - forbidden_list (set): A set of forbidden tokens, which includes stop words,
      tokens exceeding upper frequency limits, and tokens falling below lower frequency limits.

    Returns:
    list: A filtered list of tokens that excludes stop words, tokens exceeding upper frequency limits,
    and tokens falling below lower frequency limits.
    """

    mandatory_list = df_freq['Tag'][:lim].tolist()
    filtered_list = [token for token in list_tags if token in mandatory_list]

    return filtered_list


raw_data['top_tags_100'] = raw_data['all_tags'].apply(
    lambda x: keep_most_frequent_tags(x)
)

 # info targets vides
print(f'nb de targets desormais vides : {raw_data.loc[raw_data["top_tags_100"].apply(len) == 0, :].shape[0]} \
       (/ 50 000)', '\n')

display(raw_data.head())
# Out:
# nb de targets desormais vides : 2410        (/ 50 000)
#           CreationDate                                              title  \
# 0  2023-10-02 11:07:45  ImportError: cannot import name 'url_decode' f...
# 1  2023-09-25 09:05:11  Compilation error after upgrading to JDK 21 - ...
# 2  2023-08-28 07:22:32         Differences between Langchain & LlamaIndex
# 3  2023-08-15 22:21:03  session not created: This version of ChromeDri...
# 4  2023-08-01 08:16:21  Spring security method cannot decide pattern i...
#
#                                                 body  \
# 0  I am building a webapp using Flask. I imported...
# 1  After upgrading to JDK 21, I have the followin...
# 2  I'm currently working on developing a chatbot ...
# 3  I am running a Docker image from a Docker cont...
# 4  When I try to run an application it fails to s...
#
#                                             all_tags  \
# 0  [python, flask, importerror, flask-login, werk...
# 1  [spring-boot, compiler-errors, upgrade, lombok...
# 2  [chatbot, openai-api, langchain, large-languag...
# 3  [python, amazon-web-services, docker, google-c...
# 4  [java, spring-boot, eclipse, spring-security, ...
#
#                                           title_nltk  \
# 0                   [importerror, import, name, url]
# 1  [compilation, error, upgrade, jdk, member, field]
# 2                                       [difference]
# 3  [session, create, version, chromedriver, suppo...
# 4  [spring, security, method, decide, pattern, bo...
#
#                                            body_nltk  \
# 0  [importerror, import, name, build, webapp, fla...
# 1  [compilation, error, upgrade, jdk, member, fie...
# 2  [difference, work, develop, power, language, m...
# 3  [session, create, version, chromedriver, suppo...
# 4  [spring, security, method, decide, pattern, bo...
#
#                                          title_spacy  \
# 0                              [importerror, import]
# 1       [compilation, error, upgrade, member, field]
# 2                                       [difference]
# 3       [session, create, version, support, version]
# 4  [spring, security, method, decide, pattern, ap...
#
#                                           body_spacy  \
# 0  [build, webapp, import, flask, login, library,...
# 1  [upgrade, follow, compilation, error, project,...
# 2  [work, develop, power, want, provide, response...
# 3  [run, image, container, environment, work, tod...
# 4  [try, run, application, fail, start, throw, ex...
#
#                                         top_tags_100
# 0                                           [python]
# 1                                      [spring-boot]
# 2                                                 []
# 3  [python, amazon-web-services, docker, google-c...
# 4                       [java, spring-boot, eclipse]

# %%
# MultiLabelBinarizer: Does not handle missing values directly. Missing values need to be handled
# before applying the transformation.
# not so sure about that

print(raw_data.shape)

data_100 = raw_data.loc[raw_data["top_tags_100"].apply(len) >= 0, :].copy()

print(data_100.shape, '\n')

display(data_100.head())
# Out:
# (47665, 9)
# (47665, 9)
#           CreationDate                                              title  \
# 0  2023-10-02 11:07:45  ImportError: cannot import name 'url_decode' f...
# 1  2023-09-25 09:05:11  Compilation error after upgrading to JDK 21 - ...
# 2  2023-08-28 07:22:32         Differences between Langchain & LlamaIndex
# 3  2023-08-15 22:21:03  session not created: This version of ChromeDri...
# 4  2023-08-01 08:16:21  Spring security method cannot decide pattern i...
#
#                                                 body  \
# 0  I am building a webapp using Flask. I imported...
# 1  After upgrading to JDK 21, I have the followin...
# 2  I'm currently working on developing a chatbot ...
# 3  I am running a Docker image from a Docker cont...
# 4  When I try to run an application it fails to s...
#
#                                             all_tags  \
# 0  [python, flask, importerror, flask-login, werk...
# 1  [spring-boot, compiler-errors, upgrade, lombok...
# 2  [chatbot, openai-api, langchain, large-languag...
# 3  [python, amazon-web-services, docker, google-c...
# 4  [java, spring-boot, eclipse, spring-security, ...
#
#                                           title_nltk  \
# 0                   [importerror, import, name, url]
# 1  [compilation, error, upgrade, jdk, member, field]
# 2                                       [difference]
# 3  [session, create, version, chromedriver, suppo...
# 4  [spring, security, method, decide, pattern, bo...
#
#                                            body_nltk  \
# 0  [importerror, import, name, build, webapp, fla...
# 1  [compilation, error, upgrade, jdk, member, fie...
# 2  [difference, work, develop, power, language, m...
# 3  [session, create, version, chromedriver, suppo...
# 4  [spring, security, method, decide, pattern, bo...
#
#                                          title_spacy  \
# 0                              [importerror, import]
# 1       [compilation, error, upgrade, member, field]
# 2                                       [difference]
# 3       [session, create, version, support, version]
# 4  [spring, security, method, decide, pattern, ap...
#
#                                           body_spacy  \
# 0  [build, webapp, import, flask, login, library,...
# 1  [upgrade, follow, compilation, error, project,...
# 2  [work, develop, power, want, provide, response...
# 3  [run, image, container, environment, work, tod...
# 4  [try, run, application, fail, start, throw, ex...
#
#                                         top_tags_100
# 0                                           [python]
# 1                                      [spring-boot]
# 2                                                 []
# 3  [python, amazon-web-services, docker, google-c...
# 4                       [java, spring-boot, eclipse]

# %%
quick_df = data_100[::10]

train_df, test_df = train_test_split(quick_df, test_size=0.1, random_state=42)

train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %%
def knn_classifier(train_df=train_df, feature='title_nltk', k=13, target='top_tags_100', test_df=test_df):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].tolist()

    # training set
    X_bow_matrix, dict = token_list_into_bow(X_train)

    # target encoding
    mlb = MultiLabelBinarizer()
    y_encoded = mlb.fit_transform(y_train)

    # Create a KNN classifier this time
    knn = KNeighborsClassifier()

    # Define hyperparameters and their possible values for tuning
    params = {
        'n_neighbors': k
    }

    # Create the KNN regressor with the specified hyperparameters
    knn.set_params(**params)

    # Fit the KNN regressor to your training data
    knn.fit(X_bow_matrix, y_encoded)

    # Evaluate the model using a scorer
    scorer = custom_jacc_scorer
    score = scorer(knn, X_bow_matrix, y_encoded)
    print("Score : ", score)

    return knn, mlb, dict


knn_100, mlb_100, dict_100 = knn_classifier()
# Out:
# Score :  0.5686480186480186

# %%
def create_top_n_tags_feature(raw_data=raw_data, n=100, slice=1):
    raw_data[f'top_tags_{n}'] = raw_data['all_tags'].apply(
        lambda x: keep_most_frequent_tags(x, lim=n)
    )

    data = raw_data.loc[raw_data[f'top_tags_{n}'].apply(len) >= 0, :].copy()
    print(data.shape, '\n')

    slice_df = data[::slice]
    # slice_df.reset_index(drop=True, inplace=True)

    train_df, test_df = train_test_split(slice_df, test_size=0.1, random_state=42)

    train_df.reset_index(drop=True, inplace=True)
    test_df.reset_index(drop=True, inplace=True)


    return train_df, test_df


train_df, test_df = create_top_n_tags_feature(n=50, slice=10)
# Out:
# (47665, 10)

# %%
display(raw_data.head())
# Out:
#           CreationDate                                              title  \
# 0  2023-10-02 11:07:45  ImportError: cannot import name 'url_decode' f...
# 1  2023-09-25 09:05:11  Compilation error after upgrading to JDK 21 - ...
# 2  2023-08-28 07:22:32         Differences between Langchain & LlamaIndex
# 3  2023-08-15 22:21:03  session not created: This version of ChromeDri...
# 4  2023-08-01 08:16:21  Spring security method cannot decide pattern i...
#
#                                                 body  \
# 0  I am building a webapp using Flask. I imported...
# 1  After upgrading to JDK 21, I have the followin...
# 2  I'm currently working on developing a chatbot ...
# 3  I am running a Docker image from a Docker cont...
# 4  When I try to run an application it fails to s...
#
#                                             all_tags  \
# 0  [python, flask, importerror, flask-login, werk...
# 1  [spring-boot, compiler-errors, upgrade, lombok...
# 2  [chatbot, openai-api, langchain, large-languag...
# 3  [python, amazon-web-services, docker, google-c...
# 4  [java, spring-boot, eclipse, spring-security, ...
#
#                                           title_nltk  \
# 0                   [importerror, import, name, url]
# 1  [compilation, error, upgrade, jdk, member, field]
# 2                                       [difference]
# 3  [session, create, version, chromedriver, suppo...
# 4  [spring, security, method, decide, pattern, bo...
#
#                                            body_nltk  \
# 0  [importerror, import, name, build, webapp, fla...
# 1  [compilation, error, upgrade, jdk, member, fie...
# 2  [difference, work, develop, power, language, m...
# 3  [session, create, version, chromedriver, suppo...
# 4  [spring, security, method, decide, pattern, bo...
#
#                                          title_spacy  \
# 0                              [importerror, import]
# 1       [compilation, error, upgrade, member, field]
# 2                                       [difference]
# 3       [session, create, version, support, version]
# 4  [spring, security, method, decide, pattern, ap...
#
#                                           body_spacy  \
# 0  [build, webapp, import, flask, login, library,...
# 1  [upgrade, follow, compilation, error, project,...
# 2  [work, develop, power, want, provide, response...
# 3  [run, image, container, environment, work, tod...
# 4  [try, run, application, fail, start, throw, ex...
#
#                                         top_tags_100  \
# 0                                           [python]
# 1                                      [spring-boot]
# 2                                                 []
# 3  [python, amazon-web-services, docker, google-c...
# 4                       [java, spring-boot, eclipse]
#
#                              top_tags_50
# 0                               [python]
# 1                          [spring-boot]
# 2                                     []
# 3  [python, amazon-web-services, docker]
# 4                    [java, spring-boot]

# %%
knn_50, mlb_50, dict_50 = knn_classifier(train_df=train_df, k=5, target='top_tags_50')
# Out:
# Score :  0.6874125874125874

# %%
def string_query_into_bow_vector(query, dictionary):
    query_token_list = preprocess_text(query)
    query_bow = dictionary.doc2bow(query_token_list)
    query_vector = corpus2dense([query_bow], num_terms=len(dictionary)).T


    return query_vector

# %%
# predict

def predict_tags(test_data, knn_model=knn_50, mlb_encoder=mlb_50, dictionary=dict_50):
    # Transform test features
    query = string_query_into_bow_vector(test_data, dictionary)

    # Make predictions
    predicted_labels = knn_model.predict(query)

    # Inverse transform predicted labels
    predicted_tags = mlb_encoder.inverse_transform(predicted_labels)

    return predicted_tags


def test_prediction(index=0):
    predicted_tags = predict_tags(test_df['title'][index])
    print(test_df['all_tags'][index])
    print(test_df['top_tags_50'][index])
    print(predicted_tags, '\n')


test_prediction()
# Out:
# ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# ['php']
# [()]
# /tmp/ipykernel_111882/2421486217.py:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()

# %%
test_prediction(1)
test_prediction(2)
test_prediction(3)
test_prediction(4)
test_prediction(5)
test_prediction(6)

# bcp de "predictions" nulles
# Out:
# /tmp/ipykernel_111882/2421486217.py:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()
# ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# ['python']
# [('python',)]
#
# ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# ['spring']
# [()]
# ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# ['c#', '.net']
# [()]
#
# ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# ['python']
# [()]
#
# ['php', 'apache', 'curl', 'wamp', 'kohana']
# ['php']
# [()]
#
# ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# ['linux']
# [()]

# %%
def always_predict_tags(test_data, knn_model=knn_50, mlb_encoder=mlb_50, dictionary=dict_50, top_n=5):
    # Transform test features
    query = string_query_into_bow_vector(test_data, dictionary)

    # Make predictions and get probabilities
    probabilities = knn_model.predict_proba(query)

    # Extract tags from the mlb_encoder
    tags = mlb_encoder.classes_

    # Create a dictionary to store results
    results = {}

    # Iterate over probabilities and tags
    for i, tag in enumerate(tags):
        # Extract the probability for the current tag
        probability = probabilities[i][0][0]
        # Store the probability with the tag as the key
        results[tag] = probability

    # Sort the dictionary items by values in descending order
    sorted_results = dict(sorted(results.items(), key=lambda item: item[1], reverse=True))
    predicted_tags = list(sorted_results)[:top_n]
    # Construct a list of tuples containing tags and their corresponding probabilities
    tags_with_probas = [(tag, sorted_results[tag]) for tag in predicted_tags]

    return tags_with_probas


def test_prediction(index=0):
    predicted_tags = always_predict_tags(test_df['title'][index])
    print(test_df['all_tags'][index])
    print(test_df['top_tags_50'][index])
    print(predicted_tags, '\n')


test_prediction()

# bcp de probas == 1 alors qu'on n'avait pas de prediction (ou 1) sur cet exemple ??
# Out:
# ['php', 'laravel-5', 'oauth', 'permissions', 'laravel-passport']
# ['php']
# [('.net', 1.0), ('android', 1.0), ('angular', 1.0), ('angularjs', 1.0), ('arrays', 1.0)]
# /tmp/ipykernel_111882/2421486217.py:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()

# %%
test_prediction(1)
test_prediction(2)
test_prediction(3)
test_prediction(4)
test_prediction(5)
test_prediction(6)

# bcp trop de valeurs à 1
# pour le knn on peut tjs utiliser notre predict custom, mais pour les autres modeles
# il faudra une difference plus nette.
# Out:
# /tmp/ipykernel_111882/2421486217.py:62: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()
# ['python', 'selenium', 'browser', 'selenium-webdriver', 'incognito-mode']
# ['python']
# [('.net', 1.0), ('android', 1.0), ('angular', 1.0), ('angularjs', 1.0), ('arrays', 1.0)]
#
# ['spring', 'mongodb', 'spring-data', 'spring-data-mongodb', 'hibernate-ogm']
# ['spring']
# [('.net', 1.0), ('amazon-web-services', 1.0), ('android', 1.0), ('angular', 1.0), ('angularjs', 1.0)]
#
# ['c#', '.net', 'mapping', 'automapper', 'automapper-2']
# ['c#', '.net']
# [('.net', 1.0), ('amazon-web-services', 1.0), ('android', 1.0), ('angular', 1.0), ('angularjs', 1.0)]
#
# ['python', 'multidimensional-array', 'deep-learning', 'pytorch', 'tensor']
# ['python']
# [('.net', 1.0), ('amazon-web-services', 1.0), ('android', 1.0), ('angular', 1.0), ('angularjs', 1.0)]
#
# ['php', 'apache', 'curl', 'wamp', 'kohana']
# ['php']
# [('.net', 1.0), ('angularjs', 1.0), ('arrays', 1.0), ('asp.net', 1.0), ('asp.net-mvc', 1.0)]
#
# ['linux', 'audio', 'microphone', 'alsa', 'voice-recording']
# ['linux']
# [('amazon-web-services', 1.0), ('android', 1.0), ('angular', 1.0), ('angularjs', 1.0), ('arrays', 1.0)]

# %% [markdown]
# ## 3 Autres classifieur multilabels

# %% [markdown]
# ### 3.1 Logistic regression

# %%
train_df, test_df = create_top_n_tags_feature(n=30, slice=5)
# Out:
# (47665, 11)

# %%
# pas nativement mutilabel -> approche one vs rest via MultiOutputClassifier()

def logistic_regression_classifier(train_df=train_df, feature='title_nltk', target='top_tags_30', test_df=test_df):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].tolist()

    # training set
    X_bow_matrix, dict = token_list_into_bow(X_train)

    # target encoding
    mlb = MultiLabelBinarizer()
    y_encoded = mlb.fit_transform(y_train)

    # Create a Logistic Regression classifier
    logistic_reg = LogisticRegression(random_state=42)

    # Create a MultiOutputClassifier with the Logistic Regression classifier
    multi_output_classifier = MultiOutputClassifier(logistic_reg)

    # Fit the MultiOutputClassifier to your training data
    multi_output_classifier.fit(X_bow_matrix, y_encoded)

    # Evaluate the model using a scorer
    scorer = custom_jacc_scorer
    score = scorer(multi_output_classifier, X_bow_matrix, y_encoded)
    print("Score : ", score)


    return multi_output_classifier, mlb, dict


multi_output_classifier, mlb_30, dict_30 = logistic_regression_classifier()
# Out:
# Score :  0.8125655670824106

# %%
# predict

# %% [markdown]
# ### 3.2 SGDClassifier

# %%
# using default SVM

def sgd_classifier(train_df=train_df, feature='title_nltk', target='top_tags_30', test_df=test_df):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].tolist()

    # Training set
    X_bow_matrix, dict = token_list_into_bow(X_train)

    # Target encoding
    mlb = MultiLabelBinarizer()
    y_encoded = mlb.fit_transform(y_train)

    # Create an SGDClassifier with default parameters
    sgd_clf = SGDClassifier(random_state=42)  # default loss='hinge', gives a linear SVM

    # Create a MultiOutputClassifier with the SGD classifier
    multi_output_classifier = MultiOutputClassifier(sgd_clf)

    # Fit the MultiOutputClassifier to your training data
    multi_output_classifier.fit(X_bow_matrix, y_encoded)

    # Evaluate the model using a scorer
    scorer = custom_jacc_scorer
    score = scorer(multi_output_classifier, X_bow_matrix, y_encoded)
    print("Score : ", score)

    return multi_output_classifier, mlb, dict


multi_output_classifier, mlb_30, dict_30 = sgd_classifier()

# tres bon score, bcp + rapide
# Out:
# Score :  0.9061662198391421

# %%
# predict (best score)

# %%
# using logistic reg

def sgd_classifier(train_df=train_df, feature='title_nltk', target='top_tags_30', test_df=test_df):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].tolist()

    # Training set
    X_bow_matrix, dict = token_list_into_bow(X_train)

    # Target encoding
    mlb = MultiLabelBinarizer()
    y_encoded = mlb.fit_transform(y_train)

    # Create an SGDClassifier with default parameters
    sgd_clf = SGDClassifier(random_state=42, loss='log_loss')  # for logistic regression

    # Create a MultiOutputClassifier with the SGD classifier
    multi_output_classifier = MultiOutputClassifier(sgd_clf)

    # Fit the MultiOutputClassifier to your training data
    multi_output_classifier.fit(X_bow_matrix, y_encoded)

    # Evaluate the model using a scorer
    scorer = custom_jacc_scorer
    score = scorer(multi_output_classifier, X_bow_matrix, y_encoded)
    print("Score : ", score)

    return multi_output_classifier, mlb, dict

multi_output_classifier, mlb_30, dict_30 = sgd_classifier()
# Out:
# Score :  0.8286513579671291

# %% [markdown]
# ### 3.3 Random forest

# %%
train_df, test_df = create_top_n_tags_feature(n=30, slice=10)

# %%
def random_forest_classifier(train_df=train_df, feature='title_nltk', target='top_tags_30', test_df=test_df):
    # Load your training data and labels
    X_train = train_df[feature].values
    y_train = train_df[target].tolist()

    # Training set
    X_bow_matrix, dict = token_list_into_bow(X_train)

    # Target encoding
    mlb = MultiLabelBinarizer()
    y_encoded = mlb.fit_transform(y_train)

    # Create a Random Forest Classifier with default parameters
    rf_clf = RandomForestClassifier(random_state=42)

    # Create a MultiOutputClassifier with the Random Forest Classifier
    multi_output_classifier = MultiOutputClassifier(rf_clf)

    # Fit the MultiOutputClassifier to your training data
    multi_output_classifier.fit(X_bow_matrix, y_encoded)

    # Evaluate the model using a scorer
    scorer = custom_jacc_scorer
    score = scorer(multi_output_classifier, X_bow_matrix, y_encoded)
    print("Score : ", score)

    return multi_output_classifier, mlb, dict


multi_output_classifier_rf, mlb_30_rf, dict_30_rf = random_forest_classifier()

# + lent
# score wow
# Out:
# Score :  0.9984263900221471

# %%
# pred

# %% [markdown]
# ## 4 Drift

# %%
raw_data['CreationDate'] = pd.to_datetime(raw_data['CreationDate'])

raw_data['year_month'] = raw_data['CreationDate'].map(lambda dt: dt.strftime('%Y-%m'))

print(raw_data['year_month'].min())
print(raw_data['year_month'].max())
# Out:
# 2011-05
# 2023-10

# %%
grouped_month = raw_data.groupby('year_month').size().to_frame("count_per_month").reset_index()

fig, ax = plt.subplots(figsize=(12, 3))  # Adjust the figsize as needed

grouped_month.plot(kind='bar', x='year_month', y='count_per_month', fontsize=12, ax=ax, width=0.8)
plt.title('nb questions par mois', fontsize=18, pad=20)
plt.legend(loc='upper right', fontsize=12)
plt.xticks(fontsize=5)
plt.show()

# %%
# Concernant l’analyse de la stabilité du modèle, il est attendu de prendre un dataset par mois de questions
# sur un an, et de mesurer l’évolution des mesures et scores du modèle défini, afin d’en conclure une
# stabilité ou pas d’un modèle de référence établi sur des questions antérieures à cette période.

# test rapide avec svm

month = []

unique_values = np.sort(raw_data['year_month'].unique())
print(len(unique_values))
# print(unique_values)

for mois in unique_values[:13]:
    month.append(raw_data.loc[raw_data['year_month'] == mois, :].copy())

print(len(month))
# Out:
# 150
# 13

# %%
display(month[1].head())
# Out:
#              CreationDate                                              title  \
# 46779 2011-06-30 23:47:29  How to train an artificial neural network to p...
# 46780 2011-06-30 23:08:02                        Rails Admin vs. ActiveAdmin
# 46781 2011-06-30 22:41:20  How to propagate PropertyChanged changes in De...
# 46782 2011-06-30 21:27:39     thread messaging system database schema design
# 46783 2011-06-30 21:09:11    Improve subplot size/spacing with many subplots
#
#                                                     body  \
# 46779  I'm currently trying to get an ANN to play a v...
# 46780  I've been looking into some rails admin plugin...
# 46781  I have a class which implements INotifyPropert...
# 46782  I'm trying to achieve exactly what's explained...
# 46783  I need to generate a whole bunch of vertically...
#
#                                                 all_tags  \
# 46779  [machine-learning, computer-vision, neural-net...
# 46780  [ruby-on-rails, ruby, ruby-on-rails-3, activea...
# 46781  [c#, wpf, xaml, data-binding, dependency-prope...
# 46782  [asp.net, database, linq, entity-framework, da...
# 46783     [python, pandas, matplotlib, seaborn, subplot]
#
#                                               title_nltk  \
# 46779                      [train, network, play, input]
# 46780                                      [rail, admin]
# 46781  [propagate, propertychanged, change, dependenc...
# 46782  [thread, message, system, database, schema, de...
# 46783          [improve, subplot, size, space, subplots]
#
#                                                body_nltk  \
# 46779  [train, network, play, input, try, get, ann, p...
# 46780  [rail, admin, look, rail, admin, plugins, come...
# 46781  [propagate, propertychanged, change, dependenc...
# 46782  [thread, message, system, database, schema, de...
# 46783  [improve, subplot, size, space, subplots, need...
#
#                                        title_spacy  \
# 46779                [train, network, play, input]
# 46780                                       [rail]
# 46781                          [propagate, change]
# 46782  [thread, message, system, database, design]
# 46783     [improve, subplot, size, space, subplot]
#
#                                               body_spacy  \
# 46779  [try, play, video, game, hope, help, community...
# 46780  [look, rail, admin, plugin, come, add, suggest...
# 46781  [class, implement, instance, class, declare, r...
# 46782  [try, achieve, explain, create, messaging, sys...
# 46783  [need, generate, bunch, stack, plot, matplotli...
#
#                                 top_tags_100          top_tags_50  \
# 46779                     [machine-learning]                   []
# 46780                  [ruby-on-rails, ruby]      [ruby-on-rails]
# 46781                              [c#, wpf]                 [c#]
# 46782  [asp.net, database, entity-framework]  [asp.net, database]
# 46783           [python, pandas, matplotlib]     [python, pandas]
#
#             top_tags_30 year_week year_month
# 46779                []   2011-26    2011-06
# 46780                []   2011-26    2011-06
# 46781              [c#]   2011-26    2011-06
# 46782         [asp.net]   2011-26    2011-06
# 46783  [python, pandas]   2011-26    2011-06

# %%
display(month[12].head()) # last one
# Out:
#              CreationDate                                              title  \
# 40141 2012-05-31 23:29:35                        GUI MySQL database frontend
# 40142 2012-05-31 21:50:23  JavaScript format number to day with always 3 ...
# 40143 2012-05-31 21:27:27                           Canvas drawImage scaling
# 40144 2012-05-31 20:40:47  Render embedded image in PDF using Flying-Sauc...
# 40145 2012-05-31 18:41:21                                Resize bitmap image
#
#                                                     body  \
# 40141  I have a slightly hopeless wish list for a pie...
# 40142  \nPossible Duplicate:\nHow can I create a Zero...
# 40143  I'm trying to scale an image proportionately t...
# 40144  I have an xhtml document that I'm turning into...
# 40145  I want to have smaller size at image saved. \n...
#
#                                                 all_tags  \
# 40141  [php, mysql, database, user-interface, web-app...
# 40142        [javascript, numbers, format, digits, days]
# 40143  [javascript, canvas, html5-canvas, resize, dra...
# 40144  [java, pdf-generation, embedded-resource, flyi...
# 40145                   [c#, wpf, image, bitmap, resize]
#
#                                      title_nltk  \
# 40141          [gui, mysql, database, frontend]
# 40142  [javascript, format, number, day, digit]
# 40143              [canvas, drawimage, scaling]
# 40144    [render, embed, image, pdf, fly, html]
# 40145                   [resize, bitmap, image]
#
#                                                body_nltk  \
# 40141  [gui, mysql, database, frontend, list, piece, ...
# 40142  [javascript, format, number, day, digit, dupli...
# 40143  [canvas, drawimage, scale, try, scale, image, ...
# 40144  [render, embed, image, pdf, fly, html, documen...
# 40145  [resize, image, want, size, image, save, resiz...
#
#                         title_spacy  \
# 40141   [mysql, database, frontend]
# 40142  [format, number, day, digit]
# 40143    [canvas, drawimage, scale]
# 40144     [embed, image, pdf, html]
# 40145               [resize, image]
#
#                                               body_spacy  \
# 40141  [wish, list, piece, software, know, exist, nee...
# 40142  [create, value, output, day, number, digit, wr...
# 40143  [try, scale, image, canvas, scale, fix, width,...
# 40144  [document, turn, pdf, tag, base64, encode, ima...
# 40145  [want, size, image, save, resize, use, code, i...
#
#                  top_tags_100             top_tags_50   top_tags_30 year_week  \
# 40141  [php, mysql, database]  [php, mysql, database]  [php, mysql]   2012-22
# 40142            [javascript]            [javascript]  [javascript]   2012-22
# 40143            [javascript]            [javascript]  [javascript]   2012-22
# 40144                  [java]                  [java]        [java]   2012-22
# 40145        [c#, wpf, image]                    [c#]          [c#]   2012-22
#
#       year_month
# 40141    2012-05
# 40142    2012-05
# 40143    2012-05
# 40144    2012-05
# 40145    2012-05

# %%
# add mlflow

svm, mlb, dict = sgd_classifier(train_df=month[1])

for i in range(2, 13):
    train_df = month[i]
    X_train = train_df['title_nltk'].values
    y_train = train_df['top_tags_30'].tolist()

    # Training set
    X_bow_matrix, _ = token_list_into_bow(X_train)

    # Target encoding
    y_encoded = mlb.fit_transform(y_train)

    score_next_month = custom_jacc_scorer(svm, X_bow_matrix, y_encoded)
    print(score_next_month)
# Out:
# Score :  0.9963235294117647
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 16
#      13 # Target encoding
#      14 y_encoded = mlb.fit_transform(y_train)
# ---> 16 score_next_month = custom_jacc_scorer(svm, X_bow_matrix, y_encoded)
#      17 print(score_next_month)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:266, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     263 if sample_weight is not None:
#     264     _kwargs["sample_weight"] = sample_weight
# --> 266 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:353, in _PredictScorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     316 """Evaluate predicted target values for X relative to y_true.
#     317
#     318 Parameters
#    (...)
#     343     Score function applied to prediction of estimator on X.
#     344 """
#     345 self._warn_overlap(
#     346     message=(
#     347         "There is an overlap between set kwargs of this scorer instance and"
#    (...)
#     351     kwargs=kwargs,
#     352 )
# --> 353 y_pred = method_caller(estimator, "predict", X)
#     354 scoring_kwargs = {**self._kwargs, **kwargs}
#     355 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:86, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      83 if cache is not None and response_method in cache:
#      84     return cache[response_method]
# ---> 86 result, _ = _get_response_values(
#      87     estimator, *args, response_method=response_method, **kwargs
#      88 )
#      90 if cache is not None:
#      91     cache[response_method] = result
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/utils/_response.py:85, in _get_response_values(estimator, X, response_method, pos_label)
#      82 elif pos_label is None and target_type == "binary":
#      83     pos_label = pos_label if pos_label is not None else classes[-1]
# ---> 85 y_pred = prediction_method(X)
#      86 if prediction_method.__name__ == "predict_proba":
#      87     if target_type == "binary" and y_pred.shape[1] <= 2:
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/multioutput.py:305, in _MultiOutputEstimator.predict(self, X)
#     302 if not hasattr(self.estimators_[0], "predict"):
#     303     raise ValueError("The base estimator should implement a predict method")
# --> 305 y = Parallel(n_jobs=self.n_jobs)(
#     306     delayed(e.predict)(X) for e in self.estimators_
#     307 )
#     309 return np.asarray(y).T
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/linear_model/_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/linear_model/_base.py:432, in LinearClassifierMixin.decision_function(self, X)
#     429 check_is_fitted(self)
#     430 xp, _ = get_namespace(X)
# --> 432 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     433 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     434 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/base.py:625, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
# --> 625     self._check_n_features(X, reset=reset)
#     627 return out
#
# File ~/anaconda3/envs/myenv_p5/lib/python3.11/site-packages/sklearn/base.py:414, in BaseEstimator._check_n_features(self, X, reset)
#     411     return
#     413 if n_features != self.n_features_in_:
# --> 414     raise ValueError(
#     415         f"X has {n_features} features, but {self.__class__.__name__} "
#     416         f"is expecting {self.n_features_in_} features as input."
#     417     )
#
# ValueError: X has 1055 features, but SGDClassifier is expecting 1126 features as input.

# %% [markdown]
# ## Deep learning Models
