# %% [markdown]
# # **Catégorisez automatiquement des questions**
#
# ## partie 2/? : requête API
#
# ### <br> Un notebook de requête API, qui récupère 50 questions par requête via le wrapper StackAPI ou bien via Stack Exchange API, et qui stocke les principales caractéristiques de ces questions dans un DataFrame.
#
# > &emsp; <br><br>

# %% [markdown]
# ## Imports

# %%
import requests
import datetime
import pandas as pd

# %% [markdown]
# ## Requete API, via Stack Exchange API

# %%
# "réaliser une requête de 50 questions sur une période définie, contenant le tag “python”
# et qui ont un score > 50 (votes), récupérer les données principales de la question
# (date, titre, tags, score) dans un DataFrame et les afficher"

# Authentification
# Pas nécessaire ici, nous avons droit à 10 000 requêtes(lecture)/j sans OAuth 2.0
# L' OAuth 2.0 concerne seulement les requetes en écriture

# %%
# RGPD
# Nous n'avons aucune raison d'extraire des données personnelles ici, donc nous eviterons non seulement
# certaines colonnes evidentes, par exemple :
# OwnerUserId, OwnerDisplayName, LastEditorUserId, LastEditorDisplayName, etc...
# mais aussi la clé primaire (l'id), qui permettrait de les retrouver
# (notre cle primaire, si nous en avons besoin, sera simplement l'index de notre dataframe)

# Nous allons donc commencer par créer un filtre.
# On peut le faire depuis https://api.stackexchange.com/docs/create-filter,
# Ou directement depuis ce notebook, en utilisant par exemple le module requests.

api_filter_url = 'https://api.stackexchange.com/2.3/filters/create'
filter_params = {
    'include': 'creation_date,title,tags,score',
    'unsafe': 'false',
}

response = requests.get(api_filter_url, params=filter_params)
data = response.json()
print(data)
# Out:
# {'items': [{'included_fields': ['.backoff', '.error_id', '.error_message', '.error_name', '.has_more', '.items', '.quota_max', '.quota_remaining', 'access_token.access_token', 'access_token.account_id', 'access_token.expires_on_date', 'access_token.scope', 'account_merge.merge_date', 'account_merge.new_account_id', 'account_merge.old_account_id', 'achievement.account_id', 'achievement.achievement_type', 'achievement.badge_rank', 'achievement.creation_date', 'achievement.is_unread', 'achievement.link', 'achievement.on_site', 'achievement.reputation_change', 'achievement.title', 'answer.answer_id', 'answer.collectives', 'answer.community_owned_date', 'answer.content_license', 'answer.creation_date', 'answer.is_accepted', 'answer.last_activity_date', 'answer.last_edit_date', 'answer.locked_date', 'answer.owner', 'answer.posted_by_collectives', 'answer.question_id', 'answer.recommendations', 'answer.score', 'article.article_id', 'article.article_type', 'article.creation_date', 'article.last_activity_date', 'article.last_edit_date', 'article.link', 'article.owner', 'article.score', 'article.tags', 'article.title', 'article.view_count', 'badge.award_count', 'badge.badge_id', 'badge.badge_type', 'badge.link', 'badge.name', 'badge.rank', 'badge.user', 'badge_count.bronze', 'badge_count.gold', 'badge_count.silver', 'closed_details.by_users', 'closed_details.description', 'closed_details.on_hold', 'closed_details.original_questions', 'closed_details.reason', 'collective.description', 'collective.external_links', 'collective.link', 'collective.name', 'collective.slug', 'collective.tags', 'collective_external_link.link', 'collective_external_link.type', 'collective_membership.collective', 'collective_membership.role', 'collective_recommendation.collective', 'collective_recommendation.creation_date', 'collective_report.collective', 'collective_report.creation_date', 'collective_report.dimensions', 'collective_report.download_link', 'collective_report.end_date', 'collective_report.included_tags', 'collective_report.metrics', 'collective_report.name', 'collective_report.report_id', 'collective_report.report_type', 'collective_report.start_date', 'collective_report.state', 'comment.comment_id', 'comment.content_license', 'comment.creation_date', 'comment.edited', 'comment.owner', 'comment.parent_comment_id', 'comment.post_id', 'comment.post_state', 'comment.reply_to_user', 'comment.score', 'error.description', 'error.error_id', 'error.error_name', 'event.creation_date', 'event.event_id', 'event.event_type', 'exchanged_access_token.access_token', 'exchanged_access_token.account_id', 'exchanged_access_token.exchange_type', 'exchanged_access_token.expires_on_date', 'exchanged_access_token.original_access_token', 'exchanged_access_token.scope', 'filter.filter', 'filter.filter_type', 'filter.included_fields', 'flag_option.count', 'flag_option.description', 'flag_option.dialog_title', 'flag_option.has_flagged', 'flag_option.is_retraction', 'flag_option.option_id', 'flag_option.requires_comment', 'flag_option.requires_question_id', 'flag_option.requires_site', 'flag_option.sub_options', 'flag_option.title', 'inbox_item.answer_id', 'inbox_item.comment_id', 'inbox_item.creation_date', 'inbox_item.is_unread', 'inbox_item.item_type', 'inbox_item.link', 'inbox_item.question_id', 'inbox_item.site', 'inbox_item.title', 'info.answers_per_minute', 'info.api_revision', 'info.badges_per_minute', 'info.new_active_users', 'info.questions_per_minute', 'info.total_accepted', 'info.total_answers', 'info.total_badges', 'info.total_comments', 'info.total_questions', 'info.total_unanswered', 'info.total_users', 'info.total_votes', 'migration_info.on_date', 'migration_info.other_site', 'migration_info.question_id', 'network_activity.account_id', 'network_activity.activity_type', 'network_activity.api_site_parameter', 'network_activity.badge_id', 'network_activity.creation_date', 'network_activity.description', 'network_activity.link', 'network_activity.post_id', 'netwo ...

# %%
# ??

api_filter_url = 'https://api.stackexchange.com/2.3/filters/create'
filter_params = {
    'include': 'creation_date,title,tags,score',
    'unsafe': 'false',
}

response = requests.post(api_filter_url, data=filter_params)
data = response.json()
print(data)
# Out:
# {'items': [{'included_fields': ['.backoff', '.error_id', '.error_message', '.error_name', '.has_more', '.items', '.quota_max', '.quota_remaining', 'access_token.access_token', 'access_token.account_id', 'access_token.expires_on_date', 'access_token.scope', 'account_merge.merge_date', 'account_merge.new_account_id', 'account_merge.old_account_id', 'achievement.account_id', 'achievement.achievement_type', 'achievement.badge_rank', 'achievement.creation_date', 'achievement.is_unread', 'achievement.link', 'achievement.on_site', 'achievement.reputation_change', 'achievement.title', 'answer.answer_id', 'answer.collectives', 'answer.community_owned_date', 'answer.content_license', 'answer.creation_date', 'answer.is_accepted', 'answer.last_activity_date', 'answer.last_edit_date', 'answer.locked_date', 'answer.owner', 'answer.posted_by_collectives', 'answer.question_id', 'answer.recommendations', 'answer.score', 'article.article_id', 'article.article_type', 'article.creation_date', 'article.last_activity_date', 'article.last_edit_date', 'article.link', 'article.owner', 'article.score', 'article.tags', 'article.title', 'article.view_count', 'badge.award_count', 'badge.badge_id', 'badge.badge_type', 'badge.link', 'badge.name', 'badge.rank', 'badge.user', 'badge_count.bronze', 'badge_count.gold', 'badge_count.silver', 'closed_details.by_users', 'closed_details.description', 'closed_details.on_hold', 'closed_details.original_questions', 'closed_details.reason', 'collective.description', 'collective.external_links', 'collective.link', 'collective.name', 'collective.slug', 'collective.tags', 'collective_external_link.link', 'collective_external_link.type', 'collective_membership.collective', 'collective_membership.role', 'collective_recommendation.collective', 'collective_recommendation.creation_date', 'collective_report.collective', 'collective_report.creation_date', 'collective_report.dimensions', 'collective_report.download_link', 'collective_report.end_date', 'collective_report.included_tags', 'collective_report.metrics', 'collective_report.name', 'collective_report.report_id', 'collective_report.report_type', 'collective_report.start_date', 'collective_report.state', 'comment.comment_id', 'comment.content_license', 'comment.creation_date', 'comment.edited', 'comment.owner', 'comment.parent_comment_id', 'comment.post_id', 'comment.post_state', 'comment.reply_to_user', 'comment.score', 'error.description', 'error.error_id', 'error.error_name', 'event.creation_date', 'event.event_id', 'event.event_type', 'exchanged_access_token.access_token', 'exchanged_access_token.account_id', 'exchanged_access_token.exchange_type', 'exchanged_access_token.expires_on_date', 'exchanged_access_token.original_access_token', 'exchanged_access_token.scope', 'filter.filter', 'filter.filter_type', 'filter.included_fields', 'flag_option.count', 'flag_option.description', 'flag_option.dialog_title', 'flag_option.has_flagged', 'flag_option.is_retraction', 'flag_option.option_id', 'flag_option.requires_comment', 'flag_option.requires_question_id', 'flag_option.requires_site', 'flag_option.sub_options', 'flag_option.title', 'inbox_item.answer_id', 'inbox_item.comment_id', 'inbox_item.creation_date', 'inbox_item.is_unread', 'inbox_item.item_type', 'inbox_item.link', 'inbox_item.question_id', 'inbox_item.site', 'inbox_item.title', 'info.answers_per_minute', 'info.api_revision', 'info.badges_per_minute', 'info.new_active_users', 'info.questions_per_minute', 'info.total_accepted', 'info.total_answers', 'info.total_badges', 'info.total_comments', 'info.total_questions', 'info.total_unanswered', 'info.total_users', 'info.total_votes', 'migration_info.on_date', 'migration_info.other_site', 'migration_info.question_id', 'network_activity.account_id', 'network_activity.activity_type', 'network_activity.api_site_parameter', 'network_activity.badge_id', 'network_activity.creation_date', 'network_activity.description', 'network_activity.link', 'network_activity.post_id', 'netwo ...

# %%
# Apparemment la stack exchange API inclue des champs par defaut, la doc conseille de filtrer
# manuellement la reponse

# %%
# Usage of /questions GET
# Gets all the questions on the site.

# interessant ?
# questions/featured     Get all questions on the site with active bounties.
# questions/unanswered   Get all questions the site considers unanswered.

# %%
# On peut utiliser directement l'outil en ligne, qui fournit une reponse de 100 questions max,
# format JSON compressé.
# exemple de la doc :
# /2.3/questions?fromdate=1320969600&todate=1321660800&order=desc&min=10&sort=votes&tagged=skyrim&site=gaming

# Avant de récupérer nos questions, nous pouvons d'abord nous faire une idée du nombre de questions
# qui satisfont nos critères sur une période donnée.

# Pour cela il y a plusieurs stratégies possibles,
# on peut par exemple utiiser le filtre "total" (built-in)
# Ou la méthode/endpoint "search" (plus flexible)
# Comme nous allons au final récupérer des questions, utilisons directement la méthode questions

# %%
# All dates in the API are in unix epoch time

def get_number_of_questions(tag, start_date, end_date, min_score=50):
    api_url = 'https://api.stackexchange.com/2.3/questions'

    params = {
        'order': 'desc',
        'sort': 'votes',
        'tagged': tag,
        'site': 'stackoverflow',
        'fromdate': int(start_date.timestamp()),
        'todate': int(end_date.timestamp()),
        'min': min_score,
        'pagesize': 100  # 30 par défaut, 100 max
    }

    response = requests.get(api_url, params=params)
    data = response.json()
    display(data)

    if 'items' in data:
        return len(data['items'])
    else:
        return 0

# Observons l'activité cette année
tag = 'python'
start_date = datetime.datetime(2023, 1, 1)
end_date = datetime.datetime(2023, 11, 27)

result = get_number_of_questions(tag, start_date, end_date)
print(f'Number of questions with the tag "{tag}" between {start_date} and {end_date} and a minimum score of 50: \n{result}')
# Out:
# {'items': [{'tags': ['python', 'error-handling', 'pip'],
#    'owner': {'account_id': 23480036,
#     'reputation': 1614,
#     'user_id': 17532318,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d37672946ecec10b2814be93daa910ef?s=256&d=identicon&r=PG',
#     'display_name': 'Apoliticalboy',
#     'link': 'https://stackoverflow.com/users/17532318/apoliticalboy'},
#    'is_answered': True,
#    'view_count': 224796,
#    'answer_count': 17,
#    'score': 150,
#    'last_activity_date': 1700813401,
#    'creation_date': 1677700339,
#    'last_edit_date': 1694084649,
#    'question_id': 75608323,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75608323/how-do-i-solve-error-externally-managed-environment-every-time-i-use-pip-3',
#    'title': 'How do I solve &quot;error: externally-managed-environment&quot; every time I use pip 3?'},
#   {'tags': ['python', 'pandas', 'dataframe', 'attributeerror'],
#    'owner': {'account_id': 18651684,
#     'reputation': 1673,
#     'user_id': 13595011,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gja1Bf3zfNP7LY4HSFgp6beG2pul2AVcXIsoLC52g=k-s256',
#     'display_name': 'Maksimjeet Chowdhary',
#     'link': 'https://stackoverflow.com/users/13595011/maksimjeet-chowdhary'},
#    'is_answered': True,
#    'view_count': 261517,
#    'protected_date': 1695993982,
#    'answer_count': 3,
#    'score': 149,
#    'last_activity_date': 1699567288,
#    'creation_date': 1680851159,
#    'last_edit_date': 1691967377,
#    'question_id': 75956209,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75956209/error-dataframe-object-has-no-attribute-append',
#    'title': 'Error &quot;&#39;DataFrame&#39; object has no attribute &#39;append&#39;&quot;'},
#   {'tags': ['python', 'flask', 'pytest', 'werkzeug'],
#    'owner': {'account_id': 20745029,
#     'reputation': 1501,
#     'user_id': 15233792,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/2ol6b.jpg?s=256&g=1',
#     'display_name': 'stevezkw',
#     'link': 'https://stackoverflow.com/users/15233792/stevezkw'},
#    'is_answered': True,
#    'view_count': 59292,
#    'protected_date': 1698079880,
#    'accepted_answer_id': 77214086,
#    'answer_count': 6,
#    'score': 100,
#    'last_activity_date': 1700174126,
#    'creation_date': 1696215720,
#    'last_edit_date': 1700174126,
#    'question_id': 77213053,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/77213053/why-did-flask-start-failing-with-importerror-cannot-import-name-url-quote-fr',
#    'title': 'Why did Flask start failing with &quot;ImportError: cannot import name &#39;url_quote&#39; from &#39;werkzeug.urls&#39;&quot;?'},
#   {'tags': ['python', 'openai-api', 'urllib3'],
#    'owner': {'account_id': 11229285,
#     'reputation': 1043,
#     'user_id': 8237910,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-OajeBMxDGMo/AAAAAAAAAAI/AAAAAAAAAmQ/8vm8L0FQK1c/photo.jpg?sz=256',
#     'display_name': 'prismwatermelon',
#     'link': 'https://stackoverflow.com/users/8237910/prismwatermelon'},
#    'is_answered': True,
#    'view_count': 191532,
#    'accepted_answer_id': 76187415,
#    'answer_count': 12,
#    'score': 94,
#    'last_activity_date': 1699962924,
#    'creation_date': 1683349902,
#    'last_edit_date': 1691972425,
#    'question_id': 76187256,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76187256/importerror-urllib3-v2-0-only-supports-openssl-1-1-1-currently-the-ssl-modu',
#    'title': 'ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the &#39;ssl&#39; module is compiled with LibreSSL 2.8.3'},
#   {'tags': ['python', 'prompt', 'openai-api', 'completion', 'chatgpt-api'],
#    'owner': {'account_id': 3235065,
#     'reputation': 1732,
#     'user_id': 3018860,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/edec84abcde58e8f5d45a7e5522ff1e1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Unix',
#     'link': 'https://stackoverflow.com/users/3018860/unix'},
#    'is_answered': True,
#    'view_count': 203761,
#    'closed_date': 1685124780,
#    'accepted_answer_id': 75898717,
#    'answer_count': 5,
#    'score': 94,
#    'last_activity_date': 1697273724,
#    'creation_date': 1680263884,
#    'last_edit_date': 1691966958,
#    'question_id': 75898276,
#    'link': 'https://stackoverflow.com/questions/75898276/openai-chatgpt-gpt-3-5-api-error-429-you-exceeded-your-current-quota-please',
#    'closed_reason': 'Not suitable for this site',
#    'title': 'OpenAI ChatGPT (GPT-3.5) API error 429: &quot;You exceeded your current quota, please check your plan and billing details&quot;'},
#   {'tags': ['python', 'ubuntu', 'pip', 'wsl-2'],
#    'owner': {'account_id': 7752222,
#     'reputation': 997,
#     'user_id': 6799513,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Bha40.jpg?s=256&g=1',
#     'display_name': 'patrick',
#     'link': 'https://stackoverflow.com/users/6799513/patrick'},
#    'is_answered': True,
#    'view_count': 75721,
#    'accepted_answer_id': 75053968,
#    'answer_count': 3,
#    'score': 79,
#    'last_activity_date': 1687280443,
#    'creation_date': 1672657056,
#    'last_edit_date': 1672657567,
#    'question_id': 74981558,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74981558/error-updating-python3-pip-attributeerror-module-lib-has-no-attribute-openss',
#    'title': 'Error Updating Python3 pip AttributeError: module &#39;lib&#39; has no attribute &#39;OpenSSL_add_all_algorithms&#39;'},
#   {'tags': ['python', 'ffmpeg', 'discord', 'youtube-dl'],
#    'owner': {'account_id': 27587346,
#     'reputation': 778,
#     'user_id': 21055247,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp68sX4uwH8oI00wq1qnsHwmhUC3m9kFQUea4JSE=k-s256',
#     'display_name': 'nikita goncharov',
#     'link': 'https://stackoverflow.com/users/21055247/nikita-goncharov'},
#    'is_answered': True,
#    'view_count': 88599,
#    'accepted_answer_id': 75504772,
#    'answer_count': 9,
#    'score': 77,
#    'last_activity_date': 1700757654,
#    'creation_date': 1676747963,
#    'last_edit_date': 1700757654,
#    'question_id': 75495800,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75495800/error-unable-to-extract-uploader-id-youtube-discord-py',
#    'title': 'Error: Unable to extract uploader id - Youtube, Discord.py'},
#   {'tags': ['python', 'pre-commit', 'pre-commit.com', 'isort'],
#    'owner': {'account_id': 8247924,
#     'reputation': 5955,
#     'user_id': 6203472,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6854a8b5ed6ad561c0ab878c7558fb26?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'bagerard',
#     'link': 'https://stackoverflow.com/users/6203472/bagerard'},
#    'is_answered': True,
#    'view_count': 13024,
#    'accepted_answer_id': 75269701,
#    'answer_count': 5,
#    'score': 70,
#    'last_activity_date': 1678725721,
#    'creation_date': 1674928449,
#    'last_edit_date': 1675093819,
#    'question_id': 75269700,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75269700/pre-commit-fails-to-install-isort-5-11-4-with-error-runtimeerror-the-poetry-co',
#    'title': 'pre-commit fails to install isort 5.11.4 with error &quot;RuntimeError: The Poetry configuration is invalid&quot;'},
#   {'tags': ['python', 'python-poetry'],
#    'owner': {'account_id': 5622044,
#     'reputation': 7934,
#     'user_id': 4451521,
#     'user_type': 'registered',
#     'accept_rate': 34,
#     'profile_image': 'https://www.gravatar.com/avatar/4b19b54142d820aad565ca95f920c11c?s=256&d=identicon&r=PG',
#     'display_name': 'KansaiRobot',
#     'link': 'https://stackoverflow.com/users/4451521/kansairobot'},
#    'is_answered': True,
#    'view_count': 35904,
#    'answer_count': 4,
#    'score': 62,
#    'last_activity_date': 1676545701,
#    'creation_date': 1675940902,
#    'question_id': 75397736,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75397736/poetry-install-on-an-existing-project-error-does-not-contain-any-element',
#    'title': 'Poetry install on an existing project Error &quot;does not contain any element&quot;'},
#   {'tags': ['python', 'arrays', 'performance', 'cpython', 'python-internals'],
#    'owner': {'account_id': 17476274,
#     'reputation': 24756,
#     'user_id': 12671057,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/90d2e6942c69df199a95d06e0c8e9a10?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Kelly Bundy',
#     'link': 'https://stackoverflow.com/users/12671057/kelly-bundy'},
#    'is_answered': True,
#    'view_count': 6095,
#    'protected_date': 1676116638,
#    'accepted_answer_id': 75354915,
#    'answer_count': 2,
#    'score': 57,
#    'last_activity_date': 1676242955,
#    'creation_date': 1675620257,
#    'last_edit_date': 1675774367,
#    'question_id': 75354384,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75354384/why-is-b-pop0-over-200-times-slower-than-del-b0-for-bytearray',
#    'title': 'Why is b.pop(0) over 200 times slower than del b[0] for bytearray?'}],
#  'has_more': False,
#  'quota_max': 300,
#  'quota_remaining': 187}
# Number of questions with the tag "python" between 2023-01-01 00:00:00 and 2023-11-27 00:00:00 and a minimum score of 50:
# 10

# %%
# Seulement 10 questions crées avec le tag python et un score > 50 (en presque un an)

# Observons l'activité l'année dernière
start_date = datetime.datetime(2022, 1, 1)
end_date = datetime.datetime(2022, 12, 31)

result = get_number_of_questions(tag, start_date, end_date)
print(f'Number of questions with the tag "{tag}" between {start_date} and {end_date} and a minimum score of 50: \n{result}')

# Il faut du temps pour que le score atteigne 50, mais le traffic sur stack exchange a
# peut-être aussi diminué depuis l'année dernière (arrivée de chatGPT, etc...)
# Out:
# {'items': [{'tags': ['python',
#     'macos',
#     'terminal',
#     'atom-editor',
#     'macos-monterey'],
#    'owner': {'account_id': 24663681,
#     'reputation': 3226,
#     'user_id': 18559642,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/13cdab4eb9d9fb5b1c7dece549f96046?s=256&d=identicon&r=PG',
#     'display_name': 'Kirill Ignatyev',
#     'link': 'https://stackoverflow.com/users/18559642/kirill-ignatyev'},
#    'is_answered': True,
#    'view_count': 370728,
#    'protected_date': 1673118234,
#    'accepted_answer_id': 71621142,
#    'answer_count': 18,
#    'score': 197,
#    'last_activity_date': 1675219189,
#    'creation_date': 1648058522,
#    'last_edit_date': 1656277606,
#    'question_id': 71591971,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71591971/how-can-i-fix-the-zsh-command-not-found-python-error-macos-monterey-12-3',
#    'title': 'How can I fix the &quot;zsh: command not found: python&quot; error? (macOS Monterey 12.3, Python&amp;nbsp;3.10, Atom IDE, and atom-python-run 0.9.7)'},
#   {'tags': ['python', 'tensorflow', 'ray'],
#    'owner': {'account_id': 22989345,
#     'reputation': 1981,
#     'user_id': 17115086,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/16c137f7793988efb97ab410f7aec4f6?s=256&d=identicon&r=PG',
#     'display_name': 'hasu33',
#     'link': 'https://stackoverflow.com/users/17115086/hasu33'},
#    'is_answered': True,
#    'view_count': 274176,
#    'protected_date': 1689017298,
#    'answer_count': 16,
#    'score': 193,
#    'last_activity_date': 1698317855,
#    'creation_date': 1653965255,
#    'last_edit_date': 1656248470,
#    'question_id': 72441758,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72441758/typeerror-descriptors-cannot-not-be-created-directly',
#    'title': 'TypeError: Descriptors cannot not be created directly'},
#   {'tags': ['python', 'python-black'],
#    'owner': {'account_id': 13900281,
#     'reputation': 11703,
#     'user_id': 10036039,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8790cbc891c02fffb597317b43a063fa?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'zerocewl',
#     'link': 'https://stackoverflow.com/users/10036039/zerocewl'},
#    'is_answered': True,
#    'view_count': 79903,
#    'accepted_answer_id': 71674345,
#    'answer_count': 6,
#    'score': 174,
#    'last_activity_date': 1679491903,
#    'creation_date': 1648626375,
#    'last_edit_date': 1651785651,
#    'question_id': 71673404,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71673404/importerror-cannot-import-name-unicodefun-from-click',
#    'title': 'ImportError: cannot import name &#39;_unicodefun&#39; from &#39;click&#39;'},
#   {'tags': ['python', 'machine-learning', 'package', 'conda', 'python-poetry'],
#    'owner': {'account_id': 1449869,
#     'reputation': 2561,
#     'user_id': 1367124,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://i.stack.imgur.com/azGrD.jpg?s=256&g=1',
#     'display_name': 'Seub',
#     'link': 'https://stackoverflow.com/users/1367124/seub'},
#    'is_answered': True,
#    'view_count': 61264,
#    'accepted_answer_id': 71110028,
#    'answer_count': 3,
#    'score': 142,
#    'last_activity_date': 1699380700,
#    'creation_date': 1643123383,
#    'last_edit_date': 1643126235,
#    'question_id': 70851048,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70851048/does-it-make-sense-to-use-conda-poetry',
#    'title': 'Does it make sense to use Conda + Poetry?'},
#   {'tags': ['python', 'pandas', 'dataframe', 'data-wrangling', 'data-munging'],
#    'owner': {'account_id': 29727,
#     'reputation': 4413,
#     'user_id': 80544,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.stack.imgur.com/HtN07.jpg?s=256&g=1',
#     'display_name': 'Glenn',
#     'link': 'https://stackoverflow.com/users/80544/glenn'},
#    'is_answered': True,
#    'view_count': 175243,
#    'accepted_answer_id': 70837545,
#    'answer_count': 8,
#    'score': 142,
#    'last_activity_date': 1690552412,
#    'creation_date': 1643042804,
#    'last_edit_date': 1645482240,
#    'question_id': 70837397,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70837397/good-alternative-to-pandas-append-method-now-that-it-is-being-deprecated',
#    'title': 'Good alternative to Pandas .append() method, now that it is being deprecated?'},
#   {'tags': ['python', 'google-analytics-api'],
#    'owner': {'account_id': 6468208,
#     'reputation': 6455,
#     'user_id': 5009293,
#     'user_type': 'registered',
#     'accept_rate': 76,
#     'profile_image': 'https://graph.facebook.com/995762863775266/picture?type=large',
#     'display_name': 'Doug Coats',
#     'link': 'https://stackoverflow.com/users/5009293/doug-coats'},
#    'is_answered': True,
#    'view_count': 205518,
#    'accepted_answer_id': 73932621,
#    'answer_count': 18,
#    'score': 128,
#    'last_activity_date': 1693903144,
#    'creation_date': 1663949925,
#    'last_edit_date': 1663952437,
#    'question_id': 73830524,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73830524/attributeerror-module-lib-has-no-attribute-x509-v-flag-cb-issuer-check',
#    'title': 'AttributeError: module &#39;lib&#39; has no attribute &#39;X509_V_FLAG_CB_ISSUER_CHECK&#39;'},
#   {'tags': ['python',
#     'docker',
#     'docker-compose',
#     'dependencies',
#     'importerror'],
#    'owner': {'account_id': 3369545,
#     'reputation': 3171,
#     'user_id': 2829150,
#     'user_type': 'registered',
#     'accept_rate': 51,
#     'profile_image': 'https://www.gravatar.com/avatar/1e9c788890b3d2a8e468ed2773864b2c?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Arie',
#     'link': 'https://stackoverflow.com/users/2829150/arie'},
#    'is_answered': True,
#    'view_count': 152032,
#    'protected_date': 1691442712,
#    'answer_count': 15,
#    'score': 117,
#    'last_activity_date': 1699634829,
#    'creation_date': 1652208276,
#    'last_edit_date': 1667754370,
#    'question_id': 72191560,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72191560/importerror-cannot-import-name-soft-unicode-from-markupsafe',
#    'title': 'ImportError: cannot import name &#39;soft_unicode&#39; from &#39;markupsafe&#39;'},
#   {'tags': ['python',
#     'selenium',
#     'google-chrome',
#     'selenium-webdriver',
#     'selenium-chromedriver'],
#    'owner': {'account_id': 19488994,
#     'reputation': 1083,
#     'user_id': 14257612,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c49440f3d6f3831211bcb56d9614a61e?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Alesss',
#     'link': 'https://stackoverflow.com/users/14257612/alesss'},
#    'is_answered': True,
#    'view_count': 251439,
#    'accepted_answer_id': 72773269,
#    'answer_count': 4,
#    'score': 108,
#    'last_activity_date': 1700498304,
#    'creation_date': 1656337711,
#    'last_edit_date': 1661689426,
#    'question_id': 72773206,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72773206/selenium-python-attributeerror-webdriver-object-has-no-attribute-find-el',
#    'title': 'Selenium - Python - AttributeError: &#39;WebDriver&#39; object has no attribute &#39;find_element_by_name&#39;'},
#   {'tags': ['python', 'linux', 'openssl', 'python-poetry'],
#    'owner': {'account_id': 7489950,
#     'reputation': 4646,
#     'user_id': 5692012,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.stack.imgur.com/a3FwR.gif?s=256&g=1',
#     'display_name': 'RobinFrcd',
#     'link': 'https://stackoverflow.com/users/5692012/robinfrcd'},
#    'is_answered': True,
#    'view_count': 193080,
#    'accepted_answer_id': 72633324,
#    'answer_count': 14,
#    'score': 107,
#    'last_activity_date': 1699036115,
#    'creation_date': 1651782719,
#    'last_edit_date': 1675089528,
#    'question_id': 72133316,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72133316/libssl-so-1-1-cannot-open-shared-object-file-no-such-file-or-directory',
#    'title': 'libssl.so.1.1: cannot open shared object file: No such file or directory'},
#   {'tags': ['python', 'windows', 'visual-studio-2022'],
#    'owner': {'account_id': 2813476,
#     'reputation': 1813,
#     'user_id': 2419205,
#     'user_type': 'registered',
#     'accept_rate': 52,
#     'profile_image': 'https://www.gravatar.com/avatar/5a4b5ff5c0d06ba079e8d974dd8309b4?s=256&d=identicon&r=PG',
#     'display_name': 'Starfleet Security',
#     'link': 'https://stackoverflow.com/users/2419205/starfleet-security'},
#    'is_answered': True,
#    'view_count': 7130,
#    'answer_count': 9,
#    'score': 105,
#    'last_activity_date': 1668277374,
#    'creation_date': 1645204638,
#    'last_edit_date': 1648802107,
#    'question_id': 71177450,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71177450/unable-to-restore-visual-studio-2022-window-ide-itself-after-minimizing',
#    'title': 'Unable to restore Visual Studio 2022 window (IDE itself) after minimizing'},
#   {'tags': ['python',
#     'string',
#     'reference',
#     'immutability',
#     'string-concatenation'],
#    'owner': {'account_id': 6666507,
#     'reputation': 1245,
#     'user_id': 5144013,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://lh3.googleusercontent.com/-gaua46VyxKQ/AAAAAAAAAAI/AAAAAAAAHxg/M-29RPq_C6E/photo.jpg?sz=256',
#     'display_name': 'Master_Roshy',
#     'link': 'https://stackoverflow.com/users/5144013/master-roshy'},
#    'is_answered': True,
#    'view_count': 6831,
#    'protected_date': 1657262192,
#    'answer_count': 4,
#    'score': 102,
#    'last_activity_date': 1657261330,
#    'creation_date': 1654830500,
#    'last_edit_date': 1654982358,
#    'question_id': 72568719,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72568719/if-python-strings-are-immutable-why-does-it-keep-the-same-id-if-i-use-to-app',
#    'title': 'If Python strings are immutable, why does it keep the same id if I use += to append to it?'},
#   {'tags': ['python', 'cpython', 'python-internals'],
#    'owner': {'account_id': 17476274,
#     'reputation': 24756,
#     'user_id': 12671057,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/90d2e6942c69df199a95d06e0c8e9a10?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Kelly Bundy',
#     'link': 'https://stackoverflow.com/users/12671057/kelly-bundy'},
#    'is_answered': True,
#    'view_count': 8221,
#    'closed_date': 1643494282,
#    'answer_count': 3,
#    'score': 101,
#    'last_activity_date': 1644084297,
#    'creation_date': 1643300597,
#    'last_edit_date': 1644083484,
#    'question_id': 70882092,
#    'link': 'https://stackoverflow.com/questions/70882092/can-we-make-1-2-true',
#    'closed_reason': 'Duplicate',
#    'title': 'Can we make 1 == 2 true?'},
#   {'tags': ['python', 'c++', 'python-3.x', 'rounding', 'integer-division'],
#    'owner': {'account_id': 7923772,
#     'reputation': 7078,
#     'user_id': 5983841,
#     'user_type': 'registered',
#     'accept_rate': 62,
#     'profile_image': 'https://i.stack.imgur.com/GHJxG.jpg?s=256&g=1',
#     'display_name': 'Rick',
#     'link': 'https://stackoverflow.com/users/5983841/rick'},
#    'is_answered': True,
#    'view_count': 8310,
#    'accepted_answer_id': 70735005,
#    'answer_count': 8,
#    'score': 88,
#    'last_activity_date': 1660790087,
#    'creation_date': 1642342052,
#    'last_edit_date': 1643506145,
#    'question_id': 70730831,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70730831/whats-the-mathematical-reason-behind-python-choosing-to-round-integer-division',
#    'title': 'What&#39;s the mathematical reason behind Python choosing to round integer division toward negative infinity?'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 15449541,
#     'reputation': 973,
#     'user_id': 17660775,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2328891030722501/picture?type=large',
#     'display_name': 'Abdeldjalil Sekkal',
#     'link': 'https://stackoverflow.com/users/17660775/abdeldjalil-sekkal'},
#    'is_answered': True,
#    'view_count': 154116,
#    'protected_date': 1676571122,
#    'answer_count': 10,
#    'score': 82,
#    'last_activity_date': 1698355404,
#    'creation_date': 1653937478,
#    'last_edit_date': 1654222298,
#    'question_id': 72439001,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72439001/there-was-an-error-checking-the-latest-version-of-pip',
#    'title': 'There was an error checking the latest version of pip'},
#   {'tags': ['python', 'performance', 'comparison'],
#    'owner': {'account_id': 393493,
#     'reputation': 4941,
#     'user_id': 755371,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://i.stack.imgur.com/Cmp2K.png?s=256&g=1',
#     'display_name': 'Eric',
#     'link': 'https://stackoverflow.com/users/755371/eric'},
#    'is_answered': True,
#    'view_count': 7881,
#    'closed_date': 1648640765,
#    'accepted_answer_id': 71644988,
#    'answer_count': 2,
#    'score': 77,
#    'last_activity_date': 1648641525,
#    'creation_date': 1648455910,
#    'last_edit_date': 1648563343,
#    'question_id': 71644405,
#    'link': 'https://stackoverflow.com/questions/71644405/why-is-it-faster-to-compare-strings-that-match-than-strings-that-do-not',
#    'closed_reason': 'Duplicate',
#    'title': 'Why is it faster to compare strings that match than strings that do not?'},
#   {'tags': ['python', 'python-3.x', 'pip'],
#    'owner': {'account_id': 23650540,
#     'reputation': 805,
#     'user_id': 17679479,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gir3m-DTE1Yx2GwtNYJ0w02mRyRj-8yB5ZPmIx5=k-s256',
#     'display_name': 'BRICK MANE',
#     'link': 'https://stackoverflow.com/users/17679479/brick-mane'},
#    'is_answered': True,
#    'view_count': 142518,
#    'answer_count': 15,
#    'score': 74,
#    'last_activity_date': 1693433857,
#    'creation_date': 1643729700,
#    'last_edit_date': 1658994516,
#    'question_id': 70943244,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70943244/attributeerror-module-collections-has-no-attribute-mutablemapping',
#    'title': 'AttributeError: module &#39;collections&#39; has no attribute &#39;MutableMapping&#39;'},
#   {'tags': ['python', 'django', 'digital-ocean'],
#    'owner': {'account_id': 8967886,
#     'reputation': 3682,
#     'user_id': 6687699,
#     'user_type': 'registered',
#     'accept_rate': 58,
#     'profile_image': 'https://i.stack.imgur.com/4Snxy.jpg?s=256&g=1',
#     'display_name': 'Lutaaya Huzaifah Idris',
#     'link': 'https://stackoverflow.com/users/6687699/lutaaya-huzaifah-idris'},
#    'is_answered': True,
#    'view_count': 40237,
#    'accepted_answer_id': 73932581,
#    'answer_count': 5,
#    'score': 72,
#    'last_activity_date': 1675852882,
#    'creation_date': 1664747002,
#    'question_id': 73929564,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73929564/entrypoints-object-has-no-attribute-get-digital-ocean',
#    'title': '&#39;EntryPoints&#39; object has no attribute &#39;get&#39; - Digital ocean'},
#   {'tags': ['python', 'enums', 'f-string'],
#    'owner': {'account_id': 10991861,
#     'reputation': 6458,
#     'user_id': 8075540,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/0eZhT.jpg?s=256&g=1',
#     'display_name': 'Daniel Walker',
#     'link': 'https://stackoverflow.com/users/8075540/daniel-walker'},
#    'is_answered': True,
#    'view_count': 8419,
#    'accepted_answer_id': 72449614,
#    'answer_count': 2,
#    'score': 71,
#    'last_activity_date': 1693593159,
#    'creation_date': 1654006677,
#    'last_edit_date': 1660255156,
#    'question_id': 72449482,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72449482/f-string-representation-different-than-str',
#    'title': 'f-string representation different than str()'},
#   {'tags': ['python', 'docker', 'flask', 'docker-compose'],
#    'owner': {'account_id': 22335364,
#     'reputation': 884,
#     'user_id': 16556045,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GitmoVYWKb7Xize5hPMshSWNoFyMKSumgrMWNBXBA=k-s256',
#     'display_name': 'KronosHedronos2077',
#     'link': 'https://stackoverflow.com/users/16556045/kronoshedronos2077'},
#    'is_answered': True,
#    'view_count': 73564,
#    'accepted_answer_id': 71219718,
#    'answer_count': 11,
#    'score': 69,
#    'last_activity_date': 1691078711,
#    'creation_date': 1645310480,
#    'last_edit_date': 1663178530,
#    'question_id': 71189819,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71189819/importerror-cannot-import-name-json-from-itsdangerous',
#    'title': 'ImportError: cannot import name &#39;json&#39; from itsdangerous'},
#   {'tags': ['python', 'ssl', 'openssl', 'runtime-error'],
#    'owner': {'account_id': 17018517,
#     'reputation': 781,
#     'user_id': 12311729,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2152598004840080/picture?type=large',
#     'display_name': 'Gianmarco Broilo',
#     'link': 'https://stackoverflow.com/users/12311729/gianmarco-broilo'},
#    'is_answered': True,
#    'view_count': 144014,
#    'accepted_answer_id': 72374542,
#    'answer_count': 12,
#    'score': 67,
#    'last_activity_date': 1700615763,
#    'creation_date': 1648128152,
#    'last_edit_date': 1700615763,
#    'question_id': 71603314,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71603314/ssl-error-unsafe-legacy-renegotiation-disabled',
#    'title': 'SSL error unsafe legacy renegotiation disabled'},
#   {'tags': ['python', 'python-3.x', 'pycharm'],
#    'owner': {'account_id': 6823618,
#     'reputation': 1052,
#     'user_id': 5250196,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/1QajQ.jpg?s=256&g=1',
#     'display_name': 'P2000',
#     'link': 'https://stackoverflow.com/users/5250196/p2000'},
#    'is_answered': True,
#    'view_count': 5822,
#    'accepted_answer_id': 72456461,
#    'answer_count': 1,
#    'score': 63,
#    'last_activity_date': 1666193246,
#    'creation_date': 1654055104,
#    'last_edit_date': 1654143878,
#    'question_id': 72456234,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72456234/why-does-print-i-e-three-dots-in-a-row-print-blank',
#    'title': 'Why does print(&quot;...&quot;), i.e. three dots in a row, print blank?'},
#   {'tags': ['python', 'tensorflow', 'conda', 'apple-m1'],
#    'owner': {'account_id': 114708,
#     'reputation': 10637,
#     'user_id': 301513,
#     'user_type': 'registered',
#     'accept_rate': 47,
#     'profile_image': 'https://i.stack.imgur.com/oWFRY.png?s=256&g=1',
#     'display_name': 'Qiulang',
#     'link': 'https://stackoverflow.com/users/301513/qiulang'},
#    'is_answered': True,
#    'view_count': 63417,
#    'protected_date': 1694544271,
#    'answer_count': 14,
#    'score': 61,
#    'last_activity_date': 1695005358,
#    'creation_date': 1657708328,
#    'last_edit_date': 1695005358,
#    'question_id': 72964800,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72964800/what-is-the-proper-way-to-install-tensorflow-on-apple-m1-in-2022',
#    'title': 'What is the proper way to install TensorFlow on Apple M1 in 2022'},
#   {'tags': ['python', 'numpy'],
#    'owner': {'account_id': 12810242,
#     'reputation': 804,
#     'user_id': 9481479,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1769985833305230/picture?type=large',
#     'display_name': 'Nawin K Sharma',
#     'link': 'https://stackoverflow.com/users/9481479/nawin-k-sharma'},
#    'is_answered': True,
#    'view_count': 87582,
#    'accepted_answer_id': 74861894,
#    'answer_count': 7,
#    'score': 60,
#    'last_activity_date': 1696327318,
#    'creation_date': 1671396136,
#    'last_edit_date': 1677183023,
#    'question_id': 74844262,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74844262/how-can-i-solve-error-module-numpy-has-no-attribute-float-in-python',
#    'title': 'How can I solve error &quot;module &#39;numpy&#39; has no attribute &#39;float&#39;&quot; in Python?'},
#   {'tags': ['python', 'ipython'],
#    'owner': {'account_id': 3582471,
#     'reputation': 2580,
#     'user_id': 2990344,
#     'user_type': 'registered',
#     'accept_rate': 69,
#     'profile_image': 'https://www.gravatar.com/avatar/a3f9a2172c31b0a956c093d24230facd?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'xdavidliu',
#     'link': 'https://stackoverflow.com/users/2990344/xdavidliu'},
#    'is_answered': True,
#    'view_count': 8269,
#    'accepted_answer_id': 71459528,
#    'answer_count': 3,
#    'score': 59,
#    'last_activity_date': 1684946724,
#    'creation_date': 1644771035,
#    'question_id': 71102876,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71102876/in-ipython-how-do-i-accept-and-use-an-autocomplete-suggestion',
#    'title': 'in ipython how do I accept and use an autocomplete suggestion?'},
#   {'tags': ['python', 'opencv'],
#    'owner': {'account_id': 21236531,
#     'reputation': 561,
#     'user_id': 15620641,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-chjRp4lpZnM/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckVdG7sDDNo-Buu9gVMDrWohJSEFA/s96-c/photo.jpg?sz=256',
#     'display_name': '&#214;mer Faruk Aydın',
#     'link': 'https://stackoverflow.com/users/15620641/%c3%96mer-faruk-ayd%c4%b1n'},
#    'is_answered': True,
#    'view_count': 110365,
#    'answer_count': 8,
#    'score': 56,
#    'last_activity_date': 1676875906,
#    'creation_date': 1655839048,
#    'question_id': 72706073,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72706073/attributeerror-partially-initialized-module-cv2-has-no-attribute-gapi-wip-gs',
#    'title': 'AttributeError: partially initialized module &#39;cv2&#39; has no attribute &#39;gapi_wip_gst_GStreamerPipeline&#39; (most likely due to a circular import)'},
#   {'tags': ['python', 'c++', 'numpy', 'complex-numbers', 'infinity'],
#    'owner': {'account_id': 1705643,
#     'reputation': 928,
#     'user_id': 1564730,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://www.gravatar.com/avatar/81f8bd69726693149da7f75f0655e5b4?s=256&d=identicon&r=PG',
#     'display_name': 'Firman',
#     'link': 'https://stackoverflow.com/users/1564730/firman'},
#    'is_answered': True,
#    'view_count': 3925,
#    'accepted_answer_id': 74799453,
#    'answer_count': 3,
#    'score': 55,
#    'last_activity_date': 1671443913,
#    'creation_date': 1671022480,
#    'last_edit_date': 1671437130,
#    'question_id': 74798626,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74798626/why-is-loginf-inf-j-equal-to-inf-0-785398-j-in-c-python-numpy',
#    'title': 'Why is log(inf + inf j) equal to (inf + 0.785398 j), In C++/Python/NumPy?'},
#   {'tags': ['python', 'django', 'heroku'],
#    'owner': {'account_id': 16660311,
#     'reputation': 640,
#     'user_id': 12040445,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/ydOnG.jpg?s=256&g=1',
#     'display_name': 'SarveshJoshi',
#     'link': 'https://stackoverflow.com/users/12040445/sarveshjoshi'},
#    'is_answered': True,
#    'view_count': 82985,
#    'accepted_answer_id': 72796492,
#    'answer_count': 11,
#    'score': 54,
#    'last_activity_date': 1697317485,
#    'creation_date': 1648843469,
#    'question_id': 71712258,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71712258/error-could-not-build-wheels-for-backports-zoneinfo-which-is-required-to-insta',
#    'title': 'ERROR: Could not build wheels for backports.zoneinfo, which is required to install pyproject.toml-based projects'},
#   {'tags': ['python', 'flask', 'jinja2'],
#    'owner': {'account_id': 15865542,
#     'reputation': 1201,
#     'user_id': 11447688,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/16e8410a6faec497b5f4eae530cda0a7?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'young_minds1',
#     'link': 'https://stackoverflow.com/users/11447688/young-minds1'},
#    'is_answered': True,
#    'view_count': 122447,
#    'answer_count': 12,
#    'score': 54,
#    'last_activity_date': 1691384656,
#    'creation_date': 1648460099,
#    'last_edit_date': 1651468617,
#    'question_id': 71645272,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71645272/importerror-cannot-import-name-markup-from-jinja2',
#    'title': 'ImportError: cannot import name &#39;Markup&#39; from &#39;jinja2&#39;'},
#   {'tags': ['python',
#     'floating-point',
#     'complex-numbers',
#     'approximate',
#     'structural-pattern-matching'],
#    'owner': {'account_id': 186862,
#     'reputation': 218388,
#     'user_id': 424499,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bc2071afd499daef001e75e14d7f9cce?s=256&d=identicon&r=PG',
#     'display_name': 'Raymond Hettinger',
#     'link': 'https://stackoverflow.com/users/424499/raymond-hettinger'},
#    'is_answered': True,
#    'view_count': 3354,
#    'accepted_answer_id': 72596437,
#    'answer_count': 2,
#    'score': 54,
#    'last_activity_date': 1656679394,
#    'creation_date': 1655074449,
#    'last_edit_date': 1655075960,
#    'question_id': 72596436,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72596436/how-to-perform-approximate-structural-pattern-matching-for-floats-and-complex',
#    'title': 'How to perform approximate structural pattern matching for floats and complex'},
#   {'tags': ['python', 'pip', 'setuptools', 'pyproject.toml'],
#    'owner': {'account_id': 2017134,
#     'reputation': 24117,
#     'user_id': 1804173,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/53f721a451a1c68caf8316cefcde3083?s=256&d=identicon&r=PG',
#     'display_name': 'bluenote10',
#     'link': 'https://stackoverflow.com/users/1804173/bluenote10'},
#    'is_answered': True,
#    'view_count': 22031,
#    'accepted_answer_id': 73600610,
#    'answer_count': 2,
#    'score': 54,
#    'last_activity_date': 1694478158,
#    'creation_date': 1662300788,
#    'last_edit_date': 1667985506,
#    'question_id': 73600082,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73600082/how-to-reference-a-requirements-txt-in-the-pyproject-toml-of-a-setuptools-projec',
#    'title': 'How to reference a requirements.txt in the pyproject.toml of a setuptools project?'},
#   {'tags': ['python', 'python-typing'],
#    'owner': {'account_id': 1881254,
#     'reputation': 1102,
#     'user_id': 1701415,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/cb5160e829bd4a3a0863e8bd6cff9aea?s=256&d=identicon&r=PG',
#     'display_name': 'Jesse',
#     'link': 'https://stackoverflow.com/users/1701415/jesse'},
#    'is_answered': True,
#    'view_count': 27181,
#    'accepted_answer_id': 76399911,
#    'answer_count': 4,
#    'score': 54,
#    'last_activity_date': 1685874348,
#    'creation_date': 1650158620,
#    'question_id': 71898644,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71898644/how-to-use-python-typing-annotated',
#    'title': 'How to use python typing.Annotated?'},
#   {'tags': ['python', 'python-poetry'],
#    'owner': {'account_id': 442058,
#     'reputation': 38,
#     'user_id': 832490,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/38de998f10120ac8f0dab7f193bedf2b?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Rodrigo',
#     'link': 'https://stackoverflow.com/users/832490/rodrigo'},
#    'is_answered': True,
#    'view_count': 34487,
#    'accepted_answer_id': 72547402,
#    'answer_count': 2,
#    'score': 54,
#    'last_activity_date': 1689952254,
#    'creation_date': 1652898582,
#    'last_edit_date': 1652904288,
#    'question_id': 72294299,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72294299/multiple-top-level-packages-discovered-in-a-flat-layout',
#    'title': 'Multiple top-level packages discovered in a flat-layout'},
#   {'tags': ['python', 'openai-api'],
#    'owner': {'account_id': 19934883,
#     'reputation': 727,
#     'user_id': 14607802,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ebb1a082fb58622f567e9f8ba1b480ca?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Charmalade',
#     'link': 'https://stackoverflow.com/users/14607802/charmalade'},
#    'is_answered': True,
#    'view_count': 34589,
#    'answer_count': 7,
#    'score': 54,
#    'last_activity_date': 1696492784,
#    'creation_date': 1670380288,
#    'last_edit_date': 1683994435,
#    'question_id': 74711107,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74711107/openai-api-continuing-conversation-in-a-dialogue',
#    'title': 'OpenAI API continuing conversation in a dialogue'},
#   {'tags': ['python'],
#    'owner': {'account_id': 24835532,
#     'reputation': 501,
#     'user_id': 18714220,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjpNxl2WQc7w30aQ9y641atIyL2lvv3QmWJaerZC04=k-s256',
#     'display_name': 'Bachir bessei',
#     'link': 'https://stackoverflow.com/users/18714220/bachir-bessei'},
#    'is_answered': True,
#    'view_count': 120989,
#    'answer_count': 17,
#    'score': 50,
#    'last_activity_date': 1694893800,
#    'creation_date': 1649198983,
#    'last_edit_date': 1673098786,
#    'question_id': 71759248,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71759248/importerror-cannot-import-name-builder-from-google-protobuf-internal',
#    'title': 'ImportError: cannot import name &#39;builder&#39; from &#39;google.protobuf.internal&#39;'},
#   {'tags': ['python', 'keras', 'python-import'],
#    'owner': {'account_id': 21037901,
#     'reputation': 500,
#     'user_id': 15460921,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gi7Gj0kCeAAyfShKeD_hYFIzMQnalEKsPLX3-NMFw=k-s256',
#     'display_name': 'adhi',
#     'link': 'https://stackoverflow.com/users/15460921/adhi'},
#    'is_answered': True,
#    'view_count': 104764,
#    'protected_date': 1679307851,
#    'answer_count': 7,
#    'score': 50,
#    'last_activity_date': 1681697892,
#    'creation_date': 1653096480,
#    'last_edit_date': 1653153941,
#    'question_id': 72326025,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72326025/cannot-import-name-pad-sequences-from-keras-preprocessing-sequence',
#    'title': 'cannot import name &#39;pad_sequences&#39; from &#39;keras.preprocessing.sequence&#39;'}],
#  'has_more': False,
#  'quota_max': 300,
#  'quota_remaining': 185}
# Number of questions with the tag "python" between 2022-01-01 00:00:00 and 2022-12-31 00:00:00 and a minimum score of 50:
# 35

# %%
def get_questions(tag, start_date, end_date, min_score=50):
    api_url = 'https://api.stackexchange.com/2.3/questions'

    params = {
        'order': 'desc',
        'sort': 'votes',
        'tagged': tag,
        'site': 'stackoverflow',
        'fromdate': int(start_date.timestamp()),
        'todate': int(end_date.timestamp()),
        'min': min_score,
        'pagesize': 50  # 30 par défaut, 100 max
    }

    response = requests.get(api_url, params=params)
    data = response.json()

    return data

# Observons l'activité cette année
tag = 'python'
start_date = datetime.datetime(2020, 1, 1)
end_date = datetime.datetime(2023, 11, 27)

result = get_questions(tag, start_date, end_date)
display(result)
# Out:
# {'items': [{'tags': ['python', 'pip', 'packaging', 'pyproject.toml'],
#    'owner': {'account_id': 3400218,
#     'reputation': 29218,
#     'user_id': 3015186,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.stack.imgur.com/KagUg.jpg?s=256&g=1',
#     'display_name': 'Niko Fohr',
#     'link': 'https://stackoverflow.com/users/3015186/niko-fohr'},
#    'is_answered': True,
#    'view_count': 267658,
#    'accepted_answer_id': 66472800,
#    'answer_count': 5,
#    'score': 343,
#    'last_activity_date': 1677001110,
#    'creation_date': 1595181079,
#    'last_edit_date': 1614931841,
#    'question_id': 62983756,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62983756/what-is-pyproject-toml-file-for',
#    'title': 'What is pyproject.toml file for?'},
#   {'tags': ['python', 'pandas', 'xlrd', 'pcf'],
#    'owner': {'account_id': 20190357,
#     'reputation': 2889,
#     'user_id': 14808721,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-M5mYg2mtURw/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuck8OiIkLBi6IBucITy4XIy72uK80A/s96-c/photo.jpg?sz=256',
#     'display_name': 'Vignesh K',
#     'link': 'https://stackoverflow.com/users/14808721/vignesh-k'},
#    'is_answered': True,
#    'view_count': 577752,
#    'closed_date': 1608122436,
#    'answer_count': 2,
#    'score': 287,
#    'last_activity_date': 1612795847,
#    'creation_date': 1607702016,
#    'last_edit_date': 1612795847,
#    'question_id': 65254535,
#    'link': 'https://stackoverflow.com/questions/65254535/xlrd-biffh-xlrderror-excel-xlsx-file-not-supported',
#    'closed_reason': 'Duplicate',
#    'title': 'xlrd.biffh.XLRDError: Excel xlsx file; not supported'},
#   {'tags': ['python', 'machine-learning', 'deep-learning', 'pytorch'],
#    'owner': {'account_id': 543843,
#     'reputation': 24336,
#     'user_id': 913098,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/e3e07b09128f889209b738276d42d7ef?s=256&d=identicon&r=PG',
#     'display_name': 'Gulzar',
#     'link': 'https://stackoverflow.com/users/913098/gulzar'},
#    'is_answered': True,
#    'view_count': 263078,
#    'accepted_answer_id': 60018731,
#    'answer_count': 4,
#    'score': 259,
#    'last_activity_date': 1674767993,
#    'creation_date': 1580572695,
#    'last_edit_date': 1648471214,
#    'question_id': 60018578,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60018578/what-does-model-eval-do-in-pytorch',
#    'title': 'What does model.eval() do in pytorch?'},
#   {'tags': ['python', 'pandas', 'numpy', 'scikit-learn', 'python-3.7'],
#    'owner': {'account_id': 6886384,
#     'reputation': 2351,
#     'user_id': 15150567,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-OWGodLwptYQ/AAAAAAAAAAI/AAAAAAAAA1o/AMZuucmZZ7jUgnhUF3BKhul3RbeBZAF1Bw/s96-c/photo.jpg?sz=256',
#     'display_name': 'Sachit Jani',
#     'link': 'https://stackoverflow.com/users/15150567/sachit-jani'},
#    'is_answered': True,
#    'view_count': 330236,
#    'protected_date': 1673901248,
#    'answer_count': 19,
#    'score': 225,
#    'last_activity_date': 1680884751,
#    'creation_date': 1612516308,
#    'last_edit_date': 1673850793,
#    'question_id': 66060487,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66060487/valueerror-numpy-ndarray-size-changed-may-indicate-binary-incompatibility-exp',
#    'title': 'ValueError: numpy.ndarray size changed, may indicate binary incompatibility. Expected 88 from C header, got 80 from PyObject'},
#   {'tags': ['python', 'linux', 'docker', 'docker-compose'],
#    'owner': {'account_id': 20032870,
#     'reputation': 2211,
#     'user_id': 14685247,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0a20904979404a4f79e1d4f8bb405aab?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'ming',
#     'link': 'https://stackoverflow.com/users/14685247/ming'},
#    'is_answered': True,
#    'view_count': 333928,
#    'answer_count': 22,
#    'score': 221,
#    'last_activity_date': 1699410067,
#    'creation_date': 1606035195,
#    'last_edit_date': 1675820908,
#    'question_id': 64952238,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64952238/docker-errors-dockerexception-error-while-fetching-server-api-version',
#    'title': 'docker.errors.DockerException: Error while fetching server API version'},
#   {'tags': ['python',
#     'postgresql',
#     'sqlalchemy',
#     'flask-sqlalchemy',
#     'psycopg2'],
#    'owner': {'account_id': 8971560,
#     'reputation': 2201,
#     'user_id': 6689838,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1072816459461942/picture?type=large',
#     'display_name': 'Maharsh Gheewala',
#     'link': 'https://stackoverflow.com/users/6689838/maharsh-gheewala'},
#    'is_answered': True,
#    'view_count': 160916,
#    'protected_date': 1675825029,
#    'answer_count': 8,
#    'score': 220,
#    'last_activity_date': 1680670127,
#    'creation_date': 1593658606,
#    'last_edit_date': 1616648738,
#    'question_id': 62688256,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62688256/sqlalchemy-exc-nosuchmoduleerror-cant-load-plugin-sqlalchemy-dialectspostgre',
#    'title': 'sqlalchemy.exc.NoSuchModuleError: Can&#39;t load plugin: sqlalchemy.dialects:postgres'},
#   {'tags': ['python', 'python-3.x', 'windows-10'],
#    'owner': {'account_id': 20238494,
#     'reputation': 2033,
#     'user_id': 14842976,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-tPgUuYJN48Q/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckXs8Wy0ReqrKZ98hL19LxSjnU7mw/s96-c/photo.jpg?sz=256',
#     'display_name': 'Joseph Haywood',
#     'link': 'https://stackoverflow.com/users/14842976/joseph-haywood'},
#    'is_answered': True,
#    'view_count': 1231309,
#    'protected_date': 1615207834,
#    'closed_date': 1691903466,
#    'accepted_answer_id': 65349178,
#    'answer_count': 25,
#    'score': 203,
#    'last_activity_date': 1695144539,
#    'creation_date': 1608242137,
#    'last_edit_date': 1661715212,
#    'question_id': 65348890,
#    'link': 'https://stackoverflow.com/questions/65348890/python-was-not-found-run-without-arguments-to-install-from-the-microsoft-store',
#    'closed_reason': 'Duplicate',
#    'title': 'Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings'},
#   {'tags': ['python', 'selenium'],
#    'owner': {'account_id': 10383148,
#     'reputation': 9210,
#     'user_id': 7657180,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6c0ee64d62bb9980080e6881a20a15fc?s=256&d=identicon&r=PG',
#     'display_name': 'YasserKhalil',
#     'link': 'https://stackoverflow.com/users/7657180/yasserkhalil'},
#    'is_answered': True,
#    'view_count': 441207,
#    'protected_date': 1657217293,
#    'accepted_answer_id': 70099102,
#    'answer_count': 11,
#    'score': 198,
#    'last_activity_date': 1699941869,
#    'creation_date': 1604676159,
#    'question_id': 64717302,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64717302/deprecationwarning-executable-path-has-been-deprecated-selenium-python',
#    'title': 'DeprecationWarning: executable_path has been deprecated selenium python'},
#   {'tags': ['python', 'macos', 'terminal', 'atom-editor', 'macos-monterey'],
#    'owner': {'account_id': 24663681,
#     'reputation': 3226,
#     'user_id': 18559642,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/13cdab4eb9d9fb5b1c7dece549f96046?s=256&d=identicon&r=PG',
#     'display_name': 'Kirill Ignatyev',
#     'link': 'https://stackoverflow.com/users/18559642/kirill-ignatyev'},
#    'is_answered': True,
#    'view_count': 370728,
#    'protected_date': 1673118234,
#    'accepted_answer_id': 71621142,
#    'answer_count': 18,
#    'score': 197,
#    'last_activity_date': 1675219189,
#    'creation_date': 1648058522,
#    'last_edit_date': 1656277606,
#    'question_id': 71591971,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71591971/how-can-i-fix-the-zsh-command-not-found-python-error-macos-monterey-12-3',
#    'title': 'How can I fix the &quot;zsh: command not found: python&quot; error? (macOS Monterey 12.3, Python&amp;nbsp;3.10, Atom IDE, and atom-python-run 0.9.7)'},
#   {'tags': ['python', 'scipy', 'pip', 'embedded-linux', 'python-wheel'],
#    'owner': {'account_id': 18141135,
#     'reputation': 2186,
#     'user_id': 13194982,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-VAtJtMr3kYU/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJMjwnVVurgGF-5_cRAsdHZDLzCo4Q/photo.jpg?sz=256',
#     'display_name': 'Sourabrt',
#     'link': 'https://stackoverflow.com/users/13194982/sourabrt'},
#    'is_answered': True,
#    'view_count': 447023,
#    'answer_count': 30,
#    'score': 196,
#    'last_activity_date': 1658308129,
#    'creation_date': 1587560390,
#    'question_id': 61365790,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61365790/error-could-not-build-wheels-for-scipy-which-use-pep-517-and-cannot-be-installe',
#    'title': 'ERROR: Could not build wheels for scipy which use PEP 517 and cannot be installed directly'},
#   {'tags': ['python', 'tensorflow', 'ray'],
#    'owner': {'account_id': 22989345,
#     'reputation': 1981,
#     'user_id': 17115086,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/16c137f7793988efb97ab410f7aec4f6?s=256&d=identicon&r=PG',
#     'display_name': 'hasu33',
#     'link': 'https://stackoverflow.com/users/17115086/hasu33'},
#    'is_answered': True,
#    'view_count': 274176,
#    'protected_date': 1689017298,
#    'answer_count': 16,
#    'score': 193,
#    'last_activity_date': 1698317855,
#    'creation_date': 1653965255,
#    'last_edit_date': 1656248470,
#    'question_id': 72441758,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72441758/typeerror-descriptors-cannot-not-be-created-directly',
#    'title': 'TypeError: Descriptors cannot not be created directly'},
#   {'tags': ['python', 'macos', 'homebrew', 'python-2.x'],
#    'owner': {'account_id': 3023753,
#     'reputation': 3616,
#     'user_id': 2564199,
#     'user_type': 'registered',
#     'accept_rate': 74,
#     'profile_image': 'https://www.gravatar.com/avatar/e7de6198991a53a6c0da7ef3f5011725?s=256&d=identicon&r=PG',
#     'display_name': 'Pauline',
#     'link': 'https://stackoverflow.com/users/2564199/pauline'},
#    'is_answered': True,
#    'view_count': 213196,
#    'accepted_answer_id': 60345962,
#    'answer_count': 13,
#    'score': 191,
#    'last_activity_date': 1675891874,
#    'creation_date': 1582109114,
#    'last_edit_date': 1602553702,
#    'question_id': 60298514,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60298514/how-to-reinstall-python2-from-homebrew',
#    'title': 'How to reinstall python@2 from Homebrew?'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 4071073,
#     'reputation': 4567,
#     'user_id': 3344139,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.stack.imgur.com/ytB7I.jpg?s=256&g=1',
#     'display_name': 'RunOrVeith',
#     'link': 'https://stackoverflow.com/users/3344139/runorveith'},
#    'is_answered': True,
#    'view_count': 102335,
#    'accepted_answer_id': 65793484,
#    'answer_count': 9,
#    'score': 176,
#    'last_activity_date': 1670330583,
#    'creation_date': 1606986952,
#    'last_edit_date': 1619177945,
#    'question_id': 65122957,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65122957/resolving-new-pip-backtracking-runtime-issue',
#    'title': 'Resolving new pip backtracking runtime issue'},
#   {'tags': ['python', 'python-black'],
#    'owner': {'account_id': 13900281,
#     'reputation': 11703,
#     'user_id': 10036039,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8790cbc891c02fffb597317b43a063fa?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'zerocewl',
#     'link': 'https://stackoverflow.com/users/10036039/zerocewl'},
#    'is_answered': True,
#    'view_count': 79903,
#    'accepted_answer_id': 71674345,
#    'answer_count': 6,
#    'score': 174,
#    'last_activity_date': 1679491903,
#    'creation_date': 1648626375,
#    'last_edit_date': 1651785651,
#    'question_id': 71673404,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71673404/importerror-cannot-import-name-unicodefun-from-click',
#    'title': 'ImportError: cannot import name &#39;_unicodefun&#39; from &#39;click&#39;'},
#   {'tags': ['python', 'list', 'indexing', 'swap'],
#    'owner': {'account_id': 16490432,
#     'reputation': 2730,
#     'user_id': 13860719,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/9aXXj.jpg?s=256&g=1',
#     'display_name': 'Shaun Han',
#     'link': 'https://stackoverflow.com/users/13860719/shaun-han'},
#    'is_answered': True,
#    'view_count': 22682,
#    'accepted_answer_id': 68152940,
#    'answer_count': 8,
#    'score': 172,
#    'last_activity_date': 1698106750,
#    'creation_date': 1624808189,
#    'last_edit_date': 1698106750,
#    'question_id': 68152730,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/68152730/understand-python-swapping-why-is-a-b-b-a-not-always-equivalent-to-b-a-a',
#    'title': 'Understand Python swapping: why is a, b = b, a not always equivalent to b, a = a, b?'},
#   {'tags': ['python', 'python-3.x', 'django'],
#    'owner': {'account_id': 20471934,
#     'reputation': 1867,
#     'user_id': 15022111,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GglbOwwii7QET_t9MBkZTDpGTbdvrOVCOV40SkWew=k-s256',
#     'display_name': 'Hi There',
#     'link': 'https://stackoverflow.com/users/15022111/hi-there'},
#    'is_answered': True,
#    'view_count': 82973,
#    'accepted_answer_id': 66971803,
#    'answer_count': 5,
#    'score': 171,
#    'last_activity_date': 1659887345,
#    'creation_date': 1617722621,
#    'last_edit_date': 1659887345,
#    'question_id': 66971594,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66971594/auto-create-primary-key-used-when-not-defining-a-primary-key-type-warning-in-dja',
#    'title': 'Auto-create primary key used when not defining a primary key type warning in Django'},
#   {'tags': ['python', 'excel', 'pandas'],
#    'owner': {'account_id': 20188429,
#     'reputation': 2607,
#     'user_id': 14807216,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b31b40bb7f63928b9dc755251aa27fc1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'LNQ',
#     'link': 'https://stackoverflow.com/users/14807216/lnq'},
#    'is_answered': True,
#    'view_count': 184591,
#    'protected_date': 1608777720,
#    'answer_count': 5,
#    'score': 171,
#    'last_activity_date': 1667945202,
#    'creation_date': 1607684916,
#    'last_edit_date': 1607938283,
#    'question_id': 65250207,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65250207/pandas-cannot-open-an-excel-xlsx-file',
#    'title': 'Pandas cannot open an Excel (.xlsx) file'},
#   {'tags': ['python', 'django', 'django-urls', 'django-4.0'],
#    'owner': {'account_id': 39506,
#     'reputation': 301205,
#     'user_id': 113962,
#     'user_type': 'registered',
#     'accept_rate': 87,
#     'profile_image': 'https://www.gravatar.com/avatar/b80ae1d65878cf68a4b1a00848467527?s=256&d=identicon&r=PG',
#     'display_name': 'Alasdair',
#     'link': 'https://stackoverflow.com/users/113962/alasdair'},
#    'is_answered': True,
#    'view_count': 189803,
#    'protected_date': 1688169134,
#    'accepted_answer_id': 70319607,
#    'answer_count': 5,
#    'score': 169,
#    'last_activity_date': 1690610954,
#    'creation_date': 1639262655,
#    'question_id': 70319606,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70319606/importerror-cannot-import-name-url-from-django-conf-urls-after-upgrading-to',
#    'title': 'ImportError: cannot import name &#39;url&#39; from &#39;django.conf.urls&#39; after upgrading to Django 4.0'},
#   {'tags': ['python', 'python-3.x', 'tensorflow', 'keras', 'tensorflow2.0'],
#    'owner': {'account_id': 3882738,
#     'reputation': 18649,
#     'user_id': 3214872,
#     'user_type': 'registered',
#     'accept_rate': 82,
#     'profile_image': 'https://i.stack.imgur.com/NJBvG.jpg?s=256&g=1',
#     'display_name': 'GPhilo',
#     'link': 'https://stackoverflow.com/users/3214872/gphilo'},
#    'is_answered': True,
#    'view_count': 463485,
#    'protected_date': 1596965559,
#    'accepted_answer_id': 59823284,
#    'answer_count': 19,
#    'score': 160,
#    'last_activity_date': 1667973558,
#    'creation_date': 1579523213,
#    'last_edit_date': 1590593147,
#    'question_id': 59823283,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59823283/could-not-load-dynamic-library-cudart64-101-dll-on-tensorflow-cpu-only-install',
#    'title': 'Could not load dynamic library &#39;cudart64_101.dll&#39; on tensorflow CPU-only installation'},
#   {'tags': ['python', 'linux', 'alpine-linux'],
#    'owner': {'account_id': 6547232,
#     'reputation': 2129,
#     'user_id': 5062828,
#     'user_type': 'registered',
#     'accept_rate': 22,
#     'profile_image': 'https://lh5.googleusercontent.com/-76-PjkdknXw/AAAAAAAAAAI/AAAAAAAAAAA/ACevoQPo1bNLcNrv-ki3G8Lnlad_JmAClQ/mo/photo.jpg?sz=256',
#     'display_name': 'Cutaraca',
#     'link': 'https://stackoverflow.com/users/5062828/cutaraca'},
#    'is_answered': True,
#    'view_count': 275509,
#    'accepted_answer_id': 62555259,
#    'answer_count': 8,
#    'score': 155,
#    'last_activity_date': 1687675164,
#    'creation_date': 1593001526,
#    'question_id': 62554991,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62554991/how-do-i-install-python-on-alpine-linux',
#    'title': 'How do I install python on alpine linux?'},
#   {'tags': ['python', 'error-handling', 'pip'],
#    'owner': {'account_id': 23480036,
#     'reputation': 1614,
#     'user_id': 17532318,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d37672946ecec10b2814be93daa910ef?s=256&d=identicon&r=PG',
#     'display_name': 'Apoliticalboy',
#     'link': 'https://stackoverflow.com/users/17532318/apoliticalboy'},
#    'is_answered': True,
#    'view_count': 224796,
#    'answer_count': 17,
#    'score': 150,
#    'last_activity_date': 1700813401,
#    'creation_date': 1677700339,
#    'last_edit_date': 1694084649,
#    'question_id': 75608323,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75608323/how-do-i-solve-error-externally-managed-environment-every-time-i-use-pip-3',
#    'title': 'How do I solve &quot;error: externally-managed-environment&quot; every time I use pip 3?'},
#   {'tags': ['python', 'pandas', 'dataframe', 'attributeerror'],
#    'owner': {'account_id': 18651684,
#     'reputation': 1673,
#     'user_id': 13595011,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gja1Bf3zfNP7LY4HSFgp6beG2pul2AVcXIsoLC52g=k-s256',
#     'display_name': 'Maksimjeet Chowdhary',
#     'link': 'https://stackoverflow.com/users/13595011/maksimjeet-chowdhary'},
#    'is_answered': True,
#    'view_count': 261517,
#    'protected_date': 1695993982,
#    'answer_count': 3,
#    'score': 149,
#    'last_activity_date': 1699567288,
#    'creation_date': 1680851159,
#    'last_edit_date': 1691967377,
#    'question_id': 75956209,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75956209/error-dataframe-object-has-no-attribute-append',
#    'title': 'Error &quot;&#39;DataFrame&#39; object has no attribute &#39;append&#39;&quot;'},
#   {'tags': ['python', 'python-3.x', 'list', 'cpython', 'python-internals'],
#    'owner': {'account_id': 1843521,
#     'reputation': 27723,
#     'user_id': 1672429,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0815eb7d4e9dd58022d51ba2011b9c0a?s=256&d=identicon&r=PG',
#     'display_name': 'Stefan Pochmann',
#     'link': 'https://stackoverflow.com/users/1672429/stefan-pochmann'},
#    'is_answered': True,
#    'view_count': 6102,
#    'accepted_answer_id': 60551320,
#    'answer_count': 3,
#    'score': 149,
#    'last_activity_date': 1583600431,
#    'creation_date': 1583425357,
#    'last_edit_date': 1583429583,
#    'question_id': 60549865,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60549865/what-causes-a-to-overallocate',
#    'title': 'What causes [*a] to overallocate?'},
#   {'tags': ['python', 'python-3.x', 'visual-studio'],
#    'owner': {'account_id': 19662853,
#     'reputation': 1420,
#     'user_id': 14393948,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gg43aRRTvCexfkiavPSoo5UpYnVZY_0K6AcxdI6bg=k-s256',
#     'display_name': 'wloleo',
#     'link': 'https://stackoverflow.com/users/14393948/wloleo'},
#    'is_answered': True,
#    'view_count': 358694,
#    'protected_date': 1668477194,
#    'accepted_answer_id': 64262038,
#    'answer_count': 8,
#    'score': 147,
#    'last_activity_date': 1699328956,
#    'creation_date': 1602156410,
#    'last_edit_date': 1647686567,
#    'question_id': 64261546,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64261546/how-to-solve-error-microsoft-visual-c-14-0-or-greater-is-required-when-inst',
#    'title': 'How to solve &quot;error: Microsoft Visual C++ 14.0 or greater is required&quot; when installing Python packages?'},
#   {'tags': ['python', 'visual-studio-code', 'python-poetry'],
#    'owner': {'account_id': 10908059,
#     'reputation': 3074,
#     'user_id': 8491363,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6efa1647cc8d6adae97bcab9fd30d9ef?s=256&d=identicon&r=PG',
#     'display_name': 'user8491363',
#     'link': 'https://stackoverflow.com/users/8491363/user8491363'},
#    'is_answered': True,
#    'view_count': 86444,
#    'accepted_answer_id': 64434542,
#    'answer_count': 4,
#    'score': 146,
#    'last_activity_date': 1695631489,
#    'creation_date': 1579796188,
#    'question_id': 59882884,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59882884/vscode-doesnt-show-poetry-virtualenvs-in-select-interpreter-option',
#    'title': 'VSCode doesn&#39;t show poetry virtualenvs in select interpreter option'},
#   {'tags': ['python', 'path', 'pip', 'requirements.txt'],
#    'owner': {'account_id': 8311384,
#     'reputation': 2071,
#     'user_id': 6246352,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/ws9ud.jpg?s=256&g=1',
#     'display_name': 'Naeem Khoshnevis',
#     'link': 'https://stackoverflow.com/users/6246352/naeem-khoshnevis'},
#    'is_answered': True,
#    'view_count': 52488,
#    'protected_date': 1662599526,
#    'accepted_answer_id': 62886215,
#    'answer_count': 1,
#    'score': 144,
#    'last_activity_date': 1652418020,
#    'creation_date': 1594683418,
#    'question_id': 62885911,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62885911/pip-freeze-creates-some-weird-path-instead-of-the-package-version',
#    'title': 'pip freeze creates some weird path instead of the package version'},
#   {'tags': ['python', 'pip', 'python-poetry'],
#    'owner': {'account_id': 446266,
#     'reputation': 6482,
#     'user_id': 839211,
#     'user_type': 'registered',
#     'accept_rate': 90,
#     'profile_image': 'https://i.stack.imgur.com/THWvr.jpg?s=256&g=1',
#     'display_name': 'Felipe',
#     'link': 'https://stackoverflow.com/users/839211/felipe'},
#    'is_answered': True,
#    'view_count': 105583,
#    'accepted_answer_id': 62787881,
#    'answer_count': 16,
#    'score': 143,
#    'last_activity_date': 1700488456,
#    'creation_date': 1594067909,
#    'last_edit_date': 1662582741,
#    'question_id': 62764148,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62764148/how-to-import-requirements-txt-from-an-existing-project-using-poetry',
#    'title': 'How to import requirements.txt from an existing project using Poetry'},
#   {'tags': ['python', 'machine-learning', 'package', 'conda', 'python-poetry'],
#    'owner': {'account_id': 1449869,
#     'reputation': 2561,
#     'user_id': 1367124,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://i.stack.imgur.com/azGrD.jpg?s=256&g=1',
#     'display_name': 'Seub',
#     'link': 'https://stackoverflow.com/users/1367124/seub'},
#    'is_answered': True,
#    'view_count': 61264,
#    'accepted_answer_id': 71110028,
#    'answer_count': 3,
#    'score': 142,
#    'last_activity_date': 1699380700,
#    'creation_date': 1643123383,
#    'last_edit_date': 1643126235,
#    'question_id': 70851048,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70851048/does-it-make-sense-to-use-conda-poetry',
#    'title': 'Does it make sense to use Conda + Poetry?'},
#   {'tags': ['python', 'pandas', 'dataframe', 'data-wrangling', 'data-munging'],
#    'owner': {'account_id': 29727,
#     'reputation': 4413,
#     'user_id': 80544,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.stack.imgur.com/HtN07.jpg?s=256&g=1',
#     'display_name': 'Glenn',
#     'link': 'https://stackoverflow.com/users/80544/glenn'},
#    'is_answered': True,
#    'view_count': 175243,
#    'accepted_answer_id': 70837545,
#    'answer_count': 8,
#    'score': 142,
#    'last_activity_date': 1690552412,
#    'creation_date': 1643042804,
#    'last_edit_date': 1645482240,
#    'question_id': 70837397,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70837397/good-alternative-to-pandas-append-method-now-that-it-is-being-deprecated',
#    'title': 'Good alternative to Pandas .append() method, now that it is being deprecated?'},
#   {'tags': ['python', 'python-3.x', 'windows', 'numpy'],
#    'owner': {'account_id': 19883764,
#     'reputation': 1403,
#     'user_id': 14567162,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-8ED7m_am4Uo/AAAAAAAAAAI/AAAAAAAAAbU/AMZuuclxX7dkrrBdmjNHqH7VsijjuTKGIg/s96-c/photo.jpg?sz=256',
#     'display_name': 'Reed Collins',
#     'link': 'https://stackoverflow.com/users/14567162/reed-collins'},
#    'is_answered': True,
#    'view_count': 85465,
#    'protected_date': 1605219106,
#    'accepted_answer_id': 64658254,
#    'answer_count': 9,
#    'score': 140,
#    'last_activity_date': 1610096233,
#    'creation_date': 1604360224,
#    'last_edit_date': 1605519690,
#    'question_id': 64654805,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64654805/how-do-you-fix-runtimeerror-package-fails-to-pass-a-sanity-check-for-numpy-an',
#    'title': 'How do you fix &quot;runtimeError: package fails to pass a sanity check&quot; for numpy and pandas?'},
#   {'tags': ['python', 'fastapi', 'uvicorn'],
#    'owner': {'account_id': 18038692,
#     'reputation': 1391,
#     'user_id': 13111448,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b0668a7d54439dc6d0e453488bf53827?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Pokisutra',
#     'link': 'https://stackoverflow.com/users/13111448/pokisutra'},
#    'is_answered': True,
#    'view_count': 203473,
#    'protected_date': 1668645866,
#    'accepted_answer_id': 62934660,
#    'answer_count': 14,
#    'score': 137,
#    'last_activity_date': 1693004003,
#    'creation_date': 1584987372,
#    'last_edit_date': 1648939338,
#    'question_id': 60819376,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/60819376/fastapi-throws-an-error-error-loading-asgi-app-could-not-import-module-api',
#    'title': 'FastAPI throws an error (Error loading ASGI app. Could not import module &quot;api&quot;)'},
#   {'tags': ['python', 'tensorflow', 'anaconda'],
#    'owner': {'account_id': 10181486,
#     'reputation': 3279,
#     'user_id': 7518091,
#     'user_type': 'registered',
#     'accept_rate': 91,
#     'profile_image': 'https://www.gravatar.com/avatar/f8af9d177a327eaf22be1651863a103a?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'user1315789',
#     'link': 'https://stackoverflow.com/users/7518091/user1315789'},
#    'is_answered': True,
#    'view_count': 228875,
#    'accepted_answer_id': 65333085,
#    'answer_count': 8,
#    'score': 134,
#    'last_activity_date': 1700233427,
#    'creation_date': 1607990716,
#    'last_edit_date': 1700233279,
#    'question_id': 65298241,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65298241/what-does-this-tensorflow-message-mean-any-side-effect-was-the-installation-su',
#    'title': 'What does this tensorflow message mean? Any side effect? Was the installation successful?'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 12235881,
#     'reputation': 2037,
#     'user_id': 8930321,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/0bc45c7114227787d7f27ce17f523a36?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'lowercase00',
#     'link': 'https://stackoverflow.com/users/8930321/lowercase00'},
#    'is_answered': True,
#    'view_count': 493124,
#    'protected_date': 1587068882,
#    'answer_count': 18,
#    'score': 132,
#    'last_activity_date': 1677439515,
#    'creation_date': 1580436978,
#    'last_edit_date': 1614469552,
#    'question_id': 59997065,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59997065/pip-python-normal-site-packages-is-not-writeable',
#    'title': 'pip/python: normal site-packages is not writeable'},
#   {'tags': ['python', 'python-3.x', 'download', 'youtube', 'youtube-dl'],
#    'owner': {'account_id': 18939012,
#     'reputation': 1457,
#     'user_id': 13819476,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8bbd0a28d4d0e1ce6ba2a58b63aae260?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Bastien',
#     'link': 'https://stackoverflow.com/users/13819476/bastien'},
#    'is_answered': True,
#    'view_count': 175846,
#    'protected_date': 1609065407,
#    'accepted_answer_id': 65230976,
#    'answer_count': 10,
#    'score': 131,
#    'last_activity_date': 1682517250,
#    'creation_date': 1599673099,
#    'last_edit_date': 1619130962,
#    'question_id': 63816790,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/63816790/youtube-dl-error-youtube-said-unable-to-extract-video-data',
#    'title': 'Youtube_dl : ERROR : YouTube said: Unable to extract video data'},
#   {'tags': ['python', 'google-analytics-api'],
#    'owner': {'account_id': 6468208,
#     'reputation': 6455,
#     'user_id': 5009293,
#     'user_type': 'registered',
#     'accept_rate': 76,
#     'profile_image': 'https://graph.facebook.com/995762863775266/picture?type=large',
#     'display_name': 'Doug Coats',
#     'link': 'https://stackoverflow.com/users/5009293/doug-coats'},
#    'is_answered': True,
#    'view_count': 205518,
#    'accepted_answer_id': 73932621,
#    'answer_count': 18,
#    'score': 128,
#    'last_activity_date': 1693903144,
#    'creation_date': 1663949925,
#    'last_edit_date': 1663952437,
#    'question_id': 73830524,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73830524/attributeerror-module-lib-has-no-attribute-x509-v-flag-cb-issuer-check',
#    'title': 'AttributeError: module &#39;lib&#39; has no attribute &#39;X509_V_FLAG_CB_ISSUER_CHECK&#39;'},
#   {'tags': ['python', 'python-3.x', 'pathlib'],
#    'owner': {'account_id': 16410122,
#     'reputation': 1933,
#     'user_id': 11853632,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/12a934b35c313adcbf98aaf10aed69f1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'reinhardt',
#     'link': 'https://stackoverflow.com/users/11853632/reinhardt'},
#    'is_answered': True,
#    'view_count': 94191,
#    'accepted_answer_id': 61321618,
#    'answer_count': 6,
#    'score': 123,
#    'last_activity_date': 1658545772,
#    'creation_date': 1587382490,
#    'question_id': 61321503,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61321503/is-there-a-pathlib-alternate-for-os-path-join',
#    'title': 'Is there a Pathlib alternate for os.path.join?'},
#   {'tags': ['python', 'pylint'],
#    'owner': {'account_id': 15406446,
#     'reputation': 1419,
#     'user_id': 12160503,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2048851171863469/picture?type=large',
#     'display_name': 'Isaac Anatolio',
#     'link': 'https://stackoverflow.com/users/12160503/isaac-anatolio'},
#    'is_answered': True,
#    'view_count': 193654,
#    'closed_date': 1665543271,
#    'answer_count': 8,
#    'score': 123,
#    'last_activity_date': 1628071953,
#    'creation_date': 1583716399,
#    'last_edit_date': 1616202315,
#    'question_id': 60593604,
#    'link': 'https://stackoverflow.com/questions/60593604/importerror-attempted-relative-import-with-no-known-parent-package',
#    'closed_reason': 'Duplicate',
#    'title': 'ImportError : Attempted relative import with no known parent package'},
#   {'tags': ['python',
#     'django',
#     'importerror',
#     'python-module',
#     'circular-dependency'],
#    'owner': {'account_id': 9473820,
#     'reputation': 1215,
#     'user_id': 7043835,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4203ed009a7d8e7636fcfe3c0e03ae22?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': '3WZ',
#     'link': 'https://stackoverflow.com/users/7043835/3wz'},
#    'is_answered': True,
#    'view_count': 380536,
#    'protected_date': 1623706069,
#    'accepted_answer_id': 64809784,
#    'answer_count': 16,
#    'score': 121,
#    'last_activity_date': 1688392928,
#    'creation_date': 1605196086,
#    'last_edit_date': 1669973149,
#    'question_id': 64807163,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/64807163/importerror-cannot-import-name-from-partially-initialized-module-m',
#    'title': 'ImportError: cannot import name &#39;...&#39; from partially initialized module &#39;...&#39; (most likely due to a circular import)'},
#   {'tags': ['python',
#     'docker',
#     'docker-compose',
#     'dependencies',
#     'importerror'],
#    'owner': {'account_id': 3369545,
#     'reputation': 3171,
#     'user_id': 2829150,
#     'user_type': 'registered',
#     'accept_rate': 51,
#     'profile_image': 'https://www.gravatar.com/avatar/1e9c788890b3d2a8e468ed2773864b2c?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Arie',
#     'link': 'https://stackoverflow.com/users/2829150/arie'},
#    'is_answered': True,
#    'view_count': 152032,
#    'protected_date': 1691442712,
#    'answer_count': 15,
#    'score': 117,
#    'last_activity_date': 1699634829,
#    'creation_date': 1652208276,
#    'last_edit_date': 1667754370,
#    'question_id': 72191560,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72191560/importerror-cannot-import-name-soft-unicode-from-markupsafe',
#    'title': 'ImportError: cannot import name &#39;soft_unicode&#39; from &#39;markupsafe&#39;'},
#   {'tags': ['python', 'pandas', 'dataframe'],
#    'owner': {'account_id': 15702272,
#     'reputation': 1261,
#     'user_id': 11330069,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-V1jQ5QLfKI8/AAAAAAAAAAI/AAAAAAAAABY/j4kK5yAK4Ak/photo.jpg?sz=256',
#     'display_name': 'Diarmid Roberts',
#     'link': 'https://stackoverflow.com/users/11330069/diarmid-roberts'},
#    'is_answered': True,
#    'view_count': 161464,
#    'answer_count': 16,
#    'score': 116,
#    'last_activity_date': 1685493073,
#    'creation_date': 1580405248,
#    'last_edit_date': 1614713321,
#    'question_id': 59991397,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/59991397/attributeerror-dataframe-object-has-no-attribute-ix',
#    'title': 'AttributeError: &#39;DataFrame&#39; object has no attribute &#39;ix&#39;'},
#   {'tags': ['python', 'python-3.x', 'linux', 'pip'],
#    'owner': {'account_id': 22984508,
#     'reputation': 1161,
#     'user_id': 17110906,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4d835ba2d974f7b6e2c5844a29641106?s=256&d=identicon&r=PG',
#     'display_name': 'Christopher Coco',
#     'link': 'https://stackoverflow.com/users/17110906/christopher-coco'},
#    'is_answered': True,
#    'view_count': 142053,
#    'answer_count': 11,
#    'score': 115,
#    'last_activity_date': 1676514324,
#    'creation_date': 1633747154,
#    'last_edit_date': 1633747387,
#    'question_id': 69503329,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69503329/pip-is-not-working-for-python-3-10-on-ubuntu',
#    'title': 'Pip is not working for Python 3.10 on Ubuntu'},
#   {'tags': ['python',
#     'machine-learning',
#     'scikit-learn',
#     'logistic-regression'],
#    'owner': {'account_id': 1130688,
#     'reputation': 1813,
#     'user_id': 7373787,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/6df86729130c9a20a2df0e2aeefd7443?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'sums22',
#     'link': 'https://stackoverflow.com/users/7373787/sums22'},
#    'is_answered': True,
#    'view_count': 239718,
#    'protected_date': 1618936399,
#    'accepted_answer_id': 62659927,
#    'answer_count': 4,
#    'score': 115,
#    'last_activity_date': 1673518122,
#    'creation_date': 1593522500,
#    'last_edit_date': 1618913680,
#    'question_id': 62658215,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/62658215/convergencewarning-lbfgs-failed-to-converge-status-1-stop-total-no-of-iter',
#    'title': 'ConvergenceWarning: lbfgs failed to converge (status=1): STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'},
#   {'tags': ['python', 'python-3.9'],
#    'owner': {'account_id': 4650123,
#     'reputation': 34595,
#     'user_id': 3767239,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://www.gravatar.com/avatar/4d6c9d978220f4ac99f6a1237288a99c?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'a_guest',
#     'link': 'https://stackoverflow.com/users/3767239/a-guest'},
#    'is_answered': True,
#    'view_count': 11147,
#    'answer_count': 3,
#    'score': 114,
#    'last_activity_date': 1612271090,
#    'creation_date': 1611094722,
#    'last_edit_date': 1611234002,
#    'question_id': 65800344,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65800344/what-are-soft-keywords',
#    'title': 'What are &quot;soft keywords&quot;?'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 69666,
#     'reputation': 6265,
#     'user_id': 202576,
#     'user_type': 'registered',
#     'accept_rate': 47,
#     'profile_image': 'https://www.gravatar.com/avatar/bdf45a8317ff3471cdcc7ba2f18c79a1?s=256&d=identicon&r=PG',
#     'display_name': 'onknows',
#     'link': 'https://stackoverflow.com/users/202576/onknows'},
#    'is_answered': True,
#    'view_count': 151719,
#    'protected_date': 1618889077,
#    'answer_count': 12,
#    'score': 113,
#    'last_activity_date': 1674357448,
#    'creation_date': 1611639213,
#    'last_edit_date': 1674357448,
#    'question_id': 65896334,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/65896334/upgrading-pip-fails-with-syntax-error-caused-by-sys-stderr-writeferror-exc',
#    'title': 'Upgrading pip fails with syntax error caused by sys.stderr.write(f&quot;ERROR: {exc}&quot;)'},
#   {'tags': ['python', 'virtualenv'],
#    'owner': {'account_id': 15854936,
#     'reputation': 1251,
#     'user_id': 11439612,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/bBSil.jpg?s=256&g=1',
#     'display_name': 'Tung Ng.',
#     'link': 'https://stackoverflow.com/users/11439612/tung-ng'},
#    'is_answered': True,
#    'view_count': 98039,
#    'accepted_answer_id': 63491349,
#    'answer_count': 15,
#    'score': 111,
#    'last_activity_date': 1694164402,
#    'creation_date': 1597854368,
#    'last_edit_date': 1676018186,
#    'question_id': 63491221,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/63491221/modulenotfounderror-no-module-named-virtualenv-seed-embed-via-app-data-when-i',
#    'title': 'ModuleNotFoundError: No module named &#39;virtualenv.seed.embed.via_app_data&#39; when I created new env by virtualenv'},
#   {'tags': ['python', 'numpy'],
#    'owner': {'account_id': 8369136,
#     'reputation': 3442,
#     'user_id': 6284785,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/9d2ef82797b12ebbeebbf008f9524f50?s=256&d=identicon&r=PG',
#     'display_name': 'Anatoly',
#     'link': 'https://stackoverflow.com/users/6284785/anatoly'},
#    'is_answered': True,
#    'view_count': 213919,
#    'answer_count': 22,
#    'score': 110,
#    'last_activity_date': 1695172833,
#    'creation_date': 1614021415,
#    'last_edit_date': 1614030641,
#    'question_id': 66322049,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66322049/could-not-install-packages-due-to-an-oserror-winerror-2-no-such-file-or-direc',
#    'title': 'Could not install packages due to an OSError: [WinError 2] No such file or directory'},
#   {'tags': ['python', 'ubuntu', 'ubuntu-20.04'],
#    'owner': {'account_id': 13483168,
#     'reputation': 2689,
#     'user_id': 9727793,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=256',
#     'display_name': 'Kh4zit',
#     'link': 'https://stackoverflow.com/users/9727793/kh4zit'},
#    'is_answered': True,
#    'view_count': 108356,
#    'accepted_answer_id': 61876234,
#    'answer_count': 9,
#    'score': 110,
#    'last_activity_date': 1691484356,
#    'creation_date': 1589824360,
#    'last_edit_date': 1596652896,
#    'question_id': 61875869,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61875869/ubuntu-20-04-upgrade-python-missing-libffi-so-6',
#    'title': 'Ubuntu 20.04 upgrade, Python missing libffi.so.6'},
#   {'tags': ['python',
#     'selenium',
#     'google-chrome',
#     'selenium-webdriver',
#     'selenium-chromedriver'],
#    'owner': {'account_id': 19488994,
#     'reputation': 1083,
#     'user_id': 14257612,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c49440f3d6f3831211bcb56d9614a61e?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Alesss',
#     'link': 'https://stackoverflow.com/users/14257612/alesss'},
#    'is_answered': True,
#    'view_count': 251439,
#    'accepted_answer_id': 72773269,
#    'answer_count': 4,
#    'score': 108,
#    'last_activity_date': 1700498304,
#    'creation_date': 1656337711,
#    'last_edit_date': 1661689426,
#    'question_id': 72773206,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72773206/selenium-python-attributeerror-webdriver-object-has-no-attribute-find-el',
#    'title': 'Selenium - Python - AttributeError: &#39;WebDriver&#39; object has no attribute &#39;find_element_by_name&#39;'},
#   {'tags': ['python', 'linux', 'openssl', 'python-poetry'],
#    'owner': {'account_id': 7489950,
#     'reputation': 4646,
#     'user_id': 5692012,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.stack.imgur.com/a3FwR.gif?s=256&g=1',
#     'display_name': 'RobinFrcd',
#     'link': 'https://stackoverflow.com/users/5692012/robinfrcd'},
#    'is_answered': True,
#    'view_count': 193080,
#    'accepted_answer_id': 72633324,
#    'answer_count': 14,
#    'score': 107,
#    'last_activity_date': 1699036115,
#    'creation_date': 1651782719,
#    'last_edit_date': 1675089528,
#    'question_id': 72133316,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72133316/libssl-so-1-1-cannot-open-shared-object-file-no-such-file-or-directory',
#    'title': 'libssl.so.1.1: cannot open shared object file: No such file or directory'},
#   {'tags': ['python', 'python-3.x'],
#    'owner': {'account_id': 12560977,
#     'reputation': 1353,
#     'user_id': 10755032,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-OCvviTeYfqU/AAAAAAAAAAI/AAAAAAAAAA0/94yUImsA6hc/photo.jpg?sz=256',
#     'display_name': 'Karthik Bhandary',
#     'link': 'https://stackoverflow.com/users/10755032/karthik-bhandary'},
#    'is_answered': True,
#    'view_count': 256264,
#    'protected_date': 1607426163,
#    'closed_date': 1663684177,
#    'accepted_answer_id': 59777118,
#    'answer_count': 4,
#    'score': 107,
#    'last_activity_date': 1681200762,
#    'creation_date': 1579148521,
#    'last_edit_date': 1609769398,
#    'question_id': 59762996,
#    'link': 'https://stackoverflow.com/questions/59762996/how-to-fix-attributeerror-partially-initialized-module',
#    'closed_reason': 'Duplicate',
#    'title': 'How to fix AttributeError: partially initialized module?'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 184}

# %%
# Plus qu'à filtrer / créer le dataframe

def extract_fields_and_create_dataframe(data):
    questions = data.get('items', [])

    # Extracting desired fields
    extracted_data = [
        {
            'creation_date': question.get('creation_date', None),
            'title': question.get('title', None),
            'tags': question.get('tags', None),
            'score': question.get('score', None),
        }
        for question in questions
    ]

    # Creating DataFrame
    df = pd.DataFrame(extracted_data)

    return df

df = extract_fields_and_create_dataframe(result)

# Displaying the DataFrame
display(df)
# Out:
#     creation_date                                              title  \
# 0      1595181079                   What is pyproject.toml file for?
# 1      1607702016  xlrd.biffh.XLRDError: Excel xlsx file; not sup...
# 2      1580572695              What does model.eval() do in pytorch?
# 3      1612516308  ValueError: numpy.ndarray size changed, may in...
# 4      1606035195  docker.errors.DockerException: Error while fet...
# 5      1593658606  sqlalchemy.exc.NoSuchModuleError: Can&#39;t lo...
# 6      1608242137  Python was not found; run without arguments to...
# 7      1604676159  DeprecationWarning: executable_path has been d...
# 8      1648058522  How can I fix the &quot;zsh: command not found...
# 9      1587560390  ERROR: Could not build wheels for scipy which ...
# 10     1653965255  TypeError: Descriptors cannot not be created d...
# 11     1582109114           How to reinstall python@2 from Homebrew?
# 12     1606986952       Resolving new pip backtracking runtime issue
# 13     1648626375  ImportError: cannot import name &#39;_unicodef...
# 14     1624808189  Understand Python swapping: why is a, b = b, a...
# 15     1617722621  Auto-create primary key used when not defining...
# 16     1607684916           Pandas cannot open an Excel (.xlsx) file
# 17     1639262655  ImportError: cannot import name &#39;url&#39; ...
# 18     1579523213  Could not load dynamic library &#39;cudart64_1...
# 19     1593001526           How do I install python on alpine linux?
# 20     1677700339  How do I solve &quot;error: externally-managed...
# 21     1680851159  Error &quot;&#39;DataFrame&#39; object has no ...
# 22     1583425357                  What causes [*a] to overallocate?
# 23     1602156410  How to solve &quot;error: Microsoft Visual C++...
# 24     1579796188  VSCode doesn&#39;t show poetry virtualenvs in ...
# 25     1594683418  pip freeze creates some weird path instead of ...
# 26     1594067909  How to import requirements.txt from an existin...
# 27     1643123383          Does it make sense to use Conda + Poetry?
# 28     1643042804  Good alternative to Pandas .append() method, n...
# 29     1604360224  How do you fix &quot;runtimeError: package fai...
# 30     1584987372  FastAPI throws an error (Error loading ASGI ap...
# 31     1607990716  What does this tensorflow message mean? Any si...
# 32     1580436978  pip/python: normal site-packages is not writeable
# 33     1599673099  Youtube_dl : ERROR : YouTube said: Unable to e...
# 34     1663949925  AttributeError: module &#39;lib&#39; has no at...
# 35     1587382490     Is there a Pathlib alternate for os.path.join?
# 36     1583716399  ImportError : Attempted relative import with n...
# 37     1605196086  ImportError: cannot import name &#39;...&#39; ...
# 38     1652208276  ImportError: cannot import name &#39;soft_unic...
# 39     1580405248  AttributeError: &#39;DataFrame&#39; object has...
# 40     1633747154       Pip is not working for Python 3.10 on Ubuntu
# 41     1593522500  ConvergenceWarning: lbfgs failed to converge (...
# 42     1611094722                What are &quot;soft keywords&quot;?
# 43     1611639213  Upgrading pip fails with syntax error caused b...
# 44     1597854368  ModuleNotFoundError: No module named &#39;virt...
# 45     1614021415  Could not install packages due to an OSError: ...
# 46     1589824360   Ubuntu 20.04 upgrade, Python missing libffi.so.6
# 47     1656337711  Selenium - Python - AttributeError: &#39;WebDr...
# 48     1651782719  libssl.so.1.1: cannot open shared object file:...
# 49     1579148521  How to fix AttributeError: partially initializ...
#
#                                                  tags  score
# 0            [python, pip, packaging, pyproject.toml]    343
# 1                         [python, pandas, xlrd, pcf]    287
# 2   [python, machine-learning, deep-learning, pyto...    259
# 3   [python, pandas, numpy, scikit-learn, python-3.7]    225
# 4             [python, linux, docker, docker-compose]    221
# 5   [python, postgresql, sqlalchemy, flask-sqlalch...    220
# 6                    [python, python-3.x, windows-10]    203
# 7                                  [python, selenium]    198
# 8   [python, macos, terminal, atom-editor, macos-m...    197
# 9   [python, scipy, pip, embedded-linux, python-wh...    196
# 10                          [python, tensorflow, ray]    193
# 11              [python, macos, homebrew, python-2.x]    191
# 12                                      [python, pip]    176
# 13                             [python, python-black]    174
# 14                     [python, list, indexing, swap]    172
# 15                       [python, python-3.x, django]    171
# 16                            [python, excel, pandas]    171
# 17          [python, django, django-urls, django-4.0]    169
# 18  [python, python-3.x, tensorflow, keras, tensor...    160
# 19                      [python, linux, alpine-linux]    155
# 20                      [python, error-handling, pip]    150
# 21        [python, pandas, dataframe, attributeerror]    149
# 22  [python, python-3.x, list, cpython, python-int...    149
# 23                [python, python-3.x, visual-studio]    147
# 24        [python, visual-studio-code, python-poetry]    146
# 25              [python, path, pip, requirements.txt]    144
# 26                       [python, pip, python-poetry]    143
# 27  [python, machine-learning, package, conda, pyt...    142
# 28  [python, pandas, dataframe, data-wrangling, da...    142
# 29               [python, python-3.x, windows, numpy]    140
# 30                         [python, fastapi, uvicorn]    137
# 31                     [python, tensorflow, anaconda]    134
# 32                                      [python, pip]    132
# 33  [python, python-3.x, download, youtube, youtub...    131
# 34                     [python, google-analytics-api]    128
# 35                      [python, python-3.x, pathlib]    123
# 36                                   [python, pylint]    123
# 37  [python, django, importerror, python-module, c...    121
# 38  [python, docker, docker-compose, dependencies,...    117
# 39                        [python, pandas, dataframe]    116
# 40                   [python, python-3.x, linux, pip]    115
# 41  [python, machine-learning, scikit-learn, logis...    115
# 42                               [python, python-3.9]    114
# 43                                      [python, pip]    113
# 44                               [python, virtualenv]    111
# 45                                    [python, numpy]    110
# 46                     [python, ubuntu, ubuntu-20.04]    110
# 47  [python, selenium, google-chrome, selenium-web...    108
# 48            [python, linux, openssl, python-poetry]    107
# 49                               [python, python-3.x]    107

# %% [markdown]
# ## Préparation de la requete SQL : consultation de la doc (schema)

# %%
# La page d'accueil du "StackExchange Data Explorer" (l'outil d’export de données)
# présente la structure de la table, avec le type de chaque colonne, et un lien vers la doc :
# https://meta.stackexchange.com/questions/2677/database-schema-documentation-for-the-public-data-dump-and-sede

# Table : posts
# "You find in Posts all non-deleted posts."

# La requete donnee en exemple est un tres bon pt de depart.
# Tags1 - question tags (PostTypeId = 1)
# AnswerCount - the number of undeleted answers (only present if PostTypeId = 1)
# FavoriteCount (nullable)

# On peut aussi y ajouter :

# extraire des questions relativement recentes : par exemple, parce que de nouveaux tags on pu apparaitre,
# qui seraient sous-estimes autrement. (c'est un domaine en ébullition !)
# CreationDate > ...



# autres pistes possibles, mais pas tres utiles je pense :

# CommentCount (nullable) : semble redondant puisqu'on a deja AnswerCount et FavoriteCount
# de + sur stack il y a generalemt bcp - de commentaires que de reponses
# ClosedDate1 (present only if the post is closed) :  pas sur que cela nous importe directement
# CommunityOwnedDate (present only if post is community wiki'd) donc pas pour les questions
# ContentLicense1 pas pertinent pour nous.

# %% [markdown]
# ## Requete SQL

# %%
# SELECT TOP 50000 Title, Body, Tags, Score, ViewCount, FavoriteCount, AnswerCount
# FROM Posts
# WHERE PostTypeId = 1 AND ViewCount > 10 AND FavoriteCount > 10
# AND Score > 5 AND AnswerCount > 0 AND LEN(Tags) - LEN(REPLACE(Tags, '<','')) >= 5
# AND CreationDate >= '2020-01-01';

# est-ce qu on a vraimt besoin d'extraire les counts ?
# pourquoi pas juste Title, Body, Tags ?

# 0 row lol

# Pas besoin de GROUP BY ou d'ORDER BY ici.

# Mais pour s'amuser un peu, on peut choisir d'extraire, parmi nos questions qui remplissent nos criteres,
# les plus recentes. Notre requete devient :
